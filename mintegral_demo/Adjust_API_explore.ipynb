# %%
import json
import pandas as pd
import numpy as np

# %%
filename = './mintegral.csv'
df = pd.read_csv(filename)
df
# Out:
#         Unnamed: 0      Date  Offer Id                    Offer Uuid  \
# 0                0  20221001    138673   ss_Vid_ww_LYW_mess_mtg_0927
# 1                1  20221001    138673   ss_Vid_ww_LYW_mess_mtg_0927
# 2                2  20221001    138673   ss_Vid_ww_LYW_mess_mtg_0927
# 3                3  20221001    138673   ss_Vid_ww_LYW_mess_mtg_0927
# 4                4  20221001    138673   ss_Vid_ww_LYW_mess_mtg_0927
# ...            ...       ...       ...                           ...
# 860860      860860  20221003    128354  ss_Master_ww_JY_old_mtg_0715
# 860861      860861  20221003    127221   ss_Vid_ww_LYW_call_mtg_0707
# 860862      860862  20221003    127221   ss_Vid_ww_LYW_call_mtg_0707
# 860863      860863  20221003    127221   ss_Vid_ww_LYW_call_mtg_0707
# 860864      860864  20221003    127221   ss_Vid_ww_LYW_call_mtg_0707
#
#                        Offer Name  Campaign Id  Creative Id  \
# 0        Vid_ww_LYW_mess_mtg_0927        29366   1803321594
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Offer Id', 'Offer Uuid', 'Offer Name',
#        'Campaign Id', 'Creative Id', 'Creative Name', 'Ad Type', 'Location',
#        'Currency', 'Impression', 'Click', 'Conversion', 'Ecpm', 'Cpc', 'Ctr',
#        'Cvr', 'Ivr', 'Spend'],
#       dtype='object')

# %%
set(df['Creative Id'].values)
# Out:
# {1803231588,
#  0,
#  1803231589,
#  1803231590,
#  1803231601,
#  1801076751,
#  1803231591,
#  1803190291,
#  1803190292,
#  1803190293,
#  1803190294,
#  1803190295,
#  1803190296,
#  1803190297,
#  1803190298,
#  1803190299,
#  1803190300,
#  1803190301,
#  1803190302,
#  1803190303,
#  1803190304,
#  1803190305,
#  1803190306,
#  1803190307,
#  1803190308,
#  1803190309,
#  1803190310,
#  1803190311,
#  1803190312,
#  1803190313,
#  1803190314,
#  1803190315,
#  1803190316,
#  1803190317,
#  1803190318,
#  1803190319,
#  1803190320,
#  1803190321,
#  1803190322,
#  1803190323,
#  1803190324,
#  1803190325,
#  1803190326,
#  1803190327,
#  1803190328,
#  1803190329,
#  1803190330,
#  1803190331,
#  1803190332,
#  1803190333,
#  1803190334,
#  1803190335,
#  1803190336,
#  1803190337,
#  1803190338,
#  1803190339,
#  1803190340,
#  1803190341,
#  1803190342,
#  1803190343,
#  1803190344,
#  1803190345,
#  1803190346,
#  1803190347,
#  1803190348,
#  1803190349,
#  1803190350,
# ...

# %%
sub_id_file = "mintegral_1665507487.csv"
sub_id_df = pd.read_csv(sub_id_file)
sub_id_df
# Out:
#          Unnamed: 0      Date  Offer Id                    Offer Uuid  \
# 0                 0  20221001    128775    ss_Vid_ww_LYW_old_mtg_0719
# 1                 1  20221001    106503    ss_3x_ww_LYW_call_mtg_0610
# 2                 2  20221001    128354  ss_Master_ww_JY_old_mtg_0715
# 3                 3  20221001    128775    ss_Vid_ww_LYW_old_mtg_0719
# 4                 4  20221001    127221   ss_Vid_ww_LYW_call_mtg_0707
# ...             ...       ...       ...                           ...
# 1105295     1105295  20221001     53246    ss_3x_ww_JF_old_mtg_210702
# 1105296     1105296  20221001    128354  ss_Master_ww_JY_old_mtg_0715
# 1105297     1105297  20221001    128775    ss_Vid_ww_LYW_old_mtg_0719
# 1105298     1105298  20221001    127835    ss_SuperZ_ww_JY_mtg_220712
# 1105299     1105299  20221001    134459   ss_Melon_ww_LYW_old_mtg_831
#
#                         Offer Name  Campaign Id             Ad Type  \
# ...

# %%
sub_id_df[sub_id_df['Sub Id'] == 'mtg1260018182'].Spend.sum()
# Out:
# 205.01999999999998

# %%
set(sub_id_df['Offer Uuid'])
# Out:
# {'ss_3X_ww_dawn_woman_mtg_210722',
#  'ss_3x_global_platform_mtg',
#  'ss_3x_global_quantity_mtg_210303',
#  'ss_3x_ww_JF_new_mtg_210716',
#  'ss_3x_ww_JF_old_mtg_210702',
#  'ss_3x_ww_LYW_call_mtg_0610',
#  'ss_3x_ww_LYW_mtg_0528',
#  'ss_3x_ww_LYW_mtg_220606',
#  'ss_ABTalk_BD_JF_210813',
#  'ss_ABTalk_EG_JF_220216',
#  'ss_ABTalk_ID_JF_220301',
#  'ss_ABTalk_IN_JF_21088',
#  'ss_ABTalk_IN_JF_21225',
#  'ss_ABTalk_IN_JF_220215',
#  'ss_ABTalk_PK_JF_211109',
#  'ss_ABTalk_PK_dawn_210825',
#  'ss_ABTalk_global_LYW_WL_mtg_210528',
#  'ss_ABTalk_global_LYW_mtg_210423',
#  'ss_Abtalk_BD_dawn_211115',
#  'ss_BB_cou_LYW_mtg_0917',
#  'ss_CatCut_IN_LYW_0728_mtg',
#  'ss_Catcut_PK_JY_0823',
#  'ss_FaceU_ww_LYW_mtg_210903',
#  'ss_FaceU_ww_LYW_mtg_210907',
#  'ss_IndiaTalk_IN_JF_220205',
#  'ss_Inf_ww_LYW_mtg_WL_210513',
#  'ss_Inf_ww_dawn_mtg_210824',
#  'ss_Inf_ww_dawn_old_mtg_210712',
#  'ss_Inf_ww_dawn_woman3_mtg_210715',
#  'ss_Inf_ww_dawn_woman_mtg_210712',
# ...

# %%
bigo_file = './Bigo.csv'
bigo_df = pd.read_csv(bigo_file)
bigo_df
# Out:
#     aggregateTime                      广告系列名称             广告系列ID   推广目标  \
# 0      2022-10-11     catcut_kz_wsy_0930_bigo  52841353853342208  应用安装量
# 1      2022-10-11   catcut_bd_起量_bigo_wl_0831  52756929262294528  应用安装量
# 2      2022-10-11  catcut_gcc_起量_bigo_wl_0919  52810654827451136  应用安装量
# 3      2022-10-11   catcut_bd_起量_bigo_wl_0831  52756929262294528  应用安装量
# 4      2022-10-11     catcut_kz_wsy_0930_bigo  52841353853342208  应用安装量
# ..            ...                         ...                ...    ...
# 481    2022-10-05  catcut_gcc_起量_bigo_wl_0919  52810654827451136  应用安装量
# 482    2022-10-05  catcut_gcc_起量_bigo_wl_0919  52810654827451136  应用安装量
# 483    2022-10-05          catcut_中东_wsy_0930  52841370832409344  应用安装量
# 484    2022-10-05               catcut_wsy_09  52773625147726592  应用安装量
# 485    2022-10-05               catcut_wsy_09  52773625147726592  应用安装量
#
#                  广告组ID                       广告组名称  \
# ...

# %%
bigo_df.columns
# Out:
# Index(['aggregateTime', '广告系列名称', '广告系列ID', '推广目标', '广告组ID', '广告组名称', '推广应用',
#        '定向国家', '广告ID', '广告名称', '展示数', '点击数', 'CTR', 'CPM(USD)', 'CPC(USD)',
#        '花费(USD)', '转化量', '转化率', '转化成本(USD)', '单次转化价值(USD)', '去重安装数', '去重安装率',
#        '去重安装成本(USD)', '点击归因安装数', '点击归因安装率', '点击归因安装成本(USD)'],
#       dtype='object')

# %%
bigo_df['花费(USD)'] = bigo_df['花费(USD)'].apply(lambda x: float(x) if x != '-' else 0)

# %%
bigo_1010 = bigo_df[bigo_df['aggregateTime'] == '2022-10-10']
bigo_1010
# Out:
#     aggregateTime                      广告系列名称             广告系列ID   推广目标  \
# 82     2022-10-10   catcut_bd_起量_bigo_wl_0831  52756929262294528  应用安装量
# 83     2022-10-10     catcut_bd_wsy_0920_热门模版  52813360980496384  应用安装量
# 84     2022-10-10  catcut_gcc_起量_bigo_wl_0919  52810654827451136  应用安装量
# 85     2022-10-10     catcut_kz_wsy_0930_bigo  52841353853342208  应用安装量
# 86     2022-10-10               catcut_wsy_09  52773625147726592  应用安装量
# ..            ...                         ...                ...    ...
# 158    2022-10-10   catcut_bd_起量_bigo_wl_0831  52756929262294528  应用安装量
# 159    2022-10-10  catcut_gcc_起量_bigo_wl_0919  52810654827451136  应用安装量
# 160    2022-10-10             bd_wsy_1010_zgp  52870161891137024  应用安装量
# 161    2022-10-10          catcut_中东_wsy_0930  52841370832409344  应用安装量
# 162    2022-10-10               catcut_wsy_09  52773625147726592  应用安装量
#
#                  广告组ID                              广告组名称  \
# ...

# %%
bigo_1010['花费(USD)'].sum()
# Out:
# 234.30999999999997

# %%
adjust_config = """{"attribution_type":[{"id":"all","name":"all","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"click","name":"click","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"impression","name":"impression","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"partners":[{"id":"778","name":"Adcash DSP","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"406","name":"AdTiming","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"857","name":"Adxmi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"257","name":"Apple","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"7","name":"Applovin","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"221","name":"Appnext","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"1498","name":"Bigo","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"928","name":"ClickDealer","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"1635","name":"DemandScale","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"34","name":"Facebook","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"646","name":"Filex Media","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"1005","name":"GMO SmaAD (GMO TECH)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"254","name":"Google Ads","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"2360","name":"Google Organic Search","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"57","name":"InMobi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"2015","name":"InMobi DSP","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"182","name":"ironSource","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"410","name":"MAAS","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"369","name":"Mintegral","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"795","name":"MiraMedia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"1770","name":"OPPO国际 | OPPO Global","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-300","name":"Organic","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"1195","name":"PropellerAds","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"1569","name":"SKY FLAG","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"157","name":"Snapchat","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"2064","name":"Snapchat Web","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"172","name":"Startapp","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"30","name":"Tapjoy","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"1678","name":"TikTok for Business","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"32","name":"Twitter","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"217","name":"Unity Ads","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"1718","name":"Vivo 国际 | Vivo Global","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"112","name":"Vungle","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"560","name":"xiaomi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"194","name":"Yeahmobi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"2164","name":"快手（海外） | Kwai for Business (Global)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"1600","name":"有米 国际 | Youmi Overseas","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"attribution_source":[{"id":"dynamic","name":"dynamic","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"cohort_metrics":[{"id":"ad_impressions_d0","name":"0D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d1","name":"1D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d2","name":"2D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d3","name":"3D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d4","name":"4D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d5","name":"5D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d6","name":"6D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d7","name":"7D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d8","name":"8D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d14","name":"14D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d30","name":"30D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d31","name":"31D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d45","name":"45D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_d75","name":"75D Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_w0","name":"0W Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_w1","name":"1W Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_w2","name":"2W Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_w3","name":"3W Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m0","name":"0M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m1","name":"1M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m2","name":"2M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m3","name":"3M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m4","name":"4M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m5","name":"5M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m6","name":"6M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m7","name":"7M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m8","name":"8M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m9","name":"9M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m10","name":"10M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m11","name":"11M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_m12","name":"12M Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d0","name":"0D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d1","name":"1D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d2","name":"2D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d3","name":"3D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d4","name":"4D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d5","name":"5D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d6","name":"6D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d7","name":"7D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d8","name":"8D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d14","name":"14D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d30","name":"30D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d31","name":"31D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d45","name":"45D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_d75","name":"75D Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_w0","name":"0W Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_w1","name":"1W Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_w2","name":"2W Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_w3","name":"3W Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m0","name":"0M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m1","name":"1M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m2","name":"2M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m3","name":"3M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m4","name":"4M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m5","name":"5M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m6","name":"6M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m7","name":"7M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m8","name":"8M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m9","name":"9M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m10","name":"10M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m11","name":"11M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_m12","name":"12M Ad Impressions Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d0","name":"0D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d1","name":"1D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d2","name":"2D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d3","name":"3D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d4","name":"4D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d5","name":"5D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d6","name":"6D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d7","name":"7D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d8","name":"8D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d14","name":"14D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d30","name":"30D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d31","name":"31D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d45","name":"45D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_d75","name":"75D Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_w0","name":"0W Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_w1","name":"1W Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_w2","name":"2W Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_w3","name":"3W Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m0","name":"0M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m1","name":"1M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m2","name":"2M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m3","name":"3M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m4","name":"4M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m5","name":"5M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m6","name":"6M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m7","name":"7M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m8","name":"8M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m9","name":"9M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m10","name":"10M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m11","name":"11M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_impressions_total_in_cohort_m12","name":"12M Ad Impressions Total in Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_revenue_d0","name":"0D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d1","name":"1D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d2","name":"2D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d3","name":"3D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d4","name":"4D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d5","name":"5D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d6","name":"6D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d7","name":"7D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d8","name":"8D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d14","name":"14D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d30","name":"30D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d31","name":"31D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d45","name":"45D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_d75","name":"75D Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_w0","name":"0W Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_w1","name":"1W Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_w2","name":"2W Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_w3","name":"3W Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m0","name":"0M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m1","name":"1M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m2","name":"2M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m3","name":"3M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m4","name":"4M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m5","name":"5M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m6","name":"6M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m7","name":"7M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m8","name":"8M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m9","name":"9M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m10","name":"10M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m11","name":"11M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_m12","name":"12M Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d0","name":"0D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d1","name":"1D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d2","name":"2D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d3","name":"3D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d4","name":"4D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d5","name":"5D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d6","name":"6D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d7","name":"7D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d8","name":"8D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d14","name":"14D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d30","name":"30D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d31","name":"31D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d45","name":"45D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_d75","name":"75D Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_w0","name":"0W Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_w1","name":"1W Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_w2","name":"2W Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_w3","name":"3W Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m0","name":"0M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m1","name":"1M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m2","name":"2M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m3","name":"3M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m4","name":"4M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m5","name":"5M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m6","name":"6M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m7","name":"7M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m8","name":"8M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m9","name":"9M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m10","name":"10M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m11","name":"11M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_m12","name":"12M Ad Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d0","name":"0D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d1","name":"1D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d2","name":"2D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d3","name":"3D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d4","name":"4D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d5","name":"5D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d6","name":"6D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d7","name":"7D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d8","name":"8D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d14","name":"14D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d30","name":"30D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d31","name":"31D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d45","name":"45D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_d75","name":"75D Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_w0","name":"0W Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_w1","name":"1W Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_w2","name":"2W Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_w3","name":"3W Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m0","name":"0M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m1","name":"1M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m2","name":"2M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m3","name":"3M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m4","name":"4M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m5","name":"5M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m6","name":"6M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m7","name":"7M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m8","name":"8M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m9","name":"9M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m10","name":"10M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m11","name":"11M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_in_cohort_m12","name":"12M Ad Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d0","name":"0D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d1","name":"1D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d2","name":"2D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d3","name":"3D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d4","name":"4D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d5","name":"5D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d6","name":"6D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d7","name":"7D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d8","name":"8D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d14","name":"14D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d30","name":"30D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d31","name":"31D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d45","name":"45D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_d75","name":"75D Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_w0","name":"0W Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_w1","name":"1W Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_w2","name":"2W Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_w3","name":"3W Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m0","name":"0M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m1","name":"1M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m2","name":"2M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m3","name":"3M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m4","name":"4M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m5","name":"5M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m6","name":"6M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m7","name":"7M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m8","name":"8M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m9","name":"9M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m10","name":"10M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m11","name":"11M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue_total_per_user_m12","name":"12M Ad Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d0","name":"0D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d1","name":"1D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d2","name":"2D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d3","name":"3D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d4","name":"4D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d5","name":"5D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d6","name":"6D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d7","name":"7D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d8","name":"8D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d14","name":"14D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d30","name":"30D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d31","name":"31D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d45","name":"45D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_d75","name":"75D Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_w0","name":"0W Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_w1","name":"1W Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_w2","name":"2W Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_w3","name":"3W Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m0","name":"0M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m1","name":"1M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m2","name":"2M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m3","name":"3M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m4","name":"4M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m5","name":"5M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m6","name":"6M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m7","name":"7M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m8","name":"8M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m9","name":"9M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m10","name":"10M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m11","name":"11M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_rpm_m12","name":"12M Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d0","name":"0D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d1","name":"1D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d2","name":"2D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d3","name":"3D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d4","name":"4D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d5","name":"5D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d6","name":"6D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d7","name":"7D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d8","name":"8D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d14","name":"14D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d30","name":"30D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d31","name":"31D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d45","name":"45D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_d75","name":"75D All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_w0","name":"0W All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_w1","name":"1W All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_w2","name":"2W All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_w3","name":"3W All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m0","name":"0M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m1","name":"1M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m2","name":"2M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m3","name":"3M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m4","name":"4M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m5","name":"5M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m6","name":"6M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m7","name":"7M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m8","name":"8M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m9","name":"9M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m10","name":"10M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m11","name":"11M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_m12","name":"12M All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d0","name":"0D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d1","name":"1D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d2","name":"2D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d3","name":"3D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d4","name":"4D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d5","name":"5D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d6","name":"6D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d7","name":"7D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d8","name":"8D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d14","name":"14D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d30","name":"30D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d31","name":"31D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d45","name":"45D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_d75","name":"75D All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_w0","name":"0W All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_w1","name":"1W All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_w2","name":"2W All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_w3","name":"3W All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m0","name":"0M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m1","name":"1M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m2","name":"2M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m3","name":"3M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m4","name":"4M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m5","name":"5M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m6","name":"6M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m7","name":"7M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m8","name":"8M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m9","name":"9M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m10","name":"10M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m11","name":"11M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_per_user_m12","name":"12M All Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d0","name":"0D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d1","name":"1D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d2","name":"2D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d3","name":"3D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d4","name":"4D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d5","name":"5D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d6","name":"6D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d7","name":"7D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d8","name":"8D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d14","name":"14D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d30","name":"30D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d31","name":"31D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d45","name":"45D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_d75","name":"75D All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_w0","name":"0W All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_w1","name":"1W All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_w2","name":"2W All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_w3","name":"3W All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m0","name":"0M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m1","name":"1M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m2","name":"2M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m3","name":"3M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m4","name":"4M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m5","name":"5M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m6","name":"6M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m7","name":"7M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m8","name":"8M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m9","name":"9M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m10","name":"10M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m11","name":"11M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_m12","name":"12M All Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d0","name":"0D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d1","name":"1D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d2","name":"2D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d3","name":"3D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d4","name":"4D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d5","name":"5D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d6","name":"6D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d7","name":"7D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d8","name":"8D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d14","name":"14D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d30","name":"30D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d31","name":"31D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d45","name":"45D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_d75","name":"75D All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_w0","name":"0W All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_w1","name":"1W All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_w2","name":"2W All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_w3","name":"3W All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m0","name":"0M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m1","name":"1M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m2","name":"2M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m3","name":"3M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m4","name":"4M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m5","name":"5M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m6","name":"6M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m7","name":"7M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m8","name":"8M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m9","name":"9M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m10","name":"10M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m11","name":"11M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_in_cohort_m12","name":"12M All Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d0","name":"0D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d1","name":"1D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d2","name":"2D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d3","name":"3D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d4","name":"4D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d5","name":"5D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d6","name":"6D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d7","name":"7D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d8","name":"8D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d14","name":"14D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d30","name":"30D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d31","name":"31D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d45","name":"45D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_d75","name":"75D All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_w0","name":"0W All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_w1","name":"1W All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_w2","name":"2W All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_w3","name":"3W All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m0","name":"0M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m1","name":"1M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m2","name":"2M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m3","name":"3M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m4","name":"4M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m5","name":"5M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m6","name":"6M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m7","name":"7M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m8","name":"8M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m9","name":"9M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m10","name":"10M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m11","name":"11M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"all_revenue_total_per_user_m12","name":"12M All Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"cohort_size_d0","name":"0D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d1","name":"1D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d2","name":"2D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d3","name":"3D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d4","name":"4D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d5","name":"5D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d6","name":"6D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d7","name":"7D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d8","name":"8D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d14","name":"14D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d30","name":"30D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d31","name":"31D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d45","name":"45D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_d75","name":"75D Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_w0","name":"0W Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_w1","name":"1W Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_w2","name":"2W Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_w3","name":"3W Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m0","name":"0M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m1","name":"1M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m2","name":"2M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m3","name":"3M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m4","name":"4M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m5","name":"5M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m6","name":"6M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m7","name":"7M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m8","name":"8M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m9","name":"9M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m10","name":"10M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m11","name":"11M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"cohort_size_m12","name":"12M Cohort Size","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d0","name":"0D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d1","name":"1D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d2","name":"2D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d3","name":"3D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d4","name":"4D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d5","name":"5D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d6","name":"6D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d7","name":"7D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d8","name":"8D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d14","name":"14D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d30","name":"30D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d31","name":"31D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d45","name":"45D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_d75","name":"75D Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_w0","name":"0W Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_w1","name":"1W Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_w2","name":"2W Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_w3","name":"3W Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m0","name":"0M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m1","name":"1M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m2","name":"2M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m3","name":"3M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m4","name":"4M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m5","name":"5M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m6","name":"6M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m7","name":"7M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m8","name":"8M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m9","name":"9M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m10","name":"10M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m11","name":"11M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_m12","name":"12M Deattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d0","name":"0D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d1","name":"1D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d2","name":"2D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d3","name":"3D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d4","name":"4D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d5","name":"5D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d6","name":"6D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d7","name":"7D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d8","name":"8D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d14","name":"14D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d30","name":"30D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d31","name":"31D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d45","name":"45D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_d75","name":"75D Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_w0","name":"0W Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_w1","name":"1W Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_w2","name":"2W Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_w3","name":"3W Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m0","name":"0M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m1","name":"1M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m2","name":"2M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m3","name":"3M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m4","name":"4M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m5","name":"5M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m6","name":"6M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m7","name":"7M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m8","name":"8M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m9","name":"9M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m10","name":"10M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m11","name":"11M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"deattributions_per_user_m12","name":"12M Deattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d0","name":"0D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d1","name":"1D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d2","name":"2D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d3","name":"3D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d4","name":"4D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d5","name":"5D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d6","name":"6D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d7","name":"7D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d8","name":"8D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d14","name":"14D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d30","name":"30D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d31","name":"31D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d45","name":"45D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_d75","name":"75D First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_w0","name":"0W First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_w1","name":"1W First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_w2","name":"2W First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_w3","name":"3W First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m0","name":"0M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m1","name":"1M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m2","name":"2M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m3","name":"3M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m4","name":"4M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m5","name":"5M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m6","name":"6M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m7","name":"7M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m8","name":"8M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m9","name":"9M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m10","name":"10M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m11","name":"11M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_reinstalls_total_m12","name":"12M First Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"first_uninstalls_total_d0","name":"0D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d1","name":"1D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d2","name":"2D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d3","name":"3D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d4","name":"4D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d5","name":"5D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d6","name":"6D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d7","name":"7D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d8","name":"8D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d14","name":"14D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d30","name":"30D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d31","name":"31D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d45","name":"45D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_d75","name":"75D First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_w0","name":"0W First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_w1","name":"1W First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_w2","name":"2W First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_w3","name":"3W First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m0","name":"0M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m1","name":"1M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m2","name":"2M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m3","name":"3M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m4","name":"4M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m5","name":"5M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m6","name":"6M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m7","name":"7M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m8","name":"8M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m9","name":"9M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m10","name":"10M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m11","name":"11M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"first_uninstalls_total_m12","name":"12M First Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d0","name":"0D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d1","name":"1D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d2","name":"2D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d3","name":"3D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d4","name":"4D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d5","name":"5D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d6","name":"6D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d7","name":"7D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d8","name":"8D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d14","name":"14D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d30","name":"30D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d31","name":"31D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d45","name":"45D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_d75","name":"75D GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_w0","name":"0W GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_w1","name":"1W GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_w2","name":"2W GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_w3","name":"3W GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m0","name":"0M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m1","name":"1M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m2","name":"2M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m3","name":"3M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m4","name":"4M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m5","name":"5M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m6","name":"6M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m7","name":"7M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m8","name":"8M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m9","name":"9M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m10","name":"10M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m11","name":"11M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_m12","name":"12M GDPR Forgets","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d0","name":"0D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d1","name":"1D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d2","name":"2D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d3","name":"3D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d4","name":"4D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d5","name":"5D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d6","name":"6D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d7","name":"7D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d8","name":"8D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d14","name":"14D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d30","name":"30D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d31","name":"31D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d45","name":"45D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_d75","name":"75D GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_w0","name":"0W GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_w1","name":"1W GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_w2","name":"2W GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_w3","name":"3W GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m0","name":"0M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m1","name":"1M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m2","name":"2M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m3","name":"3M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m4","name":"4M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m5","name":"5M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m6","name":"6M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m7","name":"7M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m8","name":"8M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m9","name":"9M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m10","name":"10M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m11","name":"11M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gdpr_forgets_total_m12","name":"12M GDPR Forget Users Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"lifetime_value_d0","name":"0D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d1","name":"1D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d2","name":"2D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d3","name":"3D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d4","name":"4D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d5","name":"5D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d6","name":"6D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d7","name":"7D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d8","name":"8D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d14","name":"14D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d30","name":"30D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d31","name":"31D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d45","name":"45D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_d75","name":"75D LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_w0","name":"0W LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_w1","name":"1W LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_w2","name":"2W LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_w3","name":"3W LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m0","name":"0M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m1","name":"1M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m2","name":"2M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m3","name":"3M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m4","name":"4M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m5","name":"5M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m6","name":"6M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m7","name":"7M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m8","name":"8M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m9","name":"9M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m10","name":"10M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m11","name":"11M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_m12","name":"12M LTV (All) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d0","name":"0D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d1","name":"1D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d2","name":"2D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d3","name":"3D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d4","name":"4D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d5","name":"5D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d6","name":"6D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d7","name":"7D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d8","name":"8D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d14","name":"14D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d30","name":"30D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d31","name":"31D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d45","name":"45D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_d75","name":"75D LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_w0","name":"0W LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_w1","name":"1W LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_w2","name":"2W LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_w3","name":"3W LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m0","name":"0M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m1","name":"1M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m2","name":"2M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m3","name":"3M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m4","name":"4M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m5","name":"5M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m6","name":"6M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m7","name":"7M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m8","name":"8M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m9","name":"9M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m10","name":"10M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m11","name":"11M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_ad_m12","name":"12M LTV (Ad) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d0","name":"0D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d1","name":"1D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d2","name":"2D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d3","name":"3D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d4","name":"4D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d5","name":"5D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d6","name":"6D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d7","name":"7D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d8","name":"8D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d14","name":"14D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d30","name":"30D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d31","name":"31D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d45","name":"45D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_d75","name":"75D LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_w0","name":"0W LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_w1","name":"1W LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_w2","name":"2W LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_w3","name":"3W LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m0","name":"0M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m1","name":"1M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m2","name":"2M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m3","name":"3M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m4","name":"4M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m5","name":"5M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m6","name":"6M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m7","name":"7M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m8","name":"8M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m9","name":"9M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m10","name":"10M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m11","name":"11M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"lifetime_value_iap_m12","name":"12M LTV (IAP) All Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d0","name":"0D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d1","name":"1D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d2","name":"2D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d3","name":"3D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d4","name":"4D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d5","name":"5D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d6","name":"6D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d7","name":"7D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d8","name":"8D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d14","name":"14D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d30","name":"30D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d31","name":"31D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d45","name":"45D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_d75","name":"75D Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_w0","name":"0W Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_w1","name":"1W Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_w2","name":"2W Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_w3","name":"3W Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m0","name":"0M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m1","name":"1M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m2","name":"2M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m3","name":"3M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m4","name":"4M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m5","name":"5M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m6","name":"6M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m7","name":"7M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m8","name":"8M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m9","name":"9M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m10","name":"10M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m11","name":"11M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_install_sessions_m12","name":"12M Non-Install Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d0","name":"0D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d1","name":"1D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d2","name":"2D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d3","name":"3D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d4","name":"4D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d5","name":"5D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d6","name":"6D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d7","name":"7D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d8","name":"8D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d14","name":"14D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d30","name":"30D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d31","name":"31D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d45","name":"45D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_d75","name":"75D LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_w0","name":"0W LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_w1","name":"1W LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_w2","name":"2W LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_w3","name":"3W LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m0","name":"0M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m1","name":"1M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m2","name":"2M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m3","name":"3M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m4","name":"4M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m5","name":"5M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m6","name":"6M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m7","name":"7M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m8","name":"8M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m9","name":"9M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m10","name":"10M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m11","name":"11M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_m12","name":"12M LTV (All) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d0","name":"0D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d1","name":"1D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d2","name":"2D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d3","name":"3D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d4","name":"4D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d5","name":"5D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d6","name":"6D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d7","name":"7D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d8","name":"8D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d14","name":"14D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d30","name":"30D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d31","name":"31D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d45","name":"45D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_d75","name":"75D LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_w0","name":"0W LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_w1","name":"1W LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_w2","name":"2W LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_w3","name":"3W LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m0","name":"0M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m1","name":"1M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m2","name":"2M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m3","name":"3M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m4","name":"4M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m5","name":"5M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m6","name":"6M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m7","name":"7M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m8","name":"8M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m9","name":"9M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m10","name":"10M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m11","name":"11M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_ad_m12","name":"12M LTV (Ad) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d0","name":"0D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d1","name":"1D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d2","name":"2D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d3","name":"3D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d4","name":"4D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d5","name":"5D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d6","name":"6D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d7","name":"7D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d8","name":"8D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d14","name":"14D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d30","name":"30D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d31","name":"31D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d45","name":"45D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_d75","name":"75D LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_w0","name":"0W LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_w1","name":"1W LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_w2","name":"2W LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_w3","name":"3W LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m0","name":"0M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m1","name":"1M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m2","name":"2M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m3","name":"3M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m4","name":"4M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m5","name":"5M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m6","name":"6M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m7","name":"7M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m8","name":"8M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m9","name":"9M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m10","name":"10M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m11","name":"11M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_lifetime_value_iap_m12","name":"12M LTV (IAP) Paying Users","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d0","name":"0D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d1","name":"1D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d2","name":"2D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d3","name":"3D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d4","name":"4D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d5","name":"5D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d6","name":"6D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d7","name":"7D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d8","name":"8D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d14","name":"14D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d30","name":"30D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d31","name":"31D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d45","name":"45D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_d75","name":"75D Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_w0","name":"0W Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_w1","name":"1W Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_w2","name":"2W Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_w3","name":"3W Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m0","name":"0M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m1","name":"1M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m2","name":"2M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m3","name":"3M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m4","name":"4M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m5","name":"5M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m6","name":"6M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m7","name":"7M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m8","name":"8M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m9","name":"9M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m10","name":"10M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m11","name":"11M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_rate_m12","name":"12M Paying Users Rate","short_name":"","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_user_size_d0","name":"0D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d1","name":"1D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d2","name":"2D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d3","name":"3D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d4","name":"4D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d5","name":"5D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d6","name":"6D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d7","name":"7D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d8","name":"8D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d14","name":"14D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d30","name":"30D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d31","name":"31D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d45","name":"45D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_d75","name":"75D Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_w0","name":"0W Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_w1","name":"1W Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_w2","name":"2W Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_w3","name":"3W Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m0","name":"0M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m1","name":"1M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m2","name":"2M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m3","name":"3M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m4","name":"4M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m5","name":"5M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m6","name":"6M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m7","name":"7M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m8","name":"8M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m9","name":"9M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m10","name":"10M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m11","name":"11M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_user_size_m12","name":"12M Paying User Size","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d0","name":"0D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d1","name":"1D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d2","name":"2D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d3","name":"3D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d4","name":"4D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d5","name":"5D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d6","name":"6D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d7","name":"7D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d8","name":"8D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d14","name":"14D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d30","name":"30D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d31","name":"31D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d45","name":"45D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_d75","name":"75D Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_w0","name":"0W Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_w1","name":"1W Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_w2","name":"2W Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_w3","name":"3W Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m0","name":"0M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m1","name":"1M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m2","name":"2M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m3","name":"3M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m4","name":"4M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m5","name":"5M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m6","name":"6M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m7","name":"7M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m8","name":"8M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m9","name":"9M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m10","name":"10M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m11","name":"11M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_m12","name":"12M Paying Users","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d0","name":"0D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d1","name":"1D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d2","name":"2D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d3","name":"3D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d4","name":"4D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d5","name":"5D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d6","name":"6D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d7","name":"7D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d8","name":"8D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d14","name":"14D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d30","name":"30D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d31","name":"31D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d45","name":"45D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_d75","name":"75D Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_w0","name":"0W Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_w1","name":"1W Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_w2","name":"2W Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_w3","name":"3W Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m0","name":"0M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m1","name":"1M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m2","name":"2M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m3","name":"3M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m4","name":"4M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m5","name":"5M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m6","name":"6M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m7","name":"7M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m8","name":"8M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m9","name":"9M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m10","name":"10M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m11","name":"11M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"paying_users_retention_rate_m12","name":"12M Retention Rate Paying Users","short_name":"","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"reattributions_d0","name":"0D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d1","name":"1D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d2","name":"2D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d3","name":"3D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d4","name":"4D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d5","name":"5D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d6","name":"6D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d7","name":"7D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d8","name":"8D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d14","name":"14D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d30","name":"30D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d31","name":"31D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d45","name":"45D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_d75","name":"75D Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_w0","name":"0W Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_w1","name":"1W Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_w2","name":"2W Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_w3","name":"3W Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m0","name":"0M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m1","name":"1M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m2","name":"2M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m3","name":"3M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m4","name":"4M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m5","name":"5M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m6","name":"6M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m7","name":"7M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m8","name":"8M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m9","name":"9M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m10","name":"10M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m11","name":"11M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_m12","name":"12M Reattributions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d0","name":"0D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d1","name":"1D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d2","name":"2D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d3","name":"3D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d4","name":"4D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d5","name":"5D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d6","name":"6D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d7","name":"7D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d8","name":"8D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d14","name":"14D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d30","name":"30D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d31","name":"31D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d45","name":"45D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_d75","name":"75D Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_w0","name":"0W Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_w1","name":"1W Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_w2","name":"2W Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_w3","name":"3W Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m0","name":"0M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m1","name":"1M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m2","name":"2M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m3","name":"3M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m4","name":"4M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m5","name":"5M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m6","name":"6M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m7","name":"7M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m8","name":"8M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m9","name":"9M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m10","name":"10M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m11","name":"11M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_deattribution_m12","name":"12M Reattributions per Deattribution","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d0","name":"0D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d1","name":"1D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d2","name":"2D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d3","name":"3D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d4","name":"4D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d5","name":"5D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d6","name":"6D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d7","name":"7D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d8","name":"8D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d14","name":"14D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d30","name":"30D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d31","name":"31D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d45","name":"45D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_d75","name":"75D Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_w0","name":"0W Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_w1","name":"1W Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_w2","name":"2W Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_w3","name":"3W Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m0","name":"0M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m1","name":"1M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m2","name":"2M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m3","name":"3M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m4","name":"4M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m5","name":"5M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m6","name":"6M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m7","name":"7M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m8","name":"8M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m9","name":"9M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m10","name":"10M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m11","name":"11M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reattributions_per_user_m12","name":"12M Reattributions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d0","name":"0D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d1","name":"1D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d2","name":"2D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d3","name":"3D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d4","name":"4D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d5","name":"5D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d6","name":"6D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d7","name":"7D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d8","name":"8D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d14","name":"14D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d30","name":"30D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d31","name":"31D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d45","name":"45D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_d75","name":"75D Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_w0","name":"0W Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_w1","name":"1W Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_w2","name":"2W Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_w3","name":"3W Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m0","name":"0M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m1","name":"1M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m2","name":"2M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m3","name":"3M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m4","name":"4M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m5","name":"5M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m6","name":"6M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m7","name":"7M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m8","name":"8M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m9","name":"9M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m10","name":"10M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m11","name":"11M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"reinstalls_total_m12","name":"12M Reinstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d0","name":"0D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d1","name":"1D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d2","name":"2D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d3","name":"3D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d4","name":"4D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d5","name":"5D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d6","name":"6D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d7","name":"7D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d8","name":"8D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d14","name":"14D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d30","name":"30D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d31","name":"31D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d45","name":"45D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_d75","name":"75D Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_w0","name":"0W Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_w1","name":"1W Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_w2","name":"2W Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_w3","name":"3W Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m0","name":"0M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m1","name":"1M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m2","name":"2M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m3","name":"3M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m4","name":"4M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m5","name":"5M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m6","name":"6M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m7","name":"7M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m8","name":"8M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m9","name":"9M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m10","name":"10M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m11","name":"11M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retained_users_m12","name":"12M Retained Users","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"retention_rate_d0","name":"0D Retention Rate All Users","short_name":"0D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d1","name":"1D Retention Rate All Users","short_name":"1D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d2","name":"2D Retention Rate All Users","short_name":"2D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d3","name":"3D Retention Rate All Users","short_name":"3D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d4","name":"4D Retention Rate All Users","short_name":"4D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d5","name":"5D Retention Rate All Users","short_name":"5D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d6","name":"6D Retention Rate All Users","short_name":"6D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d7","name":"7D Retention Rate All Users","short_name":"7D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d8","name":"8D Retention Rate All Users","short_name":"8D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d14","name":"14D Retention Rate All Users","short_name":"14D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d30","name":"30D Retention Rate All Users","short_name":"30D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d31","name":"31D Retention Rate All Users","short_name":"31D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d45","name":"45D Retention Rate All Users","short_name":"45D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_d75","name":"75D Retention Rate All Users","short_name":"75D Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_w0","name":"0W Retention Rate All Users","short_name":"0W Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_w1","name":"1W Retention Rate All Users","short_name":"1W Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_w2","name":"2W Retention Rate All Users","short_name":"2W Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_w3","name":"3W Retention Rate All Users","short_name":"3W Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m0","name":"0M Retention Rate All Users","short_name":"0M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m1","name":"1M Retention Rate All Users","short_name":"1M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m2","name":"2M Retention Rate All Users","short_name":"2M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m3","name":"3M Retention Rate All Users","short_name":"3M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m4","name":"4M Retention Rate All Users","short_name":"4M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m5","name":"5M Retention Rate All Users","short_name":"5M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m6","name":"6M Retention Rate All Users","short_name":"6M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m7","name":"7M Retention Rate All Users","short_name":"7M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m8","name":"8M Retention Rate All Users","short_name":"8M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m9","name":"9M Retention Rate All Users","short_name":"9M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m10","name":"10M Retention Rate All Users","short_name":"10M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m11","name":"11M Retention Rate All Users","short_name":"11M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"retention_rate_m12","name":"12M Retention Rate All Users","short_name":"12M Retention","section":"Retention","formatting":"percent","increase_is_negative":false,"description":""},{"id":"revenue_d0","name":"0D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d1","name":"1D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d2","name":"2D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d3","name":"3D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d4","name":"4D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d5","name":"5D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d6","name":"6D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d7","name":"7D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d8","name":"8D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d14","name":"14D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d30","name":"30D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d31","name":"31D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d45","name":"45D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_d75","name":"75D Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_w0","name":"0W Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_w1","name":"1W Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_w2","name":"2W Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_w3","name":"3W Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m0","name":"0M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m1","name":"1M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m2","name":"2M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m3","name":"3M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m4","name":"4M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m5","name":"5M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m6","name":"6M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m7","name":"7M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m8","name":"8M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m9","name":"9M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m10","name":"10M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m11","name":"11M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_m12","name":"12M Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_events_d0","name":"0D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d1","name":"1D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d2","name":"2D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d3","name":"3D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d4","name":"4D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d5","name":"5D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d6","name":"6D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d7","name":"7D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d8","name":"8D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d14","name":"14D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d30","name":"30D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d31","name":"31D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d45","name":"45D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_d75","name":"75D Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_w0","name":"0W Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_w1","name":"1W Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_w2","name":"2W Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_w3","name":"3W Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m0","name":"0M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m1","name":"1M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m2","name":"2M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m3","name":"3M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m4","name":"4M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m5","name":"5M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m6","name":"6M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m7","name":"7M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m8","name":"8M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m9","name":"9M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m10","name":"10M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m11","name":"11M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_m12","name":"12M Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d0","name":"0D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d1","name":"1D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d2","name":"2D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d3","name":"3D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d4","name":"4D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d5","name":"5D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d6","name":"6D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d7","name":"7D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d8","name":"8D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d14","name":"14D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d30","name":"30D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d31","name":"31D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d45","name":"45D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_d75","name":"75D Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_w0","name":"0W Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_w1","name":"1W Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_w2","name":"2W Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_w3","name":"3W Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m0","name":"0M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m1","name":"1M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m2","name":"2M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m3","name":"3M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m4","name":"4M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m5","name":"5M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m6","name":"6M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m7","name":"7M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m8","name":"8M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m9","name":"9M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m10","name":"10M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m11","name":"11M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_active_user_m12","name":"12M Revenue Events Per Active User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d0","name":"0D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d1","name":"1D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d2","name":"2D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d3","name":"3D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d4","name":"4D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d5","name":"5D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d6","name":"6D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d7","name":"7D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d8","name":"8D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d14","name":"14D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d30","name":"30D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d31","name":"31D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d45","name":"45D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_d75","name":"75D Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_w0","name":"0W Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_w1","name":"1W Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_w2","name":"2W Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_w3","name":"3W Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m0","name":"0M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m1","name":"1M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m2","name":"2M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m3","name":"3M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m4","name":"4M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m5","name":"5M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m6","name":"6M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m7","name":"7M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m8","name":"8M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m9","name":"9M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m10","name":"10M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m11","name":"11M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_paying_user_m12","name":"12M Revenue Events Per Paying User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d0","name":"0D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d1","name":"1D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d2","name":"2D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d3","name":"3D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d4","name":"4D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d5","name":"5D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d6","name":"6D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d7","name":"7D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d8","name":"8D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d14","name":"14D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d30","name":"30D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d31","name":"31D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d45","name":"45D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_d75","name":"75D Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_w0","name":"0W Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_w1","name":"1W Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_w2","name":"2W Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_w3","name":"3W Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m0","name":"0M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m1","name":"1M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m2","name":"2M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m3","name":"3M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m4","name":"4M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m5","name":"5M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m6","name":"6M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m7","name":"7M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m8","name":"8M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m9","name":"9M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m10","name":"10M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m11","name":"11M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_per_user_m12","name":"12M Revenue Events Per User","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d0","name":"0D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d1","name":"1D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d2","name":"2D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d3","name":"3D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d4","name":"4D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d5","name":"5D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d6","name":"6D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d7","name":"7D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d8","name":"8D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d14","name":"14D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d30","name":"30D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d31","name":"31D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d45","name":"45D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_d75","name":"75D Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_w0","name":"0W Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_w1","name":"1W Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_w2","name":"2W Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_w3","name":"3W Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m0","name":"0M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m1","name":"1M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m2","name":"2M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m3","name":"3M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m4","name":"4M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m5","name":"5M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m6","name":"6M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m7","name":"7M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m8","name":"8M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m9","name":"9M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m10","name":"10M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m11","name":"11M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_m12","name":"12M Revenue Events Total","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d0","name":"0D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d1","name":"1D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d2","name":"2D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d3","name":"3D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d4","name":"4D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d5","name":"5D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d6","name":"6D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d7","name":"7D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d8","name":"8D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d14","name":"14D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d30","name":"30D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d31","name":"31D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d45","name":"45D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_d75","name":"75D Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_w0","name":"0W Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_w1","name":"1W Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_w2","name":"2W Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_w3","name":"3W Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m0","name":"0M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m1","name":"1M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m2","name":"2M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m3","name":"3M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m4","name":"4M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m5","name":"5M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m6","name":"6M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m7","name":"7M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m8","name":"8M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m9","name":"9M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m10","name":"10M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m11","name":"11M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_events_total_in_cohort_m12","name":"12M Revenue Events Total In Cohort","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d0","name":"0D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d1","name":"1D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d2","name":"2D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d3","name":"3D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d4","name":"4D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d5","name":"5D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d6","name":"6D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d7","name":"7D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d8","name":"8D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d14","name":"14D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d30","name":"30D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d31","name":"31D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d45","name":"45D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_d75","name":"75D Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_w0","name":"0W Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_w1","name":"1W Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_w2","name":"2W Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_w3","name":"3W Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m0","name":"0M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m1","name":"1M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m2","name":"2M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m3","name":"3M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m4","name":"4M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m5","name":"5M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m6","name":"6M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m7","name":"7M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m8","name":"8M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m9","name":"9M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m10","name":"10M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m11","name":"11M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_paying_user_m12","name":"12M Revenue Per Paying User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d0","name":"0D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d1","name":"1D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d2","name":"2D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d3","name":"3D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d4","name":"4D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d5","name":"5D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d6","name":"6D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d7","name":"7D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d8","name":"8D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d14","name":"14D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d30","name":"30D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d31","name":"31D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d45","name":"45D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_d75","name":"75D Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_w0","name":"0W Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_w1","name":"1W Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_w2","name":"2W Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_w3","name":"3W Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m0","name":"0M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m1","name":"1M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m2","name":"2M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m3","name":"3M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m4","name":"4M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m5","name":"5M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m6","name":"6M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m7","name":"7M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m8","name":"8M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m9","name":"9M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m10","name":"10M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m11","name":"11M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_per_user_m12","name":"12M Revenue Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d0","name":"0D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d1","name":"1D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d2","name":"2D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d3","name":"3D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d4","name":"4D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d5","name":"5D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d6","name":"6D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d7","name":"7D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d8","name":"8D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d14","name":"14D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d30","name":"30D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d31","name":"31D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d45","name":"45D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_d75","name":"75D Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_w0","name":"0W Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_w1","name":"1W Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_w2","name":"2W Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_w3","name":"3W Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m0","name":"0M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m1","name":"1M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m2","name":"2M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m3","name":"3M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m4","name":"4M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m5","name":"5M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m6","name":"6M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m7","name":"7M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m8","name":"8M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m9","name":"9M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m10","name":"10M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m11","name":"11M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_m12","name":"12M Revenue Total","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d0","name":"0D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d1","name":"1D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d2","name":"2D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d3","name":"3D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d4","name":"4D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d5","name":"5D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d6","name":"6D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d7","name":"7D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d8","name":"8D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d14","name":"14D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d30","name":"30D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d31","name":"31D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d45","name":"45D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_d75","name":"75D Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_w0","name":"0W Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_w1","name":"1W Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_w2","name":"2W Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_w3","name":"3W Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m0","name":"0M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m1","name":"1M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m2","name":"2M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m3","name":"3M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m4","name":"4M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m5","name":"5M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m6","name":"6M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m7","name":"7M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m8","name":"8M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m9","name":"9M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m10","name":"10M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m11","name":"11M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_in_cohort_m12","name":"12M Revenue Total In Cohort","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d0","name":"0D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d1","name":"1D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d2","name":"2D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d3","name":"3D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d4","name":"4D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d5","name":"5D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d6","name":"6D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d7","name":"7D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d8","name":"8D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d14","name":"14D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d30","name":"30D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d31","name":"31D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d45","name":"45D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_d75","name":"75D Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_w0","name":"0W Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_w1","name":"1W Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_w2","name":"2W Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_w3","name":"3W Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m0","name":"0M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m1","name":"1M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m2","name":"2M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m3","name":"3M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m4","name":"4M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m5","name":"5M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m6","name":"6M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m7","name":"7M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m8","name":"8M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m9","name":"9M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m10","name":"10M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m11","name":"11M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_total_per_user_m12","name":"12M Revenue Total Per User","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"roas_d0","name":"0D ROAS (All Revenue)","short_name":"0D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d1","name":"1D ROAS (All Revenue)","short_name":"1D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d2","name":"2D ROAS (All Revenue)","short_name":"2D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d3","name":"3D ROAS (All Revenue)","short_name":"3D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d4","name":"4D ROAS (All Revenue)","short_name":"4D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d5","name":"5D ROAS (All Revenue)","short_name":"5D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d6","name":"6D ROAS (All Revenue)","short_name":"6D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d7","name":"7D ROAS (All Revenue)","short_name":"7D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d8","name":"8D ROAS (All Revenue)","short_name":"8D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d14","name":"14D ROAS (All Revenue)","short_name":"14D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d30","name":"30D ROAS (All Revenue)","short_name":"30D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d31","name":"31D ROAS (All Revenue)","short_name":"31D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d45","name":"45D ROAS (All Revenue)","short_name":"45D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_d75","name":"75D ROAS (All Revenue)","short_name":"75D ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_w0","name":"0W ROAS (All Revenue)","short_name":"0W ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_w1","name":"1W ROAS (All Revenue)","short_name":"1W ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_w2","name":"2W ROAS (All Revenue)","short_name":"2W ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_w3","name":"3W ROAS (All Revenue)","short_name":"3W ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m0","name":"0M ROAS (All Revenue)","short_name":"0M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m1","name":"1M ROAS (All Revenue)","short_name":"1M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m2","name":"2M ROAS (All Revenue)","short_name":"2M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m3","name":"3M ROAS (All Revenue)","short_name":"3M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m4","name":"4M ROAS (All Revenue)","short_name":"4M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m5","name":"5M ROAS (All Revenue)","short_name":"5M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m6","name":"6M ROAS (All Revenue)","short_name":"6M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m7","name":"7M ROAS (All Revenue)","short_name":"7M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m8","name":"8M ROAS (All Revenue)","short_name":"8M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m9","name":"9M ROAS (All Revenue)","short_name":"9M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m10","name":"10M ROAS (All Revenue)","short_name":"10M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m11","name":"11M ROAS (All Revenue)","short_name":"11M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_m12","name":"12M ROAS (All Revenue)","short_name":"12M ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d0","name":"0D ROAS (Ad Revenue)","short_name":"0D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d1","name":"1D ROAS (Ad Revenue)","short_name":"1D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d2","name":"2D ROAS (Ad Revenue)","short_name":"2D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d3","name":"3D ROAS (Ad Revenue)","short_name":"3D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d4","name":"4D ROAS (Ad Revenue)","short_name":"4D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d5","name":"5D ROAS (Ad Revenue)","short_name":"5D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d6","name":"6D ROAS (Ad Revenue)","short_name":"6D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d7","name":"7D ROAS (Ad Revenue)","short_name":"7D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d8","name":"8D ROAS (Ad Revenue)","short_name":"8D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d14","name":"14D ROAS (Ad Revenue)","short_name":"14D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d30","name":"30D ROAS (Ad Revenue)","short_name":"30D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d31","name":"31D ROAS (Ad Revenue)","short_name":"31D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d45","name":"45D ROAS (Ad Revenue)","short_name":"45D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_d75","name":"75D ROAS (Ad Revenue)","short_name":"75D ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_w0","name":"0W ROAS (Ad Revenue)","short_name":"0W ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_w1","name":"1W ROAS (Ad Revenue)","short_name":"1W ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_w2","name":"2W ROAS (Ad Revenue)","short_name":"2W ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_w3","name":"3W ROAS (Ad Revenue)","short_name":"3W ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m0","name":"0M ROAS (Ad Revenue)","short_name":"0M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m1","name":"1M ROAS (Ad Revenue)","short_name":"1M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m2","name":"2M ROAS (Ad Revenue)","short_name":"2M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m3","name":"3M ROAS (Ad Revenue)","short_name":"3M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m4","name":"4M ROAS (Ad Revenue)","short_name":"4M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m5","name":"5M ROAS (Ad Revenue)","short_name":"5M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m6","name":"6M ROAS (Ad Revenue)","short_name":"6M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m7","name":"7M ROAS (Ad Revenue)","short_name":"7M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m8","name":"8M ROAS (Ad Revenue)","short_name":"8M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m9","name":"9M ROAS (Ad Revenue)","short_name":"9M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m10","name":"10M ROAS (Ad Revenue)","short_name":"10M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m11","name":"11M ROAS (Ad Revenue)","short_name":"11M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad_m12","name":"12M ROAS (Ad Revenue)","short_name":"12M ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d0","name":"0D ROAS (IAP Revenue)","short_name":"0D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d1","name":"1D ROAS (IAP Revenue)","short_name":"1D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d2","name":"2D ROAS (IAP Revenue)","short_name":"2D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d3","name":"3D ROAS (IAP Revenue)","short_name":"3D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d4","name":"4D ROAS (IAP Revenue)","short_name":"4D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d5","name":"5D ROAS (IAP Revenue)","short_name":"5D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d6","name":"6D ROAS (IAP Revenue)","short_name":"6D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d7","name":"7D ROAS (IAP Revenue)","short_name":"7D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d8","name":"8D ROAS (IAP Revenue)","short_name":"8D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d14","name":"14D ROAS (IAP Revenue)","short_name":"14D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d30","name":"30D ROAS (IAP Revenue)","short_name":"30D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d31","name":"31D ROAS (IAP Revenue)","short_name":"31D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d45","name":"45D ROAS (IAP Revenue)","short_name":"45D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_d75","name":"75D ROAS (IAP Revenue)","short_name":"75D ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_w0","name":"0W ROAS (IAP Revenue)","short_name":"0W ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_w1","name":"1W ROAS (IAP Revenue)","short_name":"1W ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_w2","name":"2W ROAS (IAP Revenue)","short_name":"2W ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_w3","name":"3W ROAS (IAP Revenue)","short_name":"3W ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m0","name":"0M ROAS (IAP Revenue)","short_name":"0M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m1","name":"1M ROAS (IAP Revenue)","short_name":"1M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m2","name":"2M ROAS (IAP Revenue)","short_name":"2M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m3","name":"3M ROAS (IAP Revenue)","short_name":"3M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m4","name":"4M ROAS (IAP Revenue)","short_name":"4M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m5","name":"5M ROAS (IAP Revenue)","short_name":"5M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m6","name":"6M ROAS (IAP Revenue)","short_name":"6M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m7","name":"7M ROAS (IAP Revenue)","short_name":"7M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m8","name":"8M ROAS (IAP Revenue)","short_name":"8M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m9","name":"9M ROAS (IAP Revenue)","short_name":"9M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m10","name":"10M ROAS (IAP Revenue)","short_name":"10M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m11","name":"11M ROAS (IAP Revenue)","short_name":"11M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap_m12","name":"12M ROAS (IAP Revenue)","short_name":"12M ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"sessions_d0","name":"0D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d1","name":"1D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d2","name":"2D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d3","name":"3D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d4","name":"4D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d5","name":"5D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d6","name":"6D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d7","name":"7D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d8","name":"8D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d14","name":"14D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d30","name":"30D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d31","name":"31D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d45","name":"45D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_d75","name":"75D Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_w0","name":"0W Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_w1","name":"1W Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_w2","name":"2W Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_w3","name":"3W Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m0","name":"0M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m1","name":"1M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m2","name":"2M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m3","name":"3M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m4","name":"4M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m5","name":"5M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m6","name":"6M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m7","name":"7M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m8","name":"8M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m9","name":"9M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m10","name":"10M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m11","name":"11M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_m12","name":"12M Sessions","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d0","name":"0D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d1","name":"1D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d2","name":"2D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d3","name":"3D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d4","name":"4D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d5","name":"5D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d6","name":"6D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d7","name":"7D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d8","name":"8D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d14","name":"14D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d30","name":"30D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d31","name":"31D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d45","name":"45D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_d75","name":"75D Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_w0","name":"0W Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_w1","name":"1W Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_w2","name":"2W Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_w3","name":"3W Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m0","name":"0M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m1","name":"1M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m2","name":"2M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m3","name":"3M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m4","name":"4M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m5","name":"5M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m6","name":"6M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m7","name":"7M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m8","name":"8M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m9","name":"9M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m10","name":"10M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m11","name":"11M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions_per_user_m12","name":"12M Sessions Per User","short_name":"","section":"Retention","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"time_spent_d0","name":"0D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d1","name":"1D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d2","name":"2D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d3","name":"3D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d4","name":"4D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d5","name":"5D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d6","name":"6D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d7","name":"7D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d8","name":"8D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d14","name":"14D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d30","name":"30D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d31","name":"31D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d45","name":"45D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_d75","name":"75D Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_w0","name":"0W Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_w1","name":"1W Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_w2","name":"2W Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_w3","name":"3W Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m0","name":"0M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m1","name":"1M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m2","name":"2M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m3","name":"3M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m4","name":"4M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m5","name":"5M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m6","name":"6M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m7","name":"7M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m8","name":"8M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m9","name":"9M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m10","name":"10M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m11","name":"11M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_m12","name":"12M Time Spent","short_name":"","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d0","name":"0D Time Spent Per Active User","short_name":"0D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d1","name":"1D Time Spent Per Active User","short_name":"1D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d2","name":"2D Time Spent Per Active User","short_name":"2D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d3","name":"3D Time Spent Per Active User","short_name":"3D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d4","name":"4D Time Spent Per Active User","short_name":"4D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d5","name":"5D Time Spent Per Active User","short_name":"5D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d6","name":"6D Time Spent Per Active User","short_name":"6D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d7","name":"7D Time Spent Per Active User","short_name":"7D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d8","name":"8D Time Spent Per Active User","short_name":"8D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d14","name":"14D Time Spent Per Active User","short_name":"14D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d30","name":"30D Time Spent Per Active User","short_name":"30D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d31","name":"31D Time Spent Per Active User","short_name":"31D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d45","name":"45D Time Spent Per Active User","short_name":"45D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_d75","name":"75D Time Spent Per Active User","short_name":"75D TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_w0","name":"0W Time Spent Per Active User","short_name":"0W TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_w1","name":"1W Time Spent Per Active User","short_name":"1W TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_w2","name":"2W Time Spent Per Active User","short_name":"2W TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_w3","name":"3W Time Spent Per Active User","short_name":"3W TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m0","name":"0M Time Spent Per Active User","short_name":"0M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m1","name":"1M Time Spent Per Active User","short_name":"1M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m2","name":"2M Time Spent Per Active User","short_name":"2M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m3","name":"3M Time Spent Per Active User","short_name":"3M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m4","name":"4M Time Spent Per Active User","short_name":"4M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m5","name":"5M Time Spent Per Active User","short_name":"5M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m6","name":"6M Time Spent Per Active User","short_name":"6M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m7","name":"7M Time Spent Per Active User","short_name":"7M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m8","name":"8M Time Spent Per Active User","short_name":"8M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m9","name":"9M Time Spent Per Active User","short_name":"9M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m10","name":"10M Time Spent Per Active User","short_name":"10M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m11","name":"11M Time Spent Per Active User","short_name":"11M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_active_user_m12","name":"12M Time Spent Per Active User","short_name":"12M TSPAU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d0","name":"0D Time Spent Per Session","short_name":"0D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d1","name":"1D Time Spent Per Session","short_name":"1D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d2","name":"2D Time Spent Per Session","short_name":"2D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d3","name":"3D Time Spent Per Session","short_name":"3D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d4","name":"4D Time Spent Per Session","short_name":"4D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d5","name":"5D Time Spent Per Session","short_name":"5D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d6","name":"6D Time Spent Per Session","short_name":"6D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d7","name":"7D Time Spent Per Session","short_name":"7D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d8","name":"8D Time Spent Per Session","short_name":"8D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d14","name":"14D Time Spent Per Session","short_name":"14D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d30","name":"30D Time Spent Per Session","short_name":"30D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d31","name":"31D Time Spent Per Session","short_name":"31D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d45","name":"45D Time Spent Per Session","short_name":"45D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_d75","name":"75D Time Spent Per Session","short_name":"75D TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_w0","name":"0W Time Spent Per Session","short_name":"0W TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_w1","name":"1W Time Spent Per Session","short_name":"1W TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_w2","name":"2W Time Spent Per Session","short_name":"2W TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_w3","name":"3W Time Spent Per Session","short_name":"3W TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m0","name":"0M Time Spent Per Session","short_name":"0M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m1","name":"1M Time Spent Per Session","short_name":"1M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m2","name":"2M Time Spent Per Session","short_name":"2M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m3","name":"3M Time Spent Per Session","short_name":"3M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m4","name":"4M Time Spent Per Session","short_name":"4M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m5","name":"5M Time Spent Per Session","short_name":"5M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m6","name":"6M Time Spent Per Session","short_name":"6M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m7","name":"7M Time Spent Per Session","short_name":"7M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m8","name":"8M Time Spent Per Session","short_name":"8M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m9","name":"9M Time Spent Per Session","short_name":"9M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m10","name":"10M Time Spent Per Session","short_name":"10M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m11","name":"11M Time Spent Per Session","short_name":"11M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_session_m12","name":"12M Time Spent Per Session","short_name":"12M TSPS","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d0","name":"0D Time Spent Per User","short_name":"0D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d1","name":"1D Time Spent Per User","short_name":"1D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d2","name":"2D Time Spent Per User","short_name":"2D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d3","name":"3D Time Spent Per User","short_name":"3D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d4","name":"4D Time Spent Per User","short_name":"4D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d5","name":"5D Time Spent Per User","short_name":"5D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d6","name":"6D Time Spent Per User","short_name":"6D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d7","name":"7D Time Spent Per User","short_name":"7D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d8","name":"8D Time Spent Per User","short_name":"8D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d14","name":"14D Time Spent Per User","short_name":"14D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d30","name":"30D Time Spent Per User","short_name":"30D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d31","name":"31D Time Spent Per User","short_name":"31D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d45","name":"45D Time Spent Per User","short_name":"45D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_d75","name":"75D Time Spent Per User","short_name":"75D TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_w0","name":"0W Time Spent Per User","short_name":"0W TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_w1","name":"1W Time Spent Per User","short_name":"1W TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_w2","name":"2W Time Spent Per User","short_name":"2W TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_w3","name":"3W Time Spent Per User","short_name":"3W TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m0","name":"0M Time Spent Per User","short_name":"0M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m1","name":"1M Time Spent Per User","short_name":"1M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m2","name":"2M Time Spent Per User","short_name":"2M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m3","name":"3M Time Spent Per User","short_name":"3M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m4","name":"4M Time Spent Per User","short_name":"4M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m5","name":"5M Time Spent Per User","short_name":"5M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m6","name":"6M Time Spent Per User","short_name":"6M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m7","name":"7M Time Spent Per User","short_name":"7M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m8","name":"8M Time Spent Per User","short_name":"8M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m9","name":"9M Time Spent Per User","short_name":"9M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m10","name":"10M Time Spent Per User","short_name":"10M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m11","name":"11M Time Spent Per User","short_name":"11M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"time_spent_per_user_m12","name":"12M Time Spent Per User","short_name":"12M TSPU","section":"Retention","formatting":"timeperiod","increase_is_negative":false,"description":""},{"id":"uninstalls_total_d0","name":"0D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d1","name":"1D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d2","name":"2D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d3","name":"3D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d4","name":"4D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d5","name":"5D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d6","name":"6D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d7","name":"7D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d8","name":"8D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d14","name":"14D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d30","name":"30D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d31","name":"31D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d45","name":"45D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_d75","name":"75D Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_w0","name":"0W Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_w1","name":"1W Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_w2","name":"2W Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_w3","name":"3W Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m0","name":"0M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m1","name":"1M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m2","name":"2M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m3","name":"3M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m4","name":"4M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m5","name":"5M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m6","name":"6M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m7","name":"7M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m8","name":"8M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m9","name":"9M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m10","name":"10M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m11","name":"11M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""},{"id":"uninstalls_total_m12","name":"12M Uninstalls Total","short_name":"","section":"Retention","formatting":"integer","increase_is_negative":true,"description":""}],"event_metrics":[{"id":"7d_reward_2600_events","formatting":"integer","short_name":"","name":"7d_Reward_2600","section":"Events"},{"id":"7d_reward_2600_revenue","formatting":"money","short_name":"","name":"7d_Reward_2600 (Revenue)","section":"Events"},{"id":"active_events","formatting":"integer","short_name":"","name":"active","section":"Events"},{"id":"active_revenue","formatting":"money","short_name":"","name":"active (Revenue)","section":"Events"},{"id":"ad_click_events","formatting":"integer","short_name":"","name":"ad_click","section":"Events"},{"id":"ad_click_revenue","formatting":"money","short_name":"","name":"ad_click (Revenue)","section":"Events"},{"id":"ad_show_events","formatting":"integer","short_name":"","name":"ad_show","section":"Events"},{"id":"ad_show_revenue","formatting":"money","short_name":"","name":"ad_show (Revenue)","section":"Events"},{"id":"adaction_events","formatting":"integer","short_name":"","name":"adaction","section":"Events"},{"id":"adaction_revenue","formatting":"money","short_name":"","name":"adaction (Revenue)","section":"Events"},{"id":"adclick_events","formatting":"integer","short_name":"","name":"adclick","section":"Events"},{"id":"adclick_revenue","formatting":"money","short_name":"","name":"adclick (Revenue)","section":"Events"},{"id":"adrevenue_events","formatting":"integer","short_name":"","name":"adrevenue","section":"Events"},{"id":"adrevenue_revenue","formatting":"money","short_name":"","name":"adrevenue (Revenue)","section":"Events"},{"id":"adshow_events","formatting":"integer","short_name":"","name":"adshow","section":"Events"},{"id":"adshow_revenue","formatting":"money","short_name":"","name":"adshow (Revenue)","section":"Events"},{"id":"adv_events","formatting":"integer","short_name":"","name":"adv","section":"Events"},{"id":"adv_revenue","formatting":"money","short_name":"","name":"adv (Revenue)","section":"Events"},{"id":"analytics_events","formatting":"integer","short_name":"","name":"analytics","section":"Events"},{"id":"analytics_revenue","formatting":"money","short_name":"","name":"analytics (Revenue)","section":"Events"},{"id":"buyrevenue_events","formatting":"integer","short_name":"","name":"buyrevenue","section":"Events"},{"id":"buyrevenue_revenue","formatting":"money","short_name":"","name":"buyrevenue (Revenue)","section":"Events"},{"id":"connect_vpn_events","formatting":"integer","short_name":"","name":"connect_vpn","section":"Events"},{"id":"connect_vpn_revenue","formatting":"money","short_name":"","name":"connect_vpn (Revenue)","section":"Events"},{"id":"enter_10_events","formatting":"integer","short_name":"","name":"enter_10","section":"Events"},{"id":"enter_10_revenue","formatting":"money","short_name":"","name":"enter_10 (Revenue)","section":"Events"},{"id":"enter_100_events","formatting":"integer","short_name":"","name":"enter_100","section":"Events"},{"id":"enter_100_revenue","formatting":"money","short_name":"","name":"enter_100 (Revenue)","section":"Events"},{"id":"enter_15_events","formatting":"integer","short_name":"","name":"enter_15","section":"Events"},{"id":"enter_15_revenue","formatting":"money","short_name":"","name":"enter_15 (Revenue)","section":"Events"},{"id":"enter_20_events","formatting":"integer","short_name":"","name":"enter_20","section":"Events"},{"id":"enter_20_revenue","formatting":"money","short_name":"","name":"enter_20 (Revenue)","section":"Events"},{"id":"enter_30_events","formatting":"integer","short_name":"","name":"enter_30","section":"Events"},{"id":"enter_30_revenue","formatting":"money","short_name":"","name":"enter_30 (Revenue)","section":"Events"},{"id":"enter_40_events","formatting":"integer","short_name":"","name":"enter_40","section":"Events"},{"id":"enter_40_revenue","formatting":"money","short_name":"","name":"enter_40 (Revenue)","section":"Events"},{"id":"enter_50_events","formatting":"integer","short_name":"","name":"enter_50","section":"Events"},{"id":"enter_50_revenue","formatting":"money","short_name":"","name":"enter_50 (Revenue)","section":"Events"},{"id":"enter_60_events","formatting":"integer","short_name":"","name":"enter_60","section":"Events"},{"id":"enter_60_revenue","formatting":"money","short_name":"","name":"enter_60 (Revenue)","section":"Events"},{"id":"enter_70_events","formatting":"integer","short_name":"","name":"enter_70","section":"Events"},{"id":"enter_70_revenue","formatting":"money","short_name":"","name":"enter_70 (Revenue)","section":"Events"},{"id":"enter_80_events","formatting":"integer","short_name":"","name":"enter_80","section":"Events"},{"id":"enter_80_revenue","formatting":"money","short_name":"","name":"enter_80 (Revenue)","section":"Events"},{"id":"enter_90_events","formatting":"integer","short_name":"","name":"enter_90","section":"Events"},{"id":"enter_90_revenue","formatting":"money","short_name":"","name":"enter_90 (Revenue)","section":"Events"},{"id":"event_install_events","formatting":"integer","short_name":"","name":"EVENT_INSTALL","section":"Events"},{"id":"event_install_revenue","formatting":"money","short_name":"","name":"EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_launch_app_events","formatting":"integer","short_name":"","name":"EVENT_LAUNCH_APP","section":"Events"},{"id":"event_launch_app_revenue","formatting":"money","short_name":"","name":"EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"finditems_enter_10_events","formatting":"integer","short_name":"","name":"FindItems_enter_10","section":"Events"},{"id":"finditems_enter_10_revenue","formatting":"money","short_name":"","name":"FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_20_events","formatting":"integer","short_name":"","name":"FindItems_enter_20","section":"Events"},{"id":"finditems_enter_20_revenue","formatting":"money","short_name":"","name":"FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_30_events","formatting":"integer","short_name":"","name":"FindItems_enter_30","section":"Events"},{"id":"finditems_enter_30_revenue","formatting":"money","short_name":"","name":"FindItems_enter_30 (Revenue)","section":"Events"},{"id":"general revenue_events","formatting":"integer","short_name":"","name":"General Revenue","section":"Events"},{"id":"general revenue_revenue","formatting":"money","short_name":"","name":"General Revenue (Revenue)","section":"Events"},{"id":"get_normal_time_events","formatting":"integer","short_name":"","name":"get_normal_time","section":"Events"},{"id":"get_normal_time_revenue","formatting":"money","short_name":"","name":"get_normal_time (Revenue)","section":"Events"},{"id":"get_reward_time_events","formatting":"integer","short_name":"","name":"get_reward_time","section":"Events"},{"id":"get_reward_time_revenue","formatting":"money","short_name":"","name":"get_reward_time (Revenue)","section":"Events"},{"id":"get_video_time_events","formatting":"integer","short_name":"","name":"get_video_time","section":"Events"},{"id":"get_video_time_revenue","formatting":"money","short_name":"","name":"get_video_time (Revenue)","section":"Events"},{"id":"iaa_revenue_events","formatting":"integer","short_name":"","name":"iaa_revenue","section":"Events"},{"id":"iaa_revenue_revenue","formatting":"money","short_name":"","name":"iaa_revenue (Revenue)","section":"Events"},{"id":"iap_events","formatting":"integer","short_name":"","name":"IAP","section":"Events"},{"id":"iap_revenue","formatting":"money","short_name":"","name":"IAP (Revenue)","section":"Events"},{"id":"interstital_ad_click_events","formatting":"integer","short_name":"","name":"interstital_ad_click","section":"Events"},{"id":"interstital_ad_click_revenue","formatting":"money","short_name":"","name":"interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_show_events","formatting":"integer","short_name":"","name":"interstital_ad_show","section":"Events"},{"id":"interstital_ad_show_revenue","formatting":"money","short_name":"","name":"interstital_ad_show (Revenue)","section":"Events"},{"id":"level_10_events","formatting":"integer","short_name":"","name":"level_10","section":"Events"},{"id":"level_10_revenue","formatting":"money","short_name":"","name":"level_10 (Revenue)","section":"Events"},{"id":"level_100_events","formatting":"integer","short_name":"","name":"level_100","section":"Events"},{"id":"level_100_revenue","formatting":"money","short_name":"","name":"level_100 (Revenue)","section":"Events"},{"id":"level_1000_events","formatting":"integer","short_name":"","name":"level_1000","section":"Events"},{"id":"level_1000_revenue","formatting":"money","short_name":"","name":"level_1000 (Revenue)","section":"Events"},{"id":"level_10000_events","formatting":"integer","short_name":"","name":"level_10000","section":"Events"},{"id":"level_10000_revenue","formatting":"money","short_name":"","name":"level_10000 (Revenue)","section":"Events"},{"id":"level_15_events","formatting":"integer","short_name":"","name":"level_15","section":"Events"},{"id":"level_15_revenue","formatting":"money","short_name":"","name":"level_15 (Revenue)","section":"Events"},{"id":"level_20_events","formatting":"integer","short_name":"","name":"level_20","section":"Events"},{"id":"level_20_revenue","formatting":"money","short_name":"","name":"level_20 (Revenue)","section":"Events"},{"id":"level_200_events","formatting":"integer","short_name":"","name":"level_200","section":"Events"},{"id":"level_200_revenue","formatting":"money","short_name":"","name":"level_200 (Revenue)","section":"Events"},{"id":"level_30_events","formatting":"integer","short_name":"","name":"level_30","section":"Events"},{"id":"level_30_revenue","formatting":"money","short_name":"","name":"level_30 (Revenue)","section":"Events"},{"id":"level_300_events","formatting":"integer","short_name":"","name":"level_300","section":"Events"},{"id":"level_300_revenue","formatting":"money","short_name":"","name":"level_300 (Revenue)","section":"Events"},{"id":"level_3000_events","formatting":"integer","short_name":"","name":"level_3000","section":"Events"},{"id":"level_3000_revenue","formatting":"money","short_name":"","name":"level_3000 (Revenue)","section":"Events"},{"id":"level_400_events","formatting":"integer","short_name":"","name":"level_400","section":"Events"},{"id":"level_400_revenue","formatting":"money","short_name":"","name":"level_400 (Revenue)","section":"Events"},{"id":"level_5_events","formatting":"integer","short_name":"","name":"level_5","section":"Events"},{"id":"level_5_revenue","formatting":"money","short_name":"","name":"level_5 (Revenue)","section":"Events"},{"id":"level_50_events","formatting":"integer","short_name":"","name":"level_50","section":"Events"},{"id":"level_50_revenue","formatting":"money","short_name":"","name":"level_50 (Revenue)","section":"Events"},{"id":"level_500_events","formatting":"integer","short_name":"","name":"level_500","section":"Events"},{"id":"level_500_revenue","formatting":"money","short_name":"","name":"level_500 (Revenue)","section":"Events"},{"id":"level_5000_events","formatting":"integer","short_name":"","name":"level_5000","section":"Events"},{"id":"level_5000_revenue","formatting":"money","short_name":"","name":"level_5000 (Revenue)","section":"Events"},{"id":"level_600_events","formatting":"integer","short_name":"","name":"level_600","section":"Events"},{"id":"level_600_revenue","formatting":"money","short_name":"","name":"level_600 (Revenue)","section":"Events"},{"id":"main2_enter_10_events","formatting":"integer","short_name":"","name":"Main2_enter_10","section":"Events"},{"id":"main2_enter_10_revenue","formatting":"money","short_name":"","name":"Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_20_events","formatting":"integer","short_name":"","name":"Main2_enter_20","section":"Events"},{"id":"main2_enter_20_revenue","formatting":"money","short_name":"","name":"Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_30_events","formatting":"integer","short_name":"","name":"Main2_enter_30","section":"Events"},{"id":"main2_enter_30_revenue","formatting":"money","short_name":"","name":"Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_40_events","formatting":"integer","short_name":"","name":"Main2_enter_40","section":"Events"},{"id":"main2_enter_40_revenue","formatting":"money","short_name":"","name":"Main2_enter_40 (Revenue)","section":"Events"},{"id":"main3_enter_10_events","formatting":"integer","short_name":"","name":"Main3_enter_10","section":"Events"},{"id":"main3_enter_10_revenue","formatting":"money","short_name":"","name":"Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_20_events","formatting":"integer","short_name":"","name":"Main3_enter_20","section":"Events"},{"id":"main3_enter_20_revenue","formatting":"money","short_name":"","name":"Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_30_events","formatting":"integer","short_name":"","name":"Main3_enter_30","section":"Events"},{"id":"main3_enter_30_revenue","formatting":"money","short_name":"","name":"Main3_enter_30 (Revenue)","section":"Events"},{"id":"purchase_flow_events","formatting":"integer","short_name":"","name":"purchase_flow","section":"Events"},{"id":"purchase_flow_revenue","formatting":"money","short_name":"","name":"purchase_flow (Revenue)","section":"Events"},{"id":"purchase_perky_events","formatting":"integer","short_name":"","name":"Purchase_Perky","section":"Events"},{"id":"purchase_perky_revenue","formatting":"money","short_name":"","name":"Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_simple_events","formatting":"integer","short_name":"","name":"Purchase_Simple","section":"Events"},{"id":"purchase_simple_revenue","formatting":"money","short_name":"","name":"Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_events","formatting":"integer","short_name":"","name":"Purchase_vip_quarterly","section":"Events"},{"id":"purchase_vip_quarterly_revenue","formatting":"money","short_name":"","name":"Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"resultpage_events","formatting":"integer","short_name":"","name":"resultpage","section":"Events"},{"id":"resultpage_revenue","formatting":"money","short_name":"","name":"resultpage (Revenue)","section":"Events"},{"id":"showprice_events","formatting":"integer","short_name":"","name":"showprice","section":"Events"},{"id":"showprice_revenue","formatting":"money","short_name":"","name":"showprice (Revenue)","section":"Events"},{"id":"subrevenue_events","formatting":"integer","short_name":"","name":"subrevenue","section":"Events"},{"id":"subrevenue_revenue","formatting":"money","short_name":"","name":"subrevenue (Revenue)","section":"Events"},{"id":"subscribe_events","formatting":"integer","short_name":"","name":"subscribe","section":"Events"},{"id":"subscribe_revenue","formatting":"money","short_name":"","name":"subscribe (Revenue)","section":"Events"},{"id":"uac_export_success_1_events","formatting":"integer","short_name":"","name":"uac_export_success_1","section":"Events"},{"id":"uac_export_success_1_revenue","formatting":"money","short_name":"","name":"uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_preview_2_events","formatting":"integer","short_name":"","name":"uac_preview_2","section":"Events"},{"id":"uac_preview_2_revenue","formatting":"money","short_name":"","name":"uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_3_events","formatting":"integer","short_name":"","name":"uac_preview_3","section":"Events"},{"id":"uac_preview_3_revenue","formatting":"money","short_name":"","name":"uac_preview_3 (Revenue)","section":"Events"},{"id":"uacprice_events","formatting":"integer","short_name":"","name":"uacprice","section":"Events"},{"id":"uacprice_revenue","formatting":"money","short_name":"","name":"uacprice (Revenue)","section":"Events"},{"id":"uacresultpage_events","formatting":"integer","short_name":"","name":"uacResultPage","section":"Events"},{"id":"uacresultpage_revenue","formatting":"money","short_name":"","name":"uacResultPage (Revenue)","section":"Events"},{"id":"vip_click_events","formatting":"integer","short_name":"","name":"vip_click","section":"Events"},{"id":"vip_click_revenue","formatting":"money","short_name":"","name":"vip_click (Revenue)","section":"Events"},{"id":"vip_click_event_events","formatting":"integer","short_name":"","name":"vip_click_event","section":"Events"},{"id":"vip_click_event_revenue","formatting":"money","short_name":"","name":"vip_click_event (Revenue)","section":"Events"},{"id":"vip_event_events","formatting":"integer","short_name":"","name":"vip_event","section":"Events"},{"id":"vip_event_revenue","formatting":"money","short_name":"","name":"vip_event (Revenue)","section":"Events"},{"id":"vip_show_events","formatting":"integer","short_name":"","name":"vip_show","section":"Events"},{"id":"vip_show_revenue","formatting":"money","short_name":"","name":"vip_show (Revenue)","section":"Events"},{"id":"vip_show_event_events","formatting":"integer","short_name":"","name":"vip_show_event","section":"Events"},{"id":"vip_show_event_revenue","formatting":"money","short_name":"","name":"vip_show_event (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_events","formatting":"integer","short_name":"","name":"Waterpipe_enter_10","section":"Events"},{"id":"waterpipe_enter_10_revenue","formatting":"money","short_name":"","name":"Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_events","formatting":"integer","short_name":"","name":"Waterpipe_enter_20","section":"Events"},{"id":"waterpipe_enter_20_revenue","formatting":"money","short_name":"","name":"Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"7d_reward_2600_d0_events_cohort","formatting":"integer","short_name":"","name":"0D 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_d0_events_cohort","formatting":"integer","short_name":"","name":"0D active (Events)","section":"Events"},{"id":"active_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D active (Revenue)","section":"Events"},{"id":"active_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D active Events per Conversion","section":"Events"},{"id":"active_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D active Revenue per Conversion","section":"Events"},{"id":"active_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D active (Conversions)","section":"Events"},{"id":"active_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D active (Conversion Distribution)","section":"Events"},{"id":"active_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per active (Events)","section":"Events"},{"id":"active_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D active (Converted User Size)","section":"Events"},{"id":"active_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per active (Conversions)","section":"Events"},{"id":"active_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D active Rate (Events)","section":"Events"},{"id":"active_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D active Rate (Conversions)","section":"Events"},{"id":"ad_click_d0_events_cohort","formatting":"integer","short_name":"","name":"0D ad_click (Events)","section":"Events"},{"id":"ad_click_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D ad_click (Revenue)","section":"Events"},{"id":"ad_click_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D ad_click Events per Conversion","section":"Events"},{"id":"ad_click_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D ad_click (Conversions)","section":"Events"},{"id":"ad_click_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D ad_click Rate (Events)","section":"Events"},{"id":"ad_click_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_d0_events_cohort","formatting":"integer","short_name":"","name":"0D ad_show (Events)","section":"Events"},{"id":"ad_show_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D ad_show (Revenue)","section":"Events"},{"id":"ad_show_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D ad_show Events per Conversion","section":"Events"},{"id":"ad_show_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D ad_show (Conversions)","section":"Events"},{"id":"ad_show_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D ad_show Rate (Events)","section":"Events"},{"id":"ad_show_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_d0_events_cohort","formatting":"integer","short_name":"","name":"0D adaction (Events)","section":"Events"},{"id":"adaction_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D adaction (Revenue)","section":"Events"},{"id":"adaction_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D adaction Events per Conversion","section":"Events"},{"id":"adaction_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D adaction Revenue per Conversion","section":"Events"},{"id":"adaction_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D adaction (Conversions)","section":"Events"},{"id":"adaction_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adaction (Events)","section":"Events"},{"id":"adaction_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D adaction (Converted User Size)","section":"Events"},{"id":"adaction_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D adaction Rate (Events)","section":"Events"},{"id":"adaction_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D adaction Rate (Conversions)","section":"Events"},{"id":"adclick_d0_events_cohort","formatting":"integer","short_name":"","name":"0D adclick (Events)","section":"Events"},{"id":"adclick_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D adclick (Revenue)","section":"Events"},{"id":"adclick_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D adclick Events per Conversion","section":"Events"},{"id":"adclick_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D adclick Revenue per Conversion","section":"Events"},{"id":"adclick_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D adclick (Conversions)","section":"Events"},{"id":"adclick_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adclick (Events)","section":"Events"},{"id":"adclick_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D adclick (Converted User Size)","section":"Events"},{"id":"adclick_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D adclick Rate (Events)","section":"Events"},{"id":"adclick_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_d0_events_cohort","formatting":"integer","short_name":"","name":"0D adrevenue (Events)","section":"Events"},{"id":"adrevenue_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_d0_events_cohort","formatting":"integer","short_name":"","name":"0D adshow (Events)","section":"Events"},{"id":"adshow_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D adshow (Revenue)","section":"Events"},{"id":"adshow_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D adshow Events per Conversion","section":"Events"},{"id":"adshow_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D adshow Revenue per Conversion","section":"Events"},{"id":"adshow_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D adshow (Conversions)","section":"Events"},{"id":"adshow_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adshow (Events)","section":"Events"},{"id":"adshow_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D adshow (Converted User Size)","section":"Events"},{"id":"adshow_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D adshow Rate (Events)","section":"Events"},{"id":"adshow_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D adshow Rate (Conversions)","section":"Events"},{"id":"adv_d0_events_cohort","formatting":"integer","short_name":"","name":"0D adv (Events)","section":"Events"},{"id":"adv_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D adv (Revenue)","section":"Events"},{"id":"adv_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D adv Events per Conversion","section":"Events"},{"id":"adv_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D adv Revenue per Conversion","section":"Events"},{"id":"adv_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D adv (Conversions)","section":"Events"},{"id":"adv_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D adv (Conversion Distribution)","section":"Events"},{"id":"adv_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adv (Events)","section":"Events"},{"id":"adv_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D adv (Converted User Size)","section":"Events"},{"id":"adv_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per adv (Conversions)","section":"Events"},{"id":"adv_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D adv Rate (Events)","section":"Events"},{"id":"adv_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D adv Rate (Conversions)","section":"Events"},{"id":"analytics_d0_events_cohort","formatting":"integer","short_name":"","name":"0D analytics (Events)","section":"Events"},{"id":"analytics_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D analytics (Revenue)","section":"Events"},{"id":"analytics_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D analytics Events per Conversion","section":"Events"},{"id":"analytics_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D analytics Revenue per Conversion","section":"Events"},{"id":"analytics_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D analytics (Conversions)","section":"Events"},{"id":"analytics_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per analytics (Events)","section":"Events"},{"id":"analytics_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D analytics (Converted User Size)","section":"Events"},{"id":"analytics_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D analytics Rate (Events)","section":"Events"},{"id":"analytics_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_d0_events_cohort","formatting":"integer","short_name":"","name":"0D buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_d0_events_cohort","formatting":"integer","short_name":"","name":"0D connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_10 (Events)","section":"Events"},{"id":"enter_10_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_10 (Revenue)","section":"Events"},{"id":"enter_10_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_100 (Events)","section":"Events"},{"id":"enter_100_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_100 (Revenue)","section":"Events"},{"id":"enter_100_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_15 (Events)","section":"Events"},{"id":"enter_15_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_15 (Revenue)","section":"Events"},{"id":"enter_15_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_20 (Events)","section":"Events"},{"id":"enter_20_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_20 (Revenue)","section":"Events"},{"id":"enter_20_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_30 (Events)","section":"Events"},{"id":"enter_30_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_30 (Revenue)","section":"Events"},{"id":"enter_30_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_40 (Events)","section":"Events"},{"id":"enter_40_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_40 (Revenue)","section":"Events"},{"id":"enter_40_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_50 (Events)","section":"Events"},{"id":"enter_50_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_50 (Revenue)","section":"Events"},{"id":"enter_50_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_60 (Events)","section":"Events"},{"id":"enter_60_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_60 (Revenue)","section":"Events"},{"id":"enter_60_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_70 (Events)","section":"Events"},{"id":"enter_70_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_70 (Revenue)","section":"Events"},{"id":"enter_70_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_80 (Events)","section":"Events"},{"id":"enter_80_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_80 (Revenue)","section":"Events"},{"id":"enter_80_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_d0_events_cohort","formatting":"integer","short_name":"","name":"0D enter_90 (Events)","section":"Events"},{"id":"enter_90_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D enter_90 (Revenue)","section":"Events"},{"id":"enter_90_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_d0_events_cohort","formatting":"integer","short_name":"","name":"0D EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_d0_events_cohort","formatting":"integer","short_name":"","name":"0D EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_d0_events_cohort","formatting":"integer","short_name":"","name":"0D FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_d0_events_cohort","formatting":"integer","short_name":"","name":"0D FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_d0_events_cohort","formatting":"integer","short_name":"","name":"0D FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_d0_events_cohort","formatting":"integer","short_name":"","name":"0D General Revenue (Events)","section":"Events"},{"id":"general revenue_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D General Revenue (Revenue)","section":"Events"},{"id":"general revenue_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_d0_events_cohort","formatting":"integer","short_name":"","name":"0D get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_d0_events_cohort","formatting":"integer","short_name":"","name":"0D get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_d0_events_cohort","formatting":"integer","short_name":"","name":"0D get_video_time (Events)","section":"Events"},{"id":"get_video_time_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_d0_events_cohort","formatting":"integer","short_name":"","name":"0D iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_d0_events_cohort","formatting":"integer","short_name":"","name":"0D IAP (Events)","section":"Events"},{"id":"iap_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D IAP (Revenue)","section":"Events"},{"id":"iap_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D IAP Events per Conversion","section":"Events"},{"id":"iap_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D IAP Revenue per Conversion","section":"Events"},{"id":"iap_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D IAP (Conversions)","section":"Events"},{"id":"iap_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D IAP (Conversion Distribution)","section":"Events"},{"id":"iap_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per IAP (Events)","section":"Events"},{"id":"iap_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D IAP (Converted User Size)","section":"Events"},{"id":"iap_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per IAP (Conversions)","section":"Events"},{"id":"iap_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D IAP Rate (Events)","section":"Events"},{"id":"iap_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_d0_events_cohort","formatting":"integer","short_name":"","name":"0D interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_d0_events_cohort","formatting":"integer","short_name":"","name":"0D interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_10 (Events)","section":"Events"},{"id":"level_10_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_10 (Revenue)","section":"Events"},{"id":"level_10_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_10 Events per Conversion","section":"Events"},{"id":"level_10_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_10 (Conversions)","section":"Events"},{"id":"level_10_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_10 (Events)","section":"Events"},{"id":"level_10_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_10 (Converted User Size)","section":"Events"},{"id":"level_10_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_10 Rate (Events)","section":"Events"},{"id":"level_10_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_100 (Events)","section":"Events"},{"id":"level_100_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_100 (Revenue)","section":"Events"},{"id":"level_100_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_100 Events per Conversion","section":"Events"},{"id":"level_100_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_100 (Conversions)","section":"Events"},{"id":"level_100_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_100 (Events)","section":"Events"},{"id":"level_100_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_100 (Converted User Size)","section":"Events"},{"id":"level_100_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_100 Rate (Events)","section":"Events"},{"id":"level_100_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_1000 (Events)","section":"Events"},{"id":"level_1000_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_1000 (Revenue)","section":"Events"},{"id":"level_1000_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_10000 (Events)","section":"Events"},{"id":"level_10000_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_10000 (Revenue)","section":"Events"},{"id":"level_10000_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_15 (Events)","section":"Events"},{"id":"level_15_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_15 (Revenue)","section":"Events"},{"id":"level_15_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_15 Events per Conversion","section":"Events"},{"id":"level_15_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_15 (Conversions)","section":"Events"},{"id":"level_15_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_15 (Events)","section":"Events"},{"id":"level_15_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_15 (Converted User Size)","section":"Events"},{"id":"level_15_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_15 Rate (Events)","section":"Events"},{"id":"level_15_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_20 (Events)","section":"Events"},{"id":"level_20_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_20 (Revenue)","section":"Events"},{"id":"level_20_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_20 Events per Conversion","section":"Events"},{"id":"level_20_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_20 (Conversions)","section":"Events"},{"id":"level_20_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_20 (Events)","section":"Events"},{"id":"level_20_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_20 (Converted User Size)","section":"Events"},{"id":"level_20_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_20 Rate (Events)","section":"Events"},{"id":"level_20_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_200 (Events)","section":"Events"},{"id":"level_200_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_200 (Revenue)","section":"Events"},{"id":"level_200_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_200 Events per Conversion","section":"Events"},{"id":"level_200_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_200 (Conversions)","section":"Events"},{"id":"level_200_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_200 (Events)","section":"Events"},{"id":"level_200_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_200 (Converted User Size)","section":"Events"},{"id":"level_200_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_200 Rate (Events)","section":"Events"},{"id":"level_200_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_30 (Events)","section":"Events"},{"id":"level_30_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_30 (Revenue)","section":"Events"},{"id":"level_30_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_30 Events per Conversion","section":"Events"},{"id":"level_30_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_30 (Conversions)","section":"Events"},{"id":"level_30_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_30 (Events)","section":"Events"},{"id":"level_30_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_30 (Converted User Size)","section":"Events"},{"id":"level_30_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_30 Rate (Events)","section":"Events"},{"id":"level_30_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_300 (Events)","section":"Events"},{"id":"level_300_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_300 (Revenue)","section":"Events"},{"id":"level_300_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_300 Events per Conversion","section":"Events"},{"id":"level_300_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_300 (Conversions)","section":"Events"},{"id":"level_300_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_300 (Events)","section":"Events"},{"id":"level_300_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_300 (Converted User Size)","section":"Events"},{"id":"level_300_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_300 Rate (Events)","section":"Events"},{"id":"level_300_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_3000 (Events)","section":"Events"},{"id":"level_3000_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_3000 (Revenue)","section":"Events"},{"id":"level_3000_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_400 (Events)","section":"Events"},{"id":"level_400_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_400 (Revenue)","section":"Events"},{"id":"level_400_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_400 Events per Conversion","section":"Events"},{"id":"level_400_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_400 (Conversions)","section":"Events"},{"id":"level_400_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_400 (Events)","section":"Events"},{"id":"level_400_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_400 (Converted User Size)","section":"Events"},{"id":"level_400_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_400 Rate (Events)","section":"Events"},{"id":"level_400_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_5 (Events)","section":"Events"},{"id":"level_5_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_5 (Revenue)","section":"Events"},{"id":"level_5_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_5 Events per Conversion","section":"Events"},{"id":"level_5_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_5 (Conversions)","section":"Events"},{"id":"level_5_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_5 (Events)","section":"Events"},{"id":"level_5_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_5 (Converted User Size)","section":"Events"},{"id":"level_5_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_5 Rate (Events)","section":"Events"},{"id":"level_5_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_50 (Events)","section":"Events"},{"id":"level_50_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_50 (Revenue)","section":"Events"},{"id":"level_50_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_50 Events per Conversion","section":"Events"},{"id":"level_50_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_50 (Conversions)","section":"Events"},{"id":"level_50_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_50 (Events)","section":"Events"},{"id":"level_50_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_50 (Converted User Size)","section":"Events"},{"id":"level_50_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_50 Rate (Events)","section":"Events"},{"id":"level_50_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_500 (Events)","section":"Events"},{"id":"level_500_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_500 (Revenue)","section":"Events"},{"id":"level_500_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_500 Events per Conversion","section":"Events"},{"id":"level_500_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_500 (Conversions)","section":"Events"},{"id":"level_500_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_500 (Events)","section":"Events"},{"id":"level_500_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_500 (Converted User Size)","section":"Events"},{"id":"level_500_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_500 Rate (Events)","section":"Events"},{"id":"level_500_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_5000 (Events)","section":"Events"},{"id":"level_5000_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_5000 (Revenue)","section":"Events"},{"id":"level_5000_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_d0_events_cohort","formatting":"integer","short_name":"","name":"0D level_600 (Events)","section":"Events"},{"id":"level_600_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D level_600 (Revenue)","section":"Events"},{"id":"level_600_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D level_600 Events per Conversion","section":"Events"},{"id":"level_600_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D level_600 (Conversions)","section":"Events"},{"id":"level_600_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_600 (Events)","section":"Events"},{"id":"level_600_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D level_600 (Converted User Size)","section":"Events"},{"id":"level_600_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D level_600 Rate (Events)","section":"Events"},{"id":"level_600_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_d0_events_cohort","formatting":"integer","short_name":"","name":"0D purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_d0_events_cohort","formatting":"integer","short_name":"","name":"0D resultpage (Events)","section":"Events"},{"id":"resultpage_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D resultpage (Revenue)","section":"Events"},{"id":"resultpage_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D resultpage Events per Conversion","section":"Events"},{"id":"resultpage_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D resultpage (Conversions)","section":"Events"},{"id":"resultpage_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D resultpage Rate (Events)","section":"Events"},{"id":"resultpage_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_d0_events_cohort","formatting":"integer","short_name":"","name":"0D showprice (Events)","section":"Events"},{"id":"showprice_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D showprice (Revenue)","section":"Events"},{"id":"showprice_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D showprice Events per Conversion","section":"Events"},{"id":"showprice_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D showprice Revenue per Conversion","section":"Events"},{"id":"showprice_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D showprice (Conversions)","section":"Events"},{"id":"showprice_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per showprice (Events)","section":"Events"},{"id":"showprice_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D showprice (Converted User Size)","section":"Events"},{"id":"showprice_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D showprice Rate (Events)","section":"Events"},{"id":"showprice_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_d0_events_cohort","formatting":"integer","short_name":"","name":"0D subrevenue (Events)","section":"Events"},{"id":"subrevenue_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_d0_events_cohort","formatting":"integer","short_name":"","name":"0D subscribe (Events)","section":"Events"},{"id":"subscribe_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D subscribe (Revenue)","section":"Events"},{"id":"subscribe_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D subscribe Events per Conversion","section":"Events"},{"id":"subscribe_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D subscribe (Conversions)","section":"Events"},{"id":"subscribe_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D subscribe Rate (Events)","section":"Events"},{"id":"subscribe_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_d0_events_cohort","formatting":"integer","short_name":"","name":"0D uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_d0_events_cohort","formatting":"integer","short_name":"","name":"0D uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_d0_events_cohort","formatting":"integer","short_name":"","name":"0D uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_d0_events_cohort","formatting":"integer","short_name":"","name":"0D uacprice (Events)","section":"Events"},{"id":"uacprice_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D uacprice (Revenue)","section":"Events"},{"id":"uacprice_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D uacprice Events per Conversion","section":"Events"},{"id":"uacprice_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D uacprice (Conversions)","section":"Events"},{"id":"uacprice_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D uacprice Rate (Events)","section":"Events"},{"id":"uacprice_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_d0_events_cohort","formatting":"integer","short_name":"","name":"0D uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_d0_events_cohort","formatting":"integer","short_name":"","name":"0D vip_click (Events)","section":"Events"},{"id":"vip_click_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D vip_click (Revenue)","section":"Events"},{"id":"vip_click_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D vip_click Events per Conversion","section":"Events"},{"id":"vip_click_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D vip_click (Conversions)","section":"Events"},{"id":"vip_click_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_click Rate (Events)","section":"Events"},{"id":"vip_click_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_d0_events_cohort","formatting":"integer","short_name":"","name":"0D vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_d0_events_cohort","formatting":"integer","short_name":"","name":"0D vip_event (Events)","section":"Events"},{"id":"vip_event_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D vip_event (Revenue)","section":"Events"},{"id":"vip_event_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D vip_event Events per Conversion","section":"Events"},{"id":"vip_event_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D vip_event (Conversions)","section":"Events"},{"id":"vip_event_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_event Rate (Events)","section":"Events"},{"id":"vip_event_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_d0_events_cohort","formatting":"integer","short_name":"","name":"0D vip_show (Events)","section":"Events"},{"id":"vip_show_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D vip_show (Revenue)","section":"Events"},{"id":"vip_show_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D vip_show Events per Conversion","section":"Events"},{"id":"vip_show_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D vip_show (Conversions)","section":"Events"},{"id":"vip_show_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_show Rate (Events)","section":"Events"},{"id":"vip_show_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_d0_events_cohort","formatting":"integer","short_name":"","name":"0D vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d0_events_cohort","formatting":"integer","short_name":"","name":"0D Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d0_revenue_cohort","formatting":"money","short_name":"","name":"0D Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_d0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0D Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0D Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d0_conversions_cohort","formatting":"integer","short_name":"","name":"0D Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0D Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_d0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0D Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_d0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0D Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d0_events_rate_cohort","formatting":"percent","short_name":"","name":"0D Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_d0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0D Waterpipe_enter_20 Rate (Conversions)","section":"Events"},{"id":"7d_reward_2600_d1_events_cohort","formatting":"integer","short_name":"","name":"1D 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_d1_events_cohort","formatting":"integer","short_name":"","name":"1D active (Events)","section":"Events"},{"id":"active_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D active (Revenue)","section":"Events"},{"id":"active_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D active Events per Conversion","section":"Events"},{"id":"active_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D active Revenue per Conversion","section":"Events"},{"id":"active_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D active (Conversions)","section":"Events"},{"id":"active_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D active (Conversion Distribution)","section":"Events"},{"id":"active_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per active (Events)","section":"Events"},{"id":"active_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D active (Converted User Size)","section":"Events"},{"id":"active_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per active (Conversions)","section":"Events"},{"id":"active_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D active Rate (Events)","section":"Events"},{"id":"active_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D active Rate (Conversions)","section":"Events"},{"id":"ad_click_d1_events_cohort","formatting":"integer","short_name":"","name":"1D ad_click (Events)","section":"Events"},{"id":"ad_click_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D ad_click (Revenue)","section":"Events"},{"id":"ad_click_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D ad_click Events per Conversion","section":"Events"},{"id":"ad_click_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D ad_click (Conversions)","section":"Events"},{"id":"ad_click_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D ad_click Rate (Events)","section":"Events"},{"id":"ad_click_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_d1_events_cohort","formatting":"integer","short_name":"","name":"1D ad_show (Events)","section":"Events"},{"id":"ad_show_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D ad_show (Revenue)","section":"Events"},{"id":"ad_show_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D ad_show Events per Conversion","section":"Events"},{"id":"ad_show_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D ad_show (Conversions)","section":"Events"},{"id":"ad_show_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D ad_show Rate (Events)","section":"Events"},{"id":"ad_show_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_d1_events_cohort","formatting":"integer","short_name":"","name":"1D adaction (Events)","section":"Events"},{"id":"adaction_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D adaction (Revenue)","section":"Events"},{"id":"adaction_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D adaction Events per Conversion","section":"Events"},{"id":"adaction_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D adaction Revenue per Conversion","section":"Events"},{"id":"adaction_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D adaction (Conversions)","section":"Events"},{"id":"adaction_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adaction (Events)","section":"Events"},{"id":"adaction_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D adaction (Converted User Size)","section":"Events"},{"id":"adaction_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D adaction Rate (Events)","section":"Events"},{"id":"adaction_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D adaction Rate (Conversions)","section":"Events"},{"id":"adclick_d1_events_cohort","formatting":"integer","short_name":"","name":"1D adclick (Events)","section":"Events"},{"id":"adclick_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D adclick (Revenue)","section":"Events"},{"id":"adclick_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D adclick Events per Conversion","section":"Events"},{"id":"adclick_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D adclick Revenue per Conversion","section":"Events"},{"id":"adclick_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D adclick (Conversions)","section":"Events"},{"id":"adclick_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adclick (Events)","section":"Events"},{"id":"adclick_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D adclick (Converted User Size)","section":"Events"},{"id":"adclick_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D adclick Rate (Events)","section":"Events"},{"id":"adclick_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_d1_events_cohort","formatting":"integer","short_name":"","name":"1D adrevenue (Events)","section":"Events"},{"id":"adrevenue_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_d1_events_cohort","formatting":"integer","short_name":"","name":"1D adshow (Events)","section":"Events"},{"id":"adshow_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D adshow (Revenue)","section":"Events"},{"id":"adshow_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D adshow Events per Conversion","section":"Events"},{"id":"adshow_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D adshow Revenue per Conversion","section":"Events"},{"id":"adshow_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D adshow (Conversions)","section":"Events"},{"id":"adshow_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adshow (Events)","section":"Events"},{"id":"adshow_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D adshow (Converted User Size)","section":"Events"},{"id":"adshow_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D adshow Rate (Events)","section":"Events"},{"id":"adshow_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D adshow Rate (Conversions)","section":"Events"},{"id":"adv_d1_events_cohort","formatting":"integer","short_name":"","name":"1D adv (Events)","section":"Events"},{"id":"adv_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D adv (Revenue)","section":"Events"},{"id":"adv_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D adv Events per Conversion","section":"Events"},{"id":"adv_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D adv Revenue per Conversion","section":"Events"},{"id":"adv_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D adv (Conversions)","section":"Events"},{"id":"adv_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D adv (Conversion Distribution)","section":"Events"},{"id":"adv_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adv (Events)","section":"Events"},{"id":"adv_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D adv (Converted User Size)","section":"Events"},{"id":"adv_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per adv (Conversions)","section":"Events"},{"id":"adv_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D adv Rate (Events)","section":"Events"},{"id":"adv_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D adv Rate (Conversions)","section":"Events"},{"id":"analytics_d1_events_cohort","formatting":"integer","short_name":"","name":"1D analytics (Events)","section":"Events"},{"id":"analytics_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D analytics (Revenue)","section":"Events"},{"id":"analytics_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D analytics Events per Conversion","section":"Events"},{"id":"analytics_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D analytics Revenue per Conversion","section":"Events"},{"id":"analytics_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D analytics (Conversions)","section":"Events"},{"id":"analytics_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per analytics (Events)","section":"Events"},{"id":"analytics_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D analytics (Converted User Size)","section":"Events"},{"id":"analytics_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D analytics Rate (Events)","section":"Events"},{"id":"analytics_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_d1_events_cohort","formatting":"integer","short_name":"","name":"1D buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_d1_events_cohort","formatting":"integer","short_name":"","name":"1D connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_10 (Events)","section":"Events"},{"id":"enter_10_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_10 (Revenue)","section":"Events"},{"id":"enter_10_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_100 (Events)","section":"Events"},{"id":"enter_100_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_100 (Revenue)","section":"Events"},{"id":"enter_100_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_15 (Events)","section":"Events"},{"id":"enter_15_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_15 (Revenue)","section":"Events"},{"id":"enter_15_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_20 (Events)","section":"Events"},{"id":"enter_20_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_20 (Revenue)","section":"Events"},{"id":"enter_20_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_30 (Events)","section":"Events"},{"id":"enter_30_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_30 (Revenue)","section":"Events"},{"id":"enter_30_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_40 (Events)","section":"Events"},{"id":"enter_40_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_40 (Revenue)","section":"Events"},{"id":"enter_40_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_50 (Events)","section":"Events"},{"id":"enter_50_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_50 (Revenue)","section":"Events"},{"id":"enter_50_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_60 (Events)","section":"Events"},{"id":"enter_60_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_60 (Revenue)","section":"Events"},{"id":"enter_60_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_70 (Events)","section":"Events"},{"id":"enter_70_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_70 (Revenue)","section":"Events"},{"id":"enter_70_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_80 (Events)","section":"Events"},{"id":"enter_80_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_80 (Revenue)","section":"Events"},{"id":"enter_80_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_d1_events_cohort","formatting":"integer","short_name":"","name":"1D enter_90 (Events)","section":"Events"},{"id":"enter_90_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D enter_90 (Revenue)","section":"Events"},{"id":"enter_90_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_d1_events_cohort","formatting":"integer","short_name":"","name":"1D EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_d1_events_cohort","formatting":"integer","short_name":"","name":"1D EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_d1_events_cohort","formatting":"integer","short_name":"","name":"1D FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_d1_events_cohort","formatting":"integer","short_name":"","name":"1D FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_d1_events_cohort","formatting":"integer","short_name":"","name":"1D FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_d1_events_cohort","formatting":"integer","short_name":"","name":"1D General Revenue (Events)","section":"Events"},{"id":"general revenue_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D General Revenue (Revenue)","section":"Events"},{"id":"general revenue_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_d1_events_cohort","formatting":"integer","short_name":"","name":"1D get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_d1_events_cohort","formatting":"integer","short_name":"","name":"1D get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_d1_events_cohort","formatting":"integer","short_name":"","name":"1D get_video_time (Events)","section":"Events"},{"id":"get_video_time_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_d1_events_cohort","formatting":"integer","short_name":"","name":"1D iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_d1_events_cohort","formatting":"integer","short_name":"","name":"1D IAP (Events)","section":"Events"},{"id":"iap_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D IAP (Revenue)","section":"Events"},{"id":"iap_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D IAP Events per Conversion","section":"Events"},{"id":"iap_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D IAP Revenue per Conversion","section":"Events"},{"id":"iap_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D IAP (Conversions)","section":"Events"},{"id":"iap_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D IAP (Conversion Distribution)","section":"Events"},{"id":"iap_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per IAP (Events)","section":"Events"},{"id":"iap_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D IAP (Converted User Size)","section":"Events"},{"id":"iap_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per IAP (Conversions)","section":"Events"},{"id":"iap_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D IAP Rate (Events)","section":"Events"},{"id":"iap_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_d1_events_cohort","formatting":"integer","short_name":"","name":"1D interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_d1_events_cohort","formatting":"integer","short_name":"","name":"1D interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_10 (Events)","section":"Events"},{"id":"level_10_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_10 (Revenue)","section":"Events"},{"id":"level_10_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_10 Events per Conversion","section":"Events"},{"id":"level_10_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_10 (Conversions)","section":"Events"},{"id":"level_10_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_10 (Events)","section":"Events"},{"id":"level_10_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_10 (Converted User Size)","section":"Events"},{"id":"level_10_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_10 Rate (Events)","section":"Events"},{"id":"level_10_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_100 (Events)","section":"Events"},{"id":"level_100_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_100 (Revenue)","section":"Events"},{"id":"level_100_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_100 Events per Conversion","section":"Events"},{"id":"level_100_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_100 (Conversions)","section":"Events"},{"id":"level_100_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_100 (Events)","section":"Events"},{"id":"level_100_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_100 (Converted User Size)","section":"Events"},{"id":"level_100_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_100 Rate (Events)","section":"Events"},{"id":"level_100_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_1000 (Events)","section":"Events"},{"id":"level_1000_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_1000 (Revenue)","section":"Events"},{"id":"level_1000_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_10000 (Events)","section":"Events"},{"id":"level_10000_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_10000 (Revenue)","section":"Events"},{"id":"level_10000_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_15 (Events)","section":"Events"},{"id":"level_15_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_15 (Revenue)","section":"Events"},{"id":"level_15_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_15 Events per Conversion","section":"Events"},{"id":"level_15_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_15 (Conversions)","section":"Events"},{"id":"level_15_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_15 (Events)","section":"Events"},{"id":"level_15_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_15 (Converted User Size)","section":"Events"},{"id":"level_15_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_15 Rate (Events)","section":"Events"},{"id":"level_15_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_20 (Events)","section":"Events"},{"id":"level_20_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_20 (Revenue)","section":"Events"},{"id":"level_20_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_20 Events per Conversion","section":"Events"},{"id":"level_20_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_20 (Conversions)","section":"Events"},{"id":"level_20_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_20 (Events)","section":"Events"},{"id":"level_20_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_20 (Converted User Size)","section":"Events"},{"id":"level_20_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_20 Rate (Events)","section":"Events"},{"id":"level_20_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_200 (Events)","section":"Events"},{"id":"level_200_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_200 (Revenue)","section":"Events"},{"id":"level_200_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_200 Events per Conversion","section":"Events"},{"id":"level_200_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_200 (Conversions)","section":"Events"},{"id":"level_200_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_200 (Events)","section":"Events"},{"id":"level_200_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_200 (Converted User Size)","section":"Events"},{"id":"level_200_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_200 Rate (Events)","section":"Events"},{"id":"level_200_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_30 (Events)","section":"Events"},{"id":"level_30_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_30 (Revenue)","section":"Events"},{"id":"level_30_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_30 Events per Conversion","section":"Events"},{"id":"level_30_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_30 (Conversions)","section":"Events"},{"id":"level_30_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_30 (Events)","section":"Events"},{"id":"level_30_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_30 (Converted User Size)","section":"Events"},{"id":"level_30_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_30 Rate (Events)","section":"Events"},{"id":"level_30_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_300 (Events)","section":"Events"},{"id":"level_300_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_300 (Revenue)","section":"Events"},{"id":"level_300_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_300 Events per Conversion","section":"Events"},{"id":"level_300_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_300 (Conversions)","section":"Events"},{"id":"level_300_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_300 (Events)","section":"Events"},{"id":"level_300_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_300 (Converted User Size)","section":"Events"},{"id":"level_300_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_300 Rate (Events)","section":"Events"},{"id":"level_300_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_3000 (Events)","section":"Events"},{"id":"level_3000_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_3000 (Revenue)","section":"Events"},{"id":"level_3000_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_400 (Events)","section":"Events"},{"id":"level_400_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_400 (Revenue)","section":"Events"},{"id":"level_400_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_400 Events per Conversion","section":"Events"},{"id":"level_400_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_400 (Conversions)","section":"Events"},{"id":"level_400_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_400 (Events)","section":"Events"},{"id":"level_400_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_400 (Converted User Size)","section":"Events"},{"id":"level_400_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_400 Rate (Events)","section":"Events"},{"id":"level_400_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_5 (Events)","section":"Events"},{"id":"level_5_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_5 (Revenue)","section":"Events"},{"id":"level_5_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_5 Events per Conversion","section":"Events"},{"id":"level_5_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_5 (Conversions)","section":"Events"},{"id":"level_5_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_5 (Events)","section":"Events"},{"id":"level_5_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_5 (Converted User Size)","section":"Events"},{"id":"level_5_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_5 Rate (Events)","section":"Events"},{"id":"level_5_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_50 (Events)","section":"Events"},{"id":"level_50_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_50 (Revenue)","section":"Events"},{"id":"level_50_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_50 Events per Conversion","section":"Events"},{"id":"level_50_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_50 (Conversions)","section":"Events"},{"id":"level_50_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_50 (Events)","section":"Events"},{"id":"level_50_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_50 (Converted User Size)","section":"Events"},{"id":"level_50_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_50 Rate (Events)","section":"Events"},{"id":"level_50_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_500 (Events)","section":"Events"},{"id":"level_500_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_500 (Revenue)","section":"Events"},{"id":"level_500_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_500 Events per Conversion","section":"Events"},{"id":"level_500_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_500 (Conversions)","section":"Events"},{"id":"level_500_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_500 (Events)","section":"Events"},{"id":"level_500_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_500 (Converted User Size)","section":"Events"},{"id":"level_500_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_500 Rate (Events)","section":"Events"},{"id":"level_500_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_5000 (Events)","section":"Events"},{"id":"level_5000_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_5000 (Revenue)","section":"Events"},{"id":"level_5000_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_d1_events_cohort","formatting":"integer","short_name":"","name":"1D level_600 (Events)","section":"Events"},{"id":"level_600_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D level_600 (Revenue)","section":"Events"},{"id":"level_600_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D level_600 Events per Conversion","section":"Events"},{"id":"level_600_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D level_600 (Conversions)","section":"Events"},{"id":"level_600_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_600 (Events)","section":"Events"},{"id":"level_600_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D level_600 (Converted User Size)","section":"Events"},{"id":"level_600_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D level_600 Rate (Events)","section":"Events"},{"id":"level_600_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_d1_events_cohort","formatting":"integer","short_name":"","name":"1D purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_d1_events_cohort","formatting":"integer","short_name":"","name":"1D resultpage (Events)","section":"Events"},{"id":"resultpage_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D resultpage (Revenue)","section":"Events"},{"id":"resultpage_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D resultpage Events per Conversion","section":"Events"},{"id":"resultpage_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D resultpage (Conversions)","section":"Events"},{"id":"resultpage_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D resultpage Rate (Events)","section":"Events"},{"id":"resultpage_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_d1_events_cohort","formatting":"integer","short_name":"","name":"1D showprice (Events)","section":"Events"},{"id":"showprice_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D showprice (Revenue)","section":"Events"},{"id":"showprice_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D showprice Events per Conversion","section":"Events"},{"id":"showprice_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D showprice Revenue per Conversion","section":"Events"},{"id":"showprice_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D showprice (Conversions)","section":"Events"},{"id":"showprice_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per showprice (Events)","section":"Events"},{"id":"showprice_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D showprice (Converted User Size)","section":"Events"},{"id":"showprice_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D showprice Rate (Events)","section":"Events"},{"id":"showprice_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_d1_events_cohort","formatting":"integer","short_name":"","name":"1D subrevenue (Events)","section":"Events"},{"id":"subrevenue_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_d1_events_cohort","formatting":"integer","short_name":"","name":"1D subscribe (Events)","section":"Events"},{"id":"subscribe_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D subscribe (Revenue)","section":"Events"},{"id":"subscribe_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D subscribe Events per Conversion","section":"Events"},{"id":"subscribe_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D subscribe (Conversions)","section":"Events"},{"id":"subscribe_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D subscribe Rate (Events)","section":"Events"},{"id":"subscribe_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_d1_events_cohort","formatting":"integer","short_name":"","name":"1D uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_d1_events_cohort","formatting":"integer","short_name":"","name":"1D uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_d1_events_cohort","formatting":"integer","short_name":"","name":"1D uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_d1_events_cohort","formatting":"integer","short_name":"","name":"1D uacprice (Events)","section":"Events"},{"id":"uacprice_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D uacprice (Revenue)","section":"Events"},{"id":"uacprice_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D uacprice Events per Conversion","section":"Events"},{"id":"uacprice_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D uacprice (Conversions)","section":"Events"},{"id":"uacprice_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D uacprice Rate (Events)","section":"Events"},{"id":"uacprice_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_d1_events_cohort","formatting":"integer","short_name":"","name":"1D uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_d1_events_cohort","formatting":"integer","short_name":"","name":"1D vip_click (Events)","section":"Events"},{"id":"vip_click_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D vip_click (Revenue)","section":"Events"},{"id":"vip_click_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D vip_click Events per Conversion","section":"Events"},{"id":"vip_click_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D vip_click (Conversions)","section":"Events"},{"id":"vip_click_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_click Rate (Events)","section":"Events"},{"id":"vip_click_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_d1_events_cohort","formatting":"integer","short_name":"","name":"1D vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_d1_events_cohort","formatting":"integer","short_name":"","name":"1D vip_event (Events)","section":"Events"},{"id":"vip_event_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D vip_event (Revenue)","section":"Events"},{"id":"vip_event_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D vip_event Events per Conversion","section":"Events"},{"id":"vip_event_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D vip_event (Conversions)","section":"Events"},{"id":"vip_event_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_event Rate (Events)","section":"Events"},{"id":"vip_event_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_d1_events_cohort","formatting":"integer","short_name":"","name":"1D vip_show (Events)","section":"Events"},{"id":"vip_show_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D vip_show (Revenue)","section":"Events"},{"id":"vip_show_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D vip_show Events per Conversion","section":"Events"},{"id":"vip_show_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D vip_show (Conversions)","section":"Events"},{"id":"vip_show_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_show Rate (Events)","section":"Events"},{"id":"vip_show_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_d1_events_cohort","formatting":"integer","short_name":"","name":"1D vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d1_events_cohort","formatting":"integer","short_name":"","name":"1D Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d1_revenue_cohort","formatting":"money","short_name":"","name":"1D Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_d1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1D Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1D Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d1_conversions_cohort","formatting":"integer","short_name":"","name":"1D Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1D Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_d1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1D Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_d1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1D Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d1_events_rate_cohort","formatting":"percent","short_name":"","name":"1D Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_d1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1D Waterpipe_enter_20 Rate (Conversions)","section":"Events"},{"id":"7d_reward_2600_d3_events_cohort","formatting":"integer","short_name":"","name":"3D 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_d3_events_cohort","formatting":"integer","short_name":"","name":"3D active (Events)","section":"Events"},{"id":"active_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D active (Revenue)","section":"Events"},{"id":"active_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D active Events per Conversion","section":"Events"},{"id":"active_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D active Revenue per Conversion","section":"Events"},{"id":"active_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D active (Conversions)","section":"Events"},{"id":"active_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D active (Conversion Distribution)","section":"Events"},{"id":"active_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per active (Events)","section":"Events"},{"id":"active_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D active (Converted User Size)","section":"Events"},{"id":"active_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per active (Conversions)","section":"Events"},{"id":"active_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D active Rate (Events)","section":"Events"},{"id":"active_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D active Rate (Conversions)","section":"Events"},{"id":"ad_click_d3_events_cohort","formatting":"integer","short_name":"","name":"3D ad_click (Events)","section":"Events"},{"id":"ad_click_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D ad_click (Revenue)","section":"Events"},{"id":"ad_click_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D ad_click Events per Conversion","section":"Events"},{"id":"ad_click_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D ad_click (Conversions)","section":"Events"},{"id":"ad_click_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D ad_click Rate (Events)","section":"Events"},{"id":"ad_click_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_d3_events_cohort","formatting":"integer","short_name":"","name":"3D ad_show (Events)","section":"Events"},{"id":"ad_show_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D ad_show (Revenue)","section":"Events"},{"id":"ad_show_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D ad_show Events per Conversion","section":"Events"},{"id":"ad_show_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D ad_show (Conversions)","section":"Events"},{"id":"ad_show_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D ad_show Rate (Events)","section":"Events"},{"id":"ad_show_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_d3_events_cohort","formatting":"integer","short_name":"","name":"3D adaction (Events)","section":"Events"},{"id":"adaction_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D adaction (Revenue)","section":"Events"},{"id":"adaction_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D adaction Events per Conversion","section":"Events"},{"id":"adaction_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D adaction Revenue per Conversion","section":"Events"},{"id":"adaction_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D adaction (Conversions)","section":"Events"},{"id":"adaction_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adaction (Events)","section":"Events"},{"id":"adaction_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D adaction (Converted User Size)","section":"Events"},{"id":"adaction_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D adaction Rate (Events)","section":"Events"},{"id":"adaction_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D adaction Rate (Conversions)","section":"Events"},{"id":"adclick_d3_events_cohort","formatting":"integer","short_name":"","name":"3D adclick (Events)","section":"Events"},{"id":"adclick_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D adclick (Revenue)","section":"Events"},{"id":"adclick_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D adclick Events per Conversion","section":"Events"},{"id":"adclick_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D adclick Revenue per Conversion","section":"Events"},{"id":"adclick_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D adclick (Conversions)","section":"Events"},{"id":"adclick_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adclick (Events)","section":"Events"},{"id":"adclick_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D adclick (Converted User Size)","section":"Events"},{"id":"adclick_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D adclick Rate (Events)","section":"Events"},{"id":"adclick_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_d3_events_cohort","formatting":"integer","short_name":"","name":"3D adrevenue (Events)","section":"Events"},{"id":"adrevenue_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_d3_events_cohort","formatting":"integer","short_name":"","name":"3D adshow (Events)","section":"Events"},{"id":"adshow_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D adshow (Revenue)","section":"Events"},{"id":"adshow_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D adshow Events per Conversion","section":"Events"},{"id":"adshow_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D adshow Revenue per Conversion","section":"Events"},{"id":"adshow_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D adshow (Conversions)","section":"Events"},{"id":"adshow_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adshow (Events)","section":"Events"},{"id":"adshow_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D adshow (Converted User Size)","section":"Events"},{"id":"adshow_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D adshow Rate (Events)","section":"Events"},{"id":"adshow_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D adshow Rate (Conversions)","section":"Events"},{"id":"adv_d3_events_cohort","formatting":"integer","short_name":"","name":"3D adv (Events)","section":"Events"},{"id":"adv_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D adv (Revenue)","section":"Events"},{"id":"adv_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D adv Events per Conversion","section":"Events"},{"id":"adv_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D adv Revenue per Conversion","section":"Events"},{"id":"adv_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D adv (Conversions)","section":"Events"},{"id":"adv_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D adv (Conversion Distribution)","section":"Events"},{"id":"adv_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adv (Events)","section":"Events"},{"id":"adv_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D adv (Converted User Size)","section":"Events"},{"id":"adv_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per adv (Conversions)","section":"Events"},{"id":"adv_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D adv Rate (Events)","section":"Events"},{"id":"adv_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D adv Rate (Conversions)","section":"Events"},{"id":"analytics_d3_events_cohort","formatting":"integer","short_name":"","name":"3D analytics (Events)","section":"Events"},{"id":"analytics_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D analytics (Revenue)","section":"Events"},{"id":"analytics_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D analytics Events per Conversion","section":"Events"},{"id":"analytics_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D analytics Revenue per Conversion","section":"Events"},{"id":"analytics_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D analytics (Conversions)","section":"Events"},{"id":"analytics_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per analytics (Events)","section":"Events"},{"id":"analytics_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D analytics (Converted User Size)","section":"Events"},{"id":"analytics_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D analytics Rate (Events)","section":"Events"},{"id":"analytics_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_d3_events_cohort","formatting":"integer","short_name":"","name":"3D buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_d3_events_cohort","formatting":"integer","short_name":"","name":"3D connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_10 (Events)","section":"Events"},{"id":"enter_10_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_10 (Revenue)","section":"Events"},{"id":"enter_10_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_100 (Events)","section":"Events"},{"id":"enter_100_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_100 (Revenue)","section":"Events"},{"id":"enter_100_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_15 (Events)","section":"Events"},{"id":"enter_15_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_15 (Revenue)","section":"Events"},{"id":"enter_15_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_20 (Events)","section":"Events"},{"id":"enter_20_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_20 (Revenue)","section":"Events"},{"id":"enter_20_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_30 (Events)","section":"Events"},{"id":"enter_30_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_30 (Revenue)","section":"Events"},{"id":"enter_30_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_40 (Events)","section":"Events"},{"id":"enter_40_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_40 (Revenue)","section":"Events"},{"id":"enter_40_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_50 (Events)","section":"Events"},{"id":"enter_50_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_50 (Revenue)","section":"Events"},{"id":"enter_50_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_60 (Events)","section":"Events"},{"id":"enter_60_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_60 (Revenue)","section":"Events"},{"id":"enter_60_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_70 (Events)","section":"Events"},{"id":"enter_70_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_70 (Revenue)","section":"Events"},{"id":"enter_70_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_80 (Events)","section":"Events"},{"id":"enter_80_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_80 (Revenue)","section":"Events"},{"id":"enter_80_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_d3_events_cohort","formatting":"integer","short_name":"","name":"3D enter_90 (Events)","section":"Events"},{"id":"enter_90_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D enter_90 (Revenue)","section":"Events"},{"id":"enter_90_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_d3_events_cohort","formatting":"integer","short_name":"","name":"3D EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_d3_events_cohort","formatting":"integer","short_name":"","name":"3D EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_d3_events_cohort","formatting":"integer","short_name":"","name":"3D FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_d3_events_cohort","formatting":"integer","short_name":"","name":"3D FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_d3_events_cohort","formatting":"integer","short_name":"","name":"3D FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_d3_events_cohort","formatting":"integer","short_name":"","name":"3D General Revenue (Events)","section":"Events"},{"id":"general revenue_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D General Revenue (Revenue)","section":"Events"},{"id":"general revenue_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_d3_events_cohort","formatting":"integer","short_name":"","name":"3D get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_d3_events_cohort","formatting":"integer","short_name":"","name":"3D get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_d3_events_cohort","formatting":"integer","short_name":"","name":"3D get_video_time (Events)","section":"Events"},{"id":"get_video_time_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_d3_events_cohort","formatting":"integer","short_name":"","name":"3D iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_d3_events_cohort","formatting":"integer","short_name":"","name":"3D IAP (Events)","section":"Events"},{"id":"iap_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D IAP (Revenue)","section":"Events"},{"id":"iap_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D IAP Events per Conversion","section":"Events"},{"id":"iap_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D IAP Revenue per Conversion","section":"Events"},{"id":"iap_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D IAP (Conversions)","section":"Events"},{"id":"iap_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D IAP (Conversion Distribution)","section":"Events"},{"id":"iap_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per IAP (Events)","section":"Events"},{"id":"iap_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D IAP (Converted User Size)","section":"Events"},{"id":"iap_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per IAP (Conversions)","section":"Events"},{"id":"iap_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D IAP Rate (Events)","section":"Events"},{"id":"iap_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_d3_events_cohort","formatting":"integer","short_name":"","name":"3D interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_d3_events_cohort","formatting":"integer","short_name":"","name":"3D interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_10 (Events)","section":"Events"},{"id":"level_10_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_10 (Revenue)","section":"Events"},{"id":"level_10_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_10 Events per Conversion","section":"Events"},{"id":"level_10_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_10 (Conversions)","section":"Events"},{"id":"level_10_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_10 (Events)","section":"Events"},{"id":"level_10_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_10 (Converted User Size)","section":"Events"},{"id":"level_10_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_10 Rate (Events)","section":"Events"},{"id":"level_10_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_100 (Events)","section":"Events"},{"id":"level_100_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_100 (Revenue)","section":"Events"},{"id":"level_100_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_100 Events per Conversion","section":"Events"},{"id":"level_100_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_100 (Conversions)","section":"Events"},{"id":"level_100_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_100 (Events)","section":"Events"},{"id":"level_100_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_100 (Converted User Size)","section":"Events"},{"id":"level_100_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_100 Rate (Events)","section":"Events"},{"id":"level_100_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_1000 (Events)","section":"Events"},{"id":"level_1000_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_1000 (Revenue)","section":"Events"},{"id":"level_1000_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_10000 (Events)","section":"Events"},{"id":"level_10000_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_10000 (Revenue)","section":"Events"},{"id":"level_10000_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_15 (Events)","section":"Events"},{"id":"level_15_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_15 (Revenue)","section":"Events"},{"id":"level_15_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_15 Events per Conversion","section":"Events"},{"id":"level_15_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_15 (Conversions)","section":"Events"},{"id":"level_15_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_15 (Events)","section":"Events"},{"id":"level_15_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_15 (Converted User Size)","section":"Events"},{"id":"level_15_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_15 Rate (Events)","section":"Events"},{"id":"level_15_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_20 (Events)","section":"Events"},{"id":"level_20_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_20 (Revenue)","section":"Events"},{"id":"level_20_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_20 Events per Conversion","section":"Events"},{"id":"level_20_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_20 (Conversions)","section":"Events"},{"id":"level_20_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_20 (Events)","section":"Events"},{"id":"level_20_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_20 (Converted User Size)","section":"Events"},{"id":"level_20_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_20 Rate (Events)","section":"Events"},{"id":"level_20_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_200 (Events)","section":"Events"},{"id":"level_200_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_200 (Revenue)","section":"Events"},{"id":"level_200_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_200 Events per Conversion","section":"Events"},{"id":"level_200_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_200 (Conversions)","section":"Events"},{"id":"level_200_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_200 (Events)","section":"Events"},{"id":"level_200_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_200 (Converted User Size)","section":"Events"},{"id":"level_200_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_200 Rate (Events)","section":"Events"},{"id":"level_200_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_30 (Events)","section":"Events"},{"id":"level_30_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_30 (Revenue)","section":"Events"},{"id":"level_30_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_30 Events per Conversion","section":"Events"},{"id":"level_30_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_30 (Conversions)","section":"Events"},{"id":"level_30_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_30 (Events)","section":"Events"},{"id":"level_30_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_30 (Converted User Size)","section":"Events"},{"id":"level_30_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_30 Rate (Events)","section":"Events"},{"id":"level_30_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_300 (Events)","section":"Events"},{"id":"level_300_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_300 (Revenue)","section":"Events"},{"id":"level_300_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_300 Events per Conversion","section":"Events"},{"id":"level_300_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_300 (Conversions)","section":"Events"},{"id":"level_300_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_300 (Events)","section":"Events"},{"id":"level_300_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_300 (Converted User Size)","section":"Events"},{"id":"level_300_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_300 Rate (Events)","section":"Events"},{"id":"level_300_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_3000 (Events)","section":"Events"},{"id":"level_3000_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_3000 (Revenue)","section":"Events"},{"id":"level_3000_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_400 (Events)","section":"Events"},{"id":"level_400_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_400 (Revenue)","section":"Events"},{"id":"level_400_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_400 Events per Conversion","section":"Events"},{"id":"level_400_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_400 (Conversions)","section":"Events"},{"id":"level_400_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_400 (Events)","section":"Events"},{"id":"level_400_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_400 (Converted User Size)","section":"Events"},{"id":"level_400_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_400 Rate (Events)","section":"Events"},{"id":"level_400_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_5 (Events)","section":"Events"},{"id":"level_5_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_5 (Revenue)","section":"Events"},{"id":"level_5_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_5 Events per Conversion","section":"Events"},{"id":"level_5_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_5 (Conversions)","section":"Events"},{"id":"level_5_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_5 (Events)","section":"Events"},{"id":"level_5_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_5 (Converted User Size)","section":"Events"},{"id":"level_5_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_5 Rate (Events)","section":"Events"},{"id":"level_5_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_50 (Events)","section":"Events"},{"id":"level_50_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_50 (Revenue)","section":"Events"},{"id":"level_50_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_50 Events per Conversion","section":"Events"},{"id":"level_50_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_50 (Conversions)","section":"Events"},{"id":"level_50_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_50 (Events)","section":"Events"},{"id":"level_50_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_50 (Converted User Size)","section":"Events"},{"id":"level_50_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_50 Rate (Events)","section":"Events"},{"id":"level_50_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_500 (Events)","section":"Events"},{"id":"level_500_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_500 (Revenue)","section":"Events"},{"id":"level_500_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_500 Events per Conversion","section":"Events"},{"id":"level_500_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_500 (Conversions)","section":"Events"},{"id":"level_500_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_500 (Events)","section":"Events"},{"id":"level_500_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_500 (Converted User Size)","section":"Events"},{"id":"level_500_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_500 Rate (Events)","section":"Events"},{"id":"level_500_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_5000 (Events)","section":"Events"},{"id":"level_5000_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_5000 (Revenue)","section":"Events"},{"id":"level_5000_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_d3_events_cohort","formatting":"integer","short_name":"","name":"3D level_600 (Events)","section":"Events"},{"id":"level_600_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D level_600 (Revenue)","section":"Events"},{"id":"level_600_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D level_600 Events per Conversion","section":"Events"},{"id":"level_600_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D level_600 (Conversions)","section":"Events"},{"id":"level_600_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_600 (Events)","section":"Events"},{"id":"level_600_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D level_600 (Converted User Size)","section":"Events"},{"id":"level_600_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D level_600 Rate (Events)","section":"Events"},{"id":"level_600_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_d3_events_cohort","formatting":"integer","short_name":"","name":"3D purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_d3_events_cohort","formatting":"integer","short_name":"","name":"3D resultpage (Events)","section":"Events"},{"id":"resultpage_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D resultpage (Revenue)","section":"Events"},{"id":"resultpage_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D resultpage Events per Conversion","section":"Events"},{"id":"resultpage_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D resultpage (Conversions)","section":"Events"},{"id":"resultpage_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D resultpage Rate (Events)","section":"Events"},{"id":"resultpage_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_d3_events_cohort","formatting":"integer","short_name":"","name":"3D showprice (Events)","section":"Events"},{"id":"showprice_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D showprice (Revenue)","section":"Events"},{"id":"showprice_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D showprice Events per Conversion","section":"Events"},{"id":"showprice_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D showprice Revenue per Conversion","section":"Events"},{"id":"showprice_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D showprice (Conversions)","section":"Events"},{"id":"showprice_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per showprice (Events)","section":"Events"},{"id":"showprice_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D showprice (Converted User Size)","section":"Events"},{"id":"showprice_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D showprice Rate (Events)","section":"Events"},{"id":"showprice_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_d3_events_cohort","formatting":"integer","short_name":"","name":"3D subrevenue (Events)","section":"Events"},{"id":"subrevenue_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_d3_events_cohort","formatting":"integer","short_name":"","name":"3D subscribe (Events)","section":"Events"},{"id":"subscribe_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D subscribe (Revenue)","section":"Events"},{"id":"subscribe_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D subscribe Events per Conversion","section":"Events"},{"id":"subscribe_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D subscribe (Conversions)","section":"Events"},{"id":"subscribe_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D subscribe Rate (Events)","section":"Events"},{"id":"subscribe_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_d3_events_cohort","formatting":"integer","short_name":"","name":"3D uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_d3_events_cohort","formatting":"integer","short_name":"","name":"3D uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_d3_events_cohort","formatting":"integer","short_name":"","name":"3D uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_d3_events_cohort","formatting":"integer","short_name":"","name":"3D uacprice (Events)","section":"Events"},{"id":"uacprice_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D uacprice (Revenue)","section":"Events"},{"id":"uacprice_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D uacprice Events per Conversion","section":"Events"},{"id":"uacprice_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D uacprice (Conversions)","section":"Events"},{"id":"uacprice_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D uacprice Rate (Events)","section":"Events"},{"id":"uacprice_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_d3_events_cohort","formatting":"integer","short_name":"","name":"3D uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_d3_events_cohort","formatting":"integer","short_name":"","name":"3D vip_click (Events)","section":"Events"},{"id":"vip_click_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D vip_click (Revenue)","section":"Events"},{"id":"vip_click_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D vip_click Events per Conversion","section":"Events"},{"id":"vip_click_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D vip_click (Conversions)","section":"Events"},{"id":"vip_click_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_click Rate (Events)","section":"Events"},{"id":"vip_click_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_d3_events_cohort","formatting":"integer","short_name":"","name":"3D vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_d3_events_cohort","formatting":"integer","short_name":"","name":"3D vip_event (Events)","section":"Events"},{"id":"vip_event_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D vip_event (Revenue)","section":"Events"},{"id":"vip_event_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D vip_event Events per Conversion","section":"Events"},{"id":"vip_event_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D vip_event (Conversions)","section":"Events"},{"id":"vip_event_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_event Rate (Events)","section":"Events"},{"id":"vip_event_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_d3_events_cohort","formatting":"integer","short_name":"","name":"3D vip_show (Events)","section":"Events"},{"id":"vip_show_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D vip_show (Revenue)","section":"Events"},{"id":"vip_show_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D vip_show Events per Conversion","section":"Events"},{"id":"vip_show_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D vip_show (Conversions)","section":"Events"},{"id":"vip_show_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_show Rate (Events)","section":"Events"},{"id":"vip_show_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_d3_events_cohort","formatting":"integer","short_name":"","name":"3D vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d3_events_cohort","formatting":"integer","short_name":"","name":"3D Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d3_revenue_cohort","formatting":"money","short_name":"","name":"3D Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_d3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3D Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3D Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d3_conversions_cohort","formatting":"integer","short_name":"","name":"3D Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3D Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_d3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3D Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_d3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3D Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d3_events_rate_cohort","formatting":"percent","short_name":"","name":"3D Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_d3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3D Waterpipe_enter_20 Rate (Conversions)","section":"Events"},{"id":"7d_reward_2600_d7_events_cohort","formatting":"integer","short_name":"","name":"7D 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_d7_events_cohort","formatting":"integer","short_name":"","name":"7D active (Events)","section":"Events"},{"id":"active_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D active (Revenue)","section":"Events"},{"id":"active_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D active Events per Conversion","section":"Events"},{"id":"active_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D active Revenue per Conversion","section":"Events"},{"id":"active_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D active (Conversions)","section":"Events"},{"id":"active_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D active (Conversion Distribution)","section":"Events"},{"id":"active_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per active (Events)","section":"Events"},{"id":"active_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D active (Converted User Size)","section":"Events"},{"id":"active_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per active (Conversions)","section":"Events"},{"id":"active_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D active Rate (Events)","section":"Events"},{"id":"active_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D active Rate (Conversions)","section":"Events"},{"id":"ad_click_d7_events_cohort","formatting":"integer","short_name":"","name":"7D ad_click (Events)","section":"Events"},{"id":"ad_click_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D ad_click (Revenue)","section":"Events"},{"id":"ad_click_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D ad_click Events per Conversion","section":"Events"},{"id":"ad_click_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D ad_click (Conversions)","section":"Events"},{"id":"ad_click_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D ad_click Rate (Events)","section":"Events"},{"id":"ad_click_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_d7_events_cohort","formatting":"integer","short_name":"","name":"7D ad_show (Events)","section":"Events"},{"id":"ad_show_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D ad_show (Revenue)","section":"Events"},{"id":"ad_show_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D ad_show Events per Conversion","section":"Events"},{"id":"ad_show_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D ad_show (Conversions)","section":"Events"},{"id":"ad_show_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D ad_show Rate (Events)","section":"Events"},{"id":"ad_show_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_d7_events_cohort","formatting":"integer","short_name":"","name":"7D adaction (Events)","section":"Events"},{"id":"adaction_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D adaction (Revenue)","section":"Events"},{"id":"adaction_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D adaction Events per Conversion","section":"Events"},{"id":"adaction_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D adaction Revenue per Conversion","section":"Events"},{"id":"adaction_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D adaction (Conversions)","section":"Events"},{"id":"adaction_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adaction (Events)","section":"Events"},{"id":"adaction_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D adaction (Converted User Size)","section":"Events"},{"id":"adaction_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D adaction Rate (Events)","section":"Events"},{"id":"adaction_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D adaction Rate (Conversions)","section":"Events"},{"id":"adclick_d7_events_cohort","formatting":"integer","short_name":"","name":"7D adclick (Events)","section":"Events"},{"id":"adclick_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D adclick (Revenue)","section":"Events"},{"id":"adclick_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D adclick Events per Conversion","section":"Events"},{"id":"adclick_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D adclick Revenue per Conversion","section":"Events"},{"id":"adclick_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D adclick (Conversions)","section":"Events"},{"id":"adclick_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adclick (Events)","section":"Events"},{"id":"adclick_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D adclick (Converted User Size)","section":"Events"},{"id":"adclick_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D adclick Rate (Events)","section":"Events"},{"id":"adclick_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_d7_events_cohort","formatting":"integer","short_name":"","name":"7D adrevenue (Events)","section":"Events"},{"id":"adrevenue_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_d7_events_cohort","formatting":"integer","short_name":"","name":"7D adshow (Events)","section":"Events"},{"id":"adshow_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D adshow (Revenue)","section":"Events"},{"id":"adshow_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D adshow Events per Conversion","section":"Events"},{"id":"adshow_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D adshow Revenue per Conversion","section":"Events"},{"id":"adshow_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D adshow (Conversions)","section":"Events"},{"id":"adshow_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adshow (Events)","section":"Events"},{"id":"adshow_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D adshow (Converted User Size)","section":"Events"},{"id":"adshow_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D adshow Rate (Events)","section":"Events"},{"id":"adshow_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D adshow Rate (Conversions)","section":"Events"},{"id":"adv_d7_events_cohort","formatting":"integer","short_name":"","name":"7D adv (Events)","section":"Events"},{"id":"adv_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D adv (Revenue)","section":"Events"},{"id":"adv_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D adv Events per Conversion","section":"Events"},{"id":"adv_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D adv Revenue per Conversion","section":"Events"},{"id":"adv_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D adv (Conversions)","section":"Events"},{"id":"adv_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D adv (Conversion Distribution)","section":"Events"},{"id":"adv_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adv (Events)","section":"Events"},{"id":"adv_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D adv (Converted User Size)","section":"Events"},{"id":"adv_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per adv (Conversions)","section":"Events"},{"id":"adv_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D adv Rate (Events)","section":"Events"},{"id":"adv_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D adv Rate (Conversions)","section":"Events"},{"id":"analytics_d7_events_cohort","formatting":"integer","short_name":"","name":"7D analytics (Events)","section":"Events"},{"id":"analytics_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D analytics (Revenue)","section":"Events"},{"id":"analytics_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D analytics Events per Conversion","section":"Events"},{"id":"analytics_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D analytics Revenue per Conversion","section":"Events"},{"id":"analytics_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D analytics (Conversions)","section":"Events"},{"id":"analytics_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per analytics (Events)","section":"Events"},{"id":"analytics_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D analytics (Converted User Size)","section":"Events"},{"id":"analytics_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D analytics Rate (Events)","section":"Events"},{"id":"analytics_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_d7_events_cohort","formatting":"integer","short_name":"","name":"7D buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_d7_events_cohort","formatting":"integer","short_name":"","name":"7D connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_10 (Events)","section":"Events"},{"id":"enter_10_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_10 (Revenue)","section":"Events"},{"id":"enter_10_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_100 (Events)","section":"Events"},{"id":"enter_100_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_100 (Revenue)","section":"Events"},{"id":"enter_100_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_15 (Events)","section":"Events"},{"id":"enter_15_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_15 (Revenue)","section":"Events"},{"id":"enter_15_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_20 (Events)","section":"Events"},{"id":"enter_20_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_20 (Revenue)","section":"Events"},{"id":"enter_20_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_30 (Events)","section":"Events"},{"id":"enter_30_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_30 (Revenue)","section":"Events"},{"id":"enter_30_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_40 (Events)","section":"Events"},{"id":"enter_40_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_40 (Revenue)","section":"Events"},{"id":"enter_40_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_50 (Events)","section":"Events"},{"id":"enter_50_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_50 (Revenue)","section":"Events"},{"id":"enter_50_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_60 (Events)","section":"Events"},{"id":"enter_60_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_60 (Revenue)","section":"Events"},{"id":"enter_60_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_70 (Events)","section":"Events"},{"id":"enter_70_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_70 (Revenue)","section":"Events"},{"id":"enter_70_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_80 (Events)","section":"Events"},{"id":"enter_80_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_80 (Revenue)","section":"Events"},{"id":"enter_80_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_d7_events_cohort","formatting":"integer","short_name":"","name":"7D enter_90 (Events)","section":"Events"},{"id":"enter_90_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D enter_90 (Revenue)","section":"Events"},{"id":"enter_90_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_d7_events_cohort","formatting":"integer","short_name":"","name":"7D EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_d7_events_cohort","formatting":"integer","short_name":"","name":"7D EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_d7_events_cohort","formatting":"integer","short_name":"","name":"7D FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_d7_events_cohort","formatting":"integer","short_name":"","name":"7D FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_d7_events_cohort","formatting":"integer","short_name":"","name":"7D FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_d7_events_cohort","formatting":"integer","short_name":"","name":"7D General Revenue (Events)","section":"Events"},{"id":"general revenue_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D General Revenue (Revenue)","section":"Events"},{"id":"general revenue_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_d7_events_cohort","formatting":"integer","short_name":"","name":"7D get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_d7_events_cohort","formatting":"integer","short_name":"","name":"7D get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_d7_events_cohort","formatting":"integer","short_name":"","name":"7D get_video_time (Events)","section":"Events"},{"id":"get_video_time_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_d7_events_cohort","formatting":"integer","short_name":"","name":"7D iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_d7_events_cohort","formatting":"integer","short_name":"","name":"7D IAP (Events)","section":"Events"},{"id":"iap_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D IAP (Revenue)","section":"Events"},{"id":"iap_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D IAP Events per Conversion","section":"Events"},{"id":"iap_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D IAP Revenue per Conversion","section":"Events"},{"id":"iap_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D IAP (Conversions)","section":"Events"},{"id":"iap_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D IAP (Conversion Distribution)","section":"Events"},{"id":"iap_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per IAP (Events)","section":"Events"},{"id":"iap_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D IAP (Converted User Size)","section":"Events"},{"id":"iap_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per IAP (Conversions)","section":"Events"},{"id":"iap_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D IAP Rate (Events)","section":"Events"},{"id":"iap_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_d7_events_cohort","formatting":"integer","short_name":"","name":"7D interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_d7_events_cohort","formatting":"integer","short_name":"","name":"7D interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_10 (Events)","section":"Events"},{"id":"level_10_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_10 (Revenue)","section":"Events"},{"id":"level_10_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_10 Events per Conversion","section":"Events"},{"id":"level_10_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_10 (Conversions)","section":"Events"},{"id":"level_10_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_10 (Events)","section":"Events"},{"id":"level_10_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_10 (Converted User Size)","section":"Events"},{"id":"level_10_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_10 Rate (Events)","section":"Events"},{"id":"level_10_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_100 (Events)","section":"Events"},{"id":"level_100_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_100 (Revenue)","section":"Events"},{"id":"level_100_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_100 Events per Conversion","section":"Events"},{"id":"level_100_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_100 (Conversions)","section":"Events"},{"id":"level_100_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_100 (Events)","section":"Events"},{"id":"level_100_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_100 (Converted User Size)","section":"Events"},{"id":"level_100_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_100 Rate (Events)","section":"Events"},{"id":"level_100_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_1000 (Events)","section":"Events"},{"id":"level_1000_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_1000 (Revenue)","section":"Events"},{"id":"level_1000_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_10000 (Events)","section":"Events"},{"id":"level_10000_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_10000 (Revenue)","section":"Events"},{"id":"level_10000_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_15 (Events)","section":"Events"},{"id":"level_15_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_15 (Revenue)","section":"Events"},{"id":"level_15_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_15 Events per Conversion","section":"Events"},{"id":"level_15_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_15 (Conversions)","section":"Events"},{"id":"level_15_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_15 (Events)","section":"Events"},{"id":"level_15_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_15 (Converted User Size)","section":"Events"},{"id":"level_15_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_15 Rate (Events)","section":"Events"},{"id":"level_15_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_20 (Events)","section":"Events"},{"id":"level_20_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_20 (Revenue)","section":"Events"},{"id":"level_20_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_20 Events per Conversion","section":"Events"},{"id":"level_20_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_20 (Conversions)","section":"Events"},{"id":"level_20_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_20 (Events)","section":"Events"},{"id":"level_20_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_20 (Converted User Size)","section":"Events"},{"id":"level_20_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_20 Rate (Events)","section":"Events"},{"id":"level_20_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_200 (Events)","section":"Events"},{"id":"level_200_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_200 (Revenue)","section":"Events"},{"id":"level_200_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_200 Events per Conversion","section":"Events"},{"id":"level_200_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_200 (Conversions)","section":"Events"},{"id":"level_200_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_200 (Events)","section":"Events"},{"id":"level_200_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_200 (Converted User Size)","section":"Events"},{"id":"level_200_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_200 Rate (Events)","section":"Events"},{"id":"level_200_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_30 (Events)","section":"Events"},{"id":"level_30_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_30 (Revenue)","section":"Events"},{"id":"level_30_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_30 Events per Conversion","section":"Events"},{"id":"level_30_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_30 (Conversions)","section":"Events"},{"id":"level_30_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_30 (Events)","section":"Events"},{"id":"level_30_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_30 (Converted User Size)","section":"Events"},{"id":"level_30_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_30 Rate (Events)","section":"Events"},{"id":"level_30_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_300 (Events)","section":"Events"},{"id":"level_300_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_300 (Revenue)","section":"Events"},{"id":"level_300_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_300 Events per Conversion","section":"Events"},{"id":"level_300_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_300 (Conversions)","section":"Events"},{"id":"level_300_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_300 (Events)","section":"Events"},{"id":"level_300_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_300 (Converted User Size)","section":"Events"},{"id":"level_300_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_300 Rate (Events)","section":"Events"},{"id":"level_300_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_3000 (Events)","section":"Events"},{"id":"level_3000_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_3000 (Revenue)","section":"Events"},{"id":"level_3000_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_400 (Events)","section":"Events"},{"id":"level_400_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_400 (Revenue)","section":"Events"},{"id":"level_400_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_400 Events per Conversion","section":"Events"},{"id":"level_400_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_400 (Conversions)","section":"Events"},{"id":"level_400_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_400 (Events)","section":"Events"},{"id":"level_400_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_400 (Converted User Size)","section":"Events"},{"id":"level_400_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_400 Rate (Events)","section":"Events"},{"id":"level_400_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_5 (Events)","section":"Events"},{"id":"level_5_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_5 (Revenue)","section":"Events"},{"id":"level_5_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_5 Events per Conversion","section":"Events"},{"id":"level_5_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_5 (Conversions)","section":"Events"},{"id":"level_5_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_5 (Events)","section":"Events"},{"id":"level_5_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_5 (Converted User Size)","section":"Events"},{"id":"level_5_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_5 Rate (Events)","section":"Events"},{"id":"level_5_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_50 (Events)","section":"Events"},{"id":"level_50_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_50 (Revenue)","section":"Events"},{"id":"level_50_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_50 Events per Conversion","section":"Events"},{"id":"level_50_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_50 (Conversions)","section":"Events"},{"id":"level_50_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_50 (Events)","section":"Events"},{"id":"level_50_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_50 (Converted User Size)","section":"Events"},{"id":"level_50_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_50 Rate (Events)","section":"Events"},{"id":"level_50_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_500 (Events)","section":"Events"},{"id":"level_500_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_500 (Revenue)","section":"Events"},{"id":"level_500_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_500 Events per Conversion","section":"Events"},{"id":"level_500_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_500 (Conversions)","section":"Events"},{"id":"level_500_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_500 (Events)","section":"Events"},{"id":"level_500_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_500 (Converted User Size)","section":"Events"},{"id":"level_500_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_500 Rate (Events)","section":"Events"},{"id":"level_500_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_5000 (Events)","section":"Events"},{"id":"level_5000_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_5000 (Revenue)","section":"Events"},{"id":"level_5000_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_d7_events_cohort","formatting":"integer","short_name":"","name":"7D level_600 (Events)","section":"Events"},{"id":"level_600_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D level_600 (Revenue)","section":"Events"},{"id":"level_600_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D level_600 Events per Conversion","section":"Events"},{"id":"level_600_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D level_600 (Conversions)","section":"Events"},{"id":"level_600_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_600 (Events)","section":"Events"},{"id":"level_600_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D level_600 (Converted User Size)","section":"Events"},{"id":"level_600_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D level_600 Rate (Events)","section":"Events"},{"id":"level_600_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_d7_events_cohort","formatting":"integer","short_name":"","name":"7D purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_d7_events_cohort","formatting":"integer","short_name":"","name":"7D resultpage (Events)","section":"Events"},{"id":"resultpage_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D resultpage (Revenue)","section":"Events"},{"id":"resultpage_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D resultpage Events per Conversion","section":"Events"},{"id":"resultpage_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D resultpage (Conversions)","section":"Events"},{"id":"resultpage_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D resultpage Rate (Events)","section":"Events"},{"id":"resultpage_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_d7_events_cohort","formatting":"integer","short_name":"","name":"7D showprice (Events)","section":"Events"},{"id":"showprice_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D showprice (Revenue)","section":"Events"},{"id":"showprice_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D showprice Events per Conversion","section":"Events"},{"id":"showprice_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D showprice Revenue per Conversion","section":"Events"},{"id":"showprice_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D showprice (Conversions)","section":"Events"},{"id":"showprice_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per showprice (Events)","section":"Events"},{"id":"showprice_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D showprice (Converted User Size)","section":"Events"},{"id":"showprice_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D showprice Rate (Events)","section":"Events"},{"id":"showprice_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_d7_events_cohort","formatting":"integer","short_name":"","name":"7D subrevenue (Events)","section":"Events"},{"id":"subrevenue_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_d7_events_cohort","formatting":"integer","short_name":"","name":"7D subscribe (Events)","section":"Events"},{"id":"subscribe_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D subscribe (Revenue)","section":"Events"},{"id":"subscribe_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D subscribe Events per Conversion","section":"Events"},{"id":"subscribe_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D subscribe (Conversions)","section":"Events"},{"id":"subscribe_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D subscribe Rate (Events)","section":"Events"},{"id":"subscribe_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_d7_events_cohort","formatting":"integer","short_name":"","name":"7D uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_d7_events_cohort","formatting":"integer","short_name":"","name":"7D uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_d7_events_cohort","formatting":"integer","short_name":"","name":"7D uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_d7_events_cohort","formatting":"integer","short_name":"","name":"7D uacprice (Events)","section":"Events"},{"id":"uacprice_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D uacprice (Revenue)","section":"Events"},{"id":"uacprice_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D uacprice Events per Conversion","section":"Events"},{"id":"uacprice_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D uacprice (Conversions)","section":"Events"},{"id":"uacprice_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D uacprice Rate (Events)","section":"Events"},{"id":"uacprice_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_d7_events_cohort","formatting":"integer","short_name":"","name":"7D uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_d7_events_cohort","formatting":"integer","short_name":"","name":"7D vip_click (Events)","section":"Events"},{"id":"vip_click_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D vip_click (Revenue)","section":"Events"},{"id":"vip_click_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D vip_click Events per Conversion","section":"Events"},{"id":"vip_click_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D vip_click (Conversions)","section":"Events"},{"id":"vip_click_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_click Rate (Events)","section":"Events"},{"id":"vip_click_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_d7_events_cohort","formatting":"integer","short_name":"","name":"7D vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_d7_events_cohort","formatting":"integer","short_name":"","name":"7D vip_event (Events)","section":"Events"},{"id":"vip_event_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D vip_event (Revenue)","section":"Events"},{"id":"vip_event_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D vip_event Events per Conversion","section":"Events"},{"id":"vip_event_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D vip_event (Conversions)","section":"Events"},{"id":"vip_event_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_event Rate (Events)","section":"Events"},{"id":"vip_event_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_d7_events_cohort","formatting":"integer","short_name":"","name":"7D vip_show (Events)","section":"Events"},{"id":"vip_show_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D vip_show (Revenue)","section":"Events"},{"id":"vip_show_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D vip_show Events per Conversion","section":"Events"},{"id":"vip_show_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D vip_show (Conversions)","section":"Events"},{"id":"vip_show_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_show Rate (Events)","section":"Events"},{"id":"vip_show_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_d7_events_cohort","formatting":"integer","short_name":"","name":"7D vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d7_events_cohort","formatting":"integer","short_name":"","name":"7D Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d7_revenue_cohort","formatting":"money","short_name":"","name":"7D Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_d7_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"7D Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d7_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"7D Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d7_conversions_cohort","formatting":"integer","short_name":"","name":"7D Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d7_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"7D Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_d7_events_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d7_converted_user_size_cohort","formatting":"integer","short_name":"","name":"7D Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_d7_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"7D Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d7_events_rate_cohort","formatting":"percent","short_name":"","name":"7D Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_d7_conversions_rate_cohort","formatting":"percent","short_name":"","name":"7D Waterpipe_enter_20 Rate (Conversions)","section":"Events"},{"id":"7d_reward_2600_d14_events_cohort","formatting":"integer","short_name":"","name":"14D 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_d14_events_cohort","formatting":"integer","short_name":"","name":"14D active (Events)","section":"Events"},{"id":"active_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D active (Revenue)","section":"Events"},{"id":"active_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D active Events per Conversion","section":"Events"},{"id":"active_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D active Revenue per Conversion","section":"Events"},{"id":"active_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D active (Conversions)","section":"Events"},{"id":"active_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D active (Conversion Distribution)","section":"Events"},{"id":"active_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per active (Events)","section":"Events"},{"id":"active_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D active (Converted User Size)","section":"Events"},{"id":"active_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per active (Conversions)","section":"Events"},{"id":"active_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D active Rate (Events)","section":"Events"},{"id":"active_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D active Rate (Conversions)","section":"Events"},{"id":"ad_click_d14_events_cohort","formatting":"integer","short_name":"","name":"14D ad_click (Events)","section":"Events"},{"id":"ad_click_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D ad_click (Revenue)","section":"Events"},{"id":"ad_click_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D ad_click Events per Conversion","section":"Events"},{"id":"ad_click_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D ad_click (Conversions)","section":"Events"},{"id":"ad_click_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D ad_click Rate (Events)","section":"Events"},{"id":"ad_click_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_d14_events_cohort","formatting":"integer","short_name":"","name":"14D ad_show (Events)","section":"Events"},{"id":"ad_show_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D ad_show (Revenue)","section":"Events"},{"id":"ad_show_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D ad_show Events per Conversion","section":"Events"},{"id":"ad_show_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D ad_show (Conversions)","section":"Events"},{"id":"ad_show_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D ad_show Rate (Events)","section":"Events"},{"id":"ad_show_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_d14_events_cohort","formatting":"integer","short_name":"","name":"14D adaction (Events)","section":"Events"},{"id":"adaction_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D adaction (Revenue)","section":"Events"},{"id":"adaction_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D adaction Events per Conversion","section":"Events"},{"id":"adaction_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D adaction Revenue per Conversion","section":"Events"},{"id":"adaction_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D adaction (Conversions)","section":"Events"},{"id":"adaction_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adaction (Events)","section":"Events"},{"id":"adaction_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D adaction (Converted User Size)","section":"Events"},{"id":"adaction_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D adaction Rate (Events)","section":"Events"},{"id":"adaction_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D adaction Rate (Conversions)","section":"Events"},{"id":"adclick_d14_events_cohort","formatting":"integer","short_name":"","name":"14D adclick (Events)","section":"Events"},{"id":"adclick_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D adclick (Revenue)","section":"Events"},{"id":"adclick_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D adclick Events per Conversion","section":"Events"},{"id":"adclick_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D adclick Revenue per Conversion","section":"Events"},{"id":"adclick_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D adclick (Conversions)","section":"Events"},{"id":"adclick_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adclick (Events)","section":"Events"},{"id":"adclick_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D adclick (Converted User Size)","section":"Events"},{"id":"adclick_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D adclick Rate (Events)","section":"Events"},{"id":"adclick_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_d14_events_cohort","formatting":"integer","short_name":"","name":"14D adrevenue (Events)","section":"Events"},{"id":"adrevenue_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_d14_events_cohort","formatting":"integer","short_name":"","name":"14D adshow (Events)","section":"Events"},{"id":"adshow_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D adshow (Revenue)","section":"Events"},{"id":"adshow_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D adshow Events per Conversion","section":"Events"},{"id":"adshow_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D adshow Revenue per Conversion","section":"Events"},{"id":"adshow_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D adshow (Conversions)","section":"Events"},{"id":"adshow_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adshow (Events)","section":"Events"},{"id":"adshow_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D adshow (Converted User Size)","section":"Events"},{"id":"adshow_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D adshow Rate (Events)","section":"Events"},{"id":"adshow_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D adshow Rate (Conversions)","section":"Events"},{"id":"adv_d14_events_cohort","formatting":"integer","short_name":"","name":"14D adv (Events)","section":"Events"},{"id":"adv_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D adv (Revenue)","section":"Events"},{"id":"adv_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D adv Events per Conversion","section":"Events"},{"id":"adv_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D adv Revenue per Conversion","section":"Events"},{"id":"adv_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D adv (Conversions)","section":"Events"},{"id":"adv_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D adv (Conversion Distribution)","section":"Events"},{"id":"adv_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adv (Events)","section":"Events"},{"id":"adv_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D adv (Converted User Size)","section":"Events"},{"id":"adv_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per adv (Conversions)","section":"Events"},{"id":"adv_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D adv Rate (Events)","section":"Events"},{"id":"adv_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D adv Rate (Conversions)","section":"Events"},{"id":"analytics_d14_events_cohort","formatting":"integer","short_name":"","name":"14D analytics (Events)","section":"Events"},{"id":"analytics_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D analytics (Revenue)","section":"Events"},{"id":"analytics_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D analytics Events per Conversion","section":"Events"},{"id":"analytics_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D analytics Revenue per Conversion","section":"Events"},{"id":"analytics_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D analytics (Conversions)","section":"Events"},{"id":"analytics_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per analytics (Events)","section":"Events"},{"id":"analytics_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D analytics (Converted User Size)","section":"Events"},{"id":"analytics_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D analytics Rate (Events)","section":"Events"},{"id":"analytics_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_d14_events_cohort","formatting":"integer","short_name":"","name":"14D buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_d14_events_cohort","formatting":"integer","short_name":"","name":"14D connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_10 (Events)","section":"Events"},{"id":"enter_10_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_10 (Revenue)","section":"Events"},{"id":"enter_10_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_100 (Events)","section":"Events"},{"id":"enter_100_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_100 (Revenue)","section":"Events"},{"id":"enter_100_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_15 (Events)","section":"Events"},{"id":"enter_15_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_15 (Revenue)","section":"Events"},{"id":"enter_15_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_20 (Events)","section":"Events"},{"id":"enter_20_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_20 (Revenue)","section":"Events"},{"id":"enter_20_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_30 (Events)","section":"Events"},{"id":"enter_30_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_30 (Revenue)","section":"Events"},{"id":"enter_30_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_40 (Events)","section":"Events"},{"id":"enter_40_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_40 (Revenue)","section":"Events"},{"id":"enter_40_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_50 (Events)","section":"Events"},{"id":"enter_50_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_50 (Revenue)","section":"Events"},{"id":"enter_50_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_60 (Events)","section":"Events"},{"id":"enter_60_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_60 (Revenue)","section":"Events"},{"id":"enter_60_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_70 (Events)","section":"Events"},{"id":"enter_70_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_70 (Revenue)","section":"Events"},{"id":"enter_70_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_80 (Events)","section":"Events"},{"id":"enter_80_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_80 (Revenue)","section":"Events"},{"id":"enter_80_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_d14_events_cohort","formatting":"integer","short_name":"","name":"14D enter_90 (Events)","section":"Events"},{"id":"enter_90_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D enter_90 (Revenue)","section":"Events"},{"id":"enter_90_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_d14_events_cohort","formatting":"integer","short_name":"","name":"14D EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_d14_events_cohort","formatting":"integer","short_name":"","name":"14D EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_d14_events_cohort","formatting":"integer","short_name":"","name":"14D FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_d14_events_cohort","formatting":"integer","short_name":"","name":"14D FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_d14_events_cohort","formatting":"integer","short_name":"","name":"14D FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_d14_events_cohort","formatting":"integer","short_name":"","name":"14D General Revenue (Events)","section":"Events"},{"id":"general revenue_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D General Revenue (Revenue)","section":"Events"},{"id":"general revenue_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_d14_events_cohort","formatting":"integer","short_name":"","name":"14D get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_d14_events_cohort","formatting":"integer","short_name":"","name":"14D get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_d14_events_cohort","formatting":"integer","short_name":"","name":"14D get_video_time (Events)","section":"Events"},{"id":"get_video_time_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_d14_events_cohort","formatting":"integer","short_name":"","name":"14D iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_d14_events_cohort","formatting":"integer","short_name":"","name":"14D IAP (Events)","section":"Events"},{"id":"iap_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D IAP (Revenue)","section":"Events"},{"id":"iap_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D IAP Events per Conversion","section":"Events"},{"id":"iap_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D IAP Revenue per Conversion","section":"Events"},{"id":"iap_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D IAP (Conversions)","section":"Events"},{"id":"iap_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D IAP (Conversion Distribution)","section":"Events"},{"id":"iap_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per IAP (Events)","section":"Events"},{"id":"iap_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D IAP (Converted User Size)","section":"Events"},{"id":"iap_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per IAP (Conversions)","section":"Events"},{"id":"iap_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D IAP Rate (Events)","section":"Events"},{"id":"iap_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_d14_events_cohort","formatting":"integer","short_name":"","name":"14D interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_d14_events_cohort","formatting":"integer","short_name":"","name":"14D interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_10 (Events)","section":"Events"},{"id":"level_10_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_10 (Revenue)","section":"Events"},{"id":"level_10_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_10 Events per Conversion","section":"Events"},{"id":"level_10_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_10 (Conversions)","section":"Events"},{"id":"level_10_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_10 (Events)","section":"Events"},{"id":"level_10_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_10 (Converted User Size)","section":"Events"},{"id":"level_10_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_10 Rate (Events)","section":"Events"},{"id":"level_10_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_100 (Events)","section":"Events"},{"id":"level_100_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_100 (Revenue)","section":"Events"},{"id":"level_100_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_100 Events per Conversion","section":"Events"},{"id":"level_100_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_100 (Conversions)","section":"Events"},{"id":"level_100_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_100 (Events)","section":"Events"},{"id":"level_100_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_100 (Converted User Size)","section":"Events"},{"id":"level_100_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_100 Rate (Events)","section":"Events"},{"id":"level_100_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_1000 (Events)","section":"Events"},{"id":"level_1000_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_1000 (Revenue)","section":"Events"},{"id":"level_1000_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_10000 (Events)","section":"Events"},{"id":"level_10000_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_10000 (Revenue)","section":"Events"},{"id":"level_10000_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_15 (Events)","section":"Events"},{"id":"level_15_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_15 (Revenue)","section":"Events"},{"id":"level_15_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_15 Events per Conversion","section":"Events"},{"id":"level_15_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_15 (Conversions)","section":"Events"},{"id":"level_15_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_15 (Events)","section":"Events"},{"id":"level_15_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_15 (Converted User Size)","section":"Events"},{"id":"level_15_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_15 Rate (Events)","section":"Events"},{"id":"level_15_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_20 (Events)","section":"Events"},{"id":"level_20_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_20 (Revenue)","section":"Events"},{"id":"level_20_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_20 Events per Conversion","section":"Events"},{"id":"level_20_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_20 (Conversions)","section":"Events"},{"id":"level_20_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_20 (Events)","section":"Events"},{"id":"level_20_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_20 (Converted User Size)","section":"Events"},{"id":"level_20_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_20 Rate (Events)","section":"Events"},{"id":"level_20_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_200 (Events)","section":"Events"},{"id":"level_200_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_200 (Revenue)","section":"Events"},{"id":"level_200_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_200 Events per Conversion","section":"Events"},{"id":"level_200_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_200 (Conversions)","section":"Events"},{"id":"level_200_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_200 (Events)","section":"Events"},{"id":"level_200_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_200 (Converted User Size)","section":"Events"},{"id":"level_200_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_200 Rate (Events)","section":"Events"},{"id":"level_200_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_30 (Events)","section":"Events"},{"id":"level_30_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_30 (Revenue)","section":"Events"},{"id":"level_30_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_30 Events per Conversion","section":"Events"},{"id":"level_30_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_30 (Conversions)","section":"Events"},{"id":"level_30_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_30 (Events)","section":"Events"},{"id":"level_30_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_30 (Converted User Size)","section":"Events"},{"id":"level_30_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_30 Rate (Events)","section":"Events"},{"id":"level_30_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_300 (Events)","section":"Events"},{"id":"level_300_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_300 (Revenue)","section":"Events"},{"id":"level_300_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_300 Events per Conversion","section":"Events"},{"id":"level_300_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_300 (Conversions)","section":"Events"},{"id":"level_300_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_300 (Events)","section":"Events"},{"id":"level_300_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_300 (Converted User Size)","section":"Events"},{"id":"level_300_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_300 Rate (Events)","section":"Events"},{"id":"level_300_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_3000 (Events)","section":"Events"},{"id":"level_3000_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_3000 (Revenue)","section":"Events"},{"id":"level_3000_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_400 (Events)","section":"Events"},{"id":"level_400_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_400 (Revenue)","section":"Events"},{"id":"level_400_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_400 Events per Conversion","section":"Events"},{"id":"level_400_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_400 (Conversions)","section":"Events"},{"id":"level_400_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_400 (Events)","section":"Events"},{"id":"level_400_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_400 (Converted User Size)","section":"Events"},{"id":"level_400_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_400 Rate (Events)","section":"Events"},{"id":"level_400_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_5 (Events)","section":"Events"},{"id":"level_5_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_5 (Revenue)","section":"Events"},{"id":"level_5_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_5 Events per Conversion","section":"Events"},{"id":"level_5_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_5 (Conversions)","section":"Events"},{"id":"level_5_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_5 (Events)","section":"Events"},{"id":"level_5_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_5 (Converted User Size)","section":"Events"},{"id":"level_5_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_5 Rate (Events)","section":"Events"},{"id":"level_5_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_50 (Events)","section":"Events"},{"id":"level_50_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_50 (Revenue)","section":"Events"},{"id":"level_50_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_50 Events per Conversion","section":"Events"},{"id":"level_50_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_50 (Conversions)","section":"Events"},{"id":"level_50_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_50 (Events)","section":"Events"},{"id":"level_50_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_50 (Converted User Size)","section":"Events"},{"id":"level_50_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_50 Rate (Events)","section":"Events"},{"id":"level_50_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_500 (Events)","section":"Events"},{"id":"level_500_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_500 (Revenue)","section":"Events"},{"id":"level_500_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_500 Events per Conversion","section":"Events"},{"id":"level_500_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_500 (Conversions)","section":"Events"},{"id":"level_500_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_500 (Events)","section":"Events"},{"id":"level_500_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_500 (Converted User Size)","section":"Events"},{"id":"level_500_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_500 Rate (Events)","section":"Events"},{"id":"level_500_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_5000 (Events)","section":"Events"},{"id":"level_5000_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_5000 (Revenue)","section":"Events"},{"id":"level_5000_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_d14_events_cohort","formatting":"integer","short_name":"","name":"14D level_600 (Events)","section":"Events"},{"id":"level_600_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D level_600 (Revenue)","section":"Events"},{"id":"level_600_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D level_600 Events per Conversion","section":"Events"},{"id":"level_600_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D level_600 (Conversions)","section":"Events"},{"id":"level_600_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_600 (Events)","section":"Events"},{"id":"level_600_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D level_600 (Converted User Size)","section":"Events"},{"id":"level_600_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D level_600 Rate (Events)","section":"Events"},{"id":"level_600_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_d14_events_cohort","formatting":"integer","short_name":"","name":"14D purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_d14_events_cohort","formatting":"integer","short_name":"","name":"14D resultpage (Events)","section":"Events"},{"id":"resultpage_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D resultpage (Revenue)","section":"Events"},{"id":"resultpage_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D resultpage Events per Conversion","section":"Events"},{"id":"resultpage_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D resultpage (Conversions)","section":"Events"},{"id":"resultpage_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D resultpage Rate (Events)","section":"Events"},{"id":"resultpage_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_d14_events_cohort","formatting":"integer","short_name":"","name":"14D showprice (Events)","section":"Events"},{"id":"showprice_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D showprice (Revenue)","section":"Events"},{"id":"showprice_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D showprice Events per Conversion","section":"Events"},{"id":"showprice_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D showprice Revenue per Conversion","section":"Events"},{"id":"showprice_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D showprice (Conversions)","section":"Events"},{"id":"showprice_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per showprice (Events)","section":"Events"},{"id":"showprice_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D showprice (Converted User Size)","section":"Events"},{"id":"showprice_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D showprice Rate (Events)","section":"Events"},{"id":"showprice_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_d14_events_cohort","formatting":"integer","short_name":"","name":"14D subrevenue (Events)","section":"Events"},{"id":"subrevenue_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_d14_events_cohort","formatting":"integer","short_name":"","name":"14D subscribe (Events)","section":"Events"},{"id":"subscribe_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D subscribe (Revenue)","section":"Events"},{"id":"subscribe_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D subscribe Events per Conversion","section":"Events"},{"id":"subscribe_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D subscribe (Conversions)","section":"Events"},{"id":"subscribe_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D subscribe Rate (Events)","section":"Events"},{"id":"subscribe_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_d14_events_cohort","formatting":"integer","short_name":"","name":"14D uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_d14_events_cohort","formatting":"integer","short_name":"","name":"14D uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_d14_events_cohort","formatting":"integer","short_name":"","name":"14D uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_d14_events_cohort","formatting":"integer","short_name":"","name":"14D uacprice (Events)","section":"Events"},{"id":"uacprice_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D uacprice (Revenue)","section":"Events"},{"id":"uacprice_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D uacprice Events per Conversion","section":"Events"},{"id":"uacprice_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D uacprice (Conversions)","section":"Events"},{"id":"uacprice_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D uacprice Rate (Events)","section":"Events"},{"id":"uacprice_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_d14_events_cohort","formatting":"integer","short_name":"","name":"14D uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_d14_events_cohort","formatting":"integer","short_name":"","name":"14D vip_click (Events)","section":"Events"},{"id":"vip_click_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D vip_click (Revenue)","section":"Events"},{"id":"vip_click_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D vip_click Events per Conversion","section":"Events"},{"id":"vip_click_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D vip_click (Conversions)","section":"Events"},{"id":"vip_click_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_click Rate (Events)","section":"Events"},{"id":"vip_click_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_d14_events_cohort","formatting":"integer","short_name":"","name":"14D vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_d14_events_cohort","formatting":"integer","short_name":"","name":"14D vip_event (Events)","section":"Events"},{"id":"vip_event_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D vip_event (Revenue)","section":"Events"},{"id":"vip_event_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D vip_event Events per Conversion","section":"Events"},{"id":"vip_event_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D vip_event (Conversions)","section":"Events"},{"id":"vip_event_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_event Rate (Events)","section":"Events"},{"id":"vip_event_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_d14_events_cohort","formatting":"integer","short_name":"","name":"14D vip_show (Events)","section":"Events"},{"id":"vip_show_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D vip_show (Revenue)","section":"Events"},{"id":"vip_show_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D vip_show Events per Conversion","section":"Events"},{"id":"vip_show_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D vip_show (Conversions)","section":"Events"},{"id":"vip_show_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_show Rate (Events)","section":"Events"},{"id":"vip_show_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_d14_events_cohort","formatting":"integer","short_name":"","name":"14D vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d14_events_cohort","formatting":"integer","short_name":"","name":"14D Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d14_revenue_cohort","formatting":"money","short_name":"","name":"14D Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_d14_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"14D Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d14_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"14D Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d14_conversions_cohort","formatting":"integer","short_name":"","name":"14D Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d14_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"14D Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_d14_events_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d14_converted_user_size_cohort","formatting":"integer","short_name":"","name":"14D Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_d14_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"14D Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d14_events_rate_cohort","formatting":"percent","short_name":"","name":"14D Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_d14_conversions_rate_cohort","formatting":"percent","short_name":"","name":"14D Waterpipe_enter_20 Rate (Conversions)","section":"Events"},{"id":"7d_reward_2600_d30_events_cohort","formatting":"integer","short_name":"","name":"30D 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_d30_events_cohort","formatting":"integer","short_name":"","name":"30D active (Events)","section":"Events"},{"id":"active_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D active (Revenue)","section":"Events"},{"id":"active_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D active Events per Conversion","section":"Events"},{"id":"active_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D active Revenue per Conversion","section":"Events"},{"id":"active_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D active (Conversions)","section":"Events"},{"id":"active_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D active (Conversion Distribution)","section":"Events"},{"id":"active_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per active (Events)","section":"Events"},{"id":"active_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D active (Converted User Size)","section":"Events"},{"id":"active_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per active (Conversions)","section":"Events"},{"id":"active_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D active Rate (Events)","section":"Events"},{"id":"active_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D active Rate (Conversions)","section":"Events"},{"id":"ad_click_d30_events_cohort","formatting":"integer","short_name":"","name":"30D ad_click (Events)","section":"Events"},{"id":"ad_click_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D ad_click (Revenue)","section":"Events"},{"id":"ad_click_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D ad_click Events per Conversion","section":"Events"},{"id":"ad_click_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D ad_click (Conversions)","section":"Events"},{"id":"ad_click_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D ad_click Rate (Events)","section":"Events"},{"id":"ad_click_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_d30_events_cohort","formatting":"integer","short_name":"","name":"30D ad_show (Events)","section":"Events"},{"id":"ad_show_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D ad_show (Revenue)","section":"Events"},{"id":"ad_show_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D ad_show Events per Conversion","section":"Events"},{"id":"ad_show_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D ad_show (Conversions)","section":"Events"},{"id":"ad_show_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D ad_show Rate (Events)","section":"Events"},{"id":"ad_show_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_d30_events_cohort","formatting":"integer","short_name":"","name":"30D adaction (Events)","section":"Events"},{"id":"adaction_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D adaction (Revenue)","section":"Events"},{"id":"adaction_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D adaction Events per Conversion","section":"Events"},{"id":"adaction_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D adaction Revenue per Conversion","section":"Events"},{"id":"adaction_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D adaction (Conversions)","section":"Events"},{"id":"adaction_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adaction (Events)","section":"Events"},{"id":"adaction_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D adaction (Converted User Size)","section":"Events"},{"id":"adaction_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D adaction Rate (Events)","section":"Events"},{"id":"adaction_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D adaction Rate (Conversions)","section":"Events"},{"id":"adclick_d30_events_cohort","formatting":"integer","short_name":"","name":"30D adclick (Events)","section":"Events"},{"id":"adclick_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D adclick (Revenue)","section":"Events"},{"id":"adclick_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D adclick Events per Conversion","section":"Events"},{"id":"adclick_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D adclick Revenue per Conversion","section":"Events"},{"id":"adclick_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D adclick (Conversions)","section":"Events"},{"id":"adclick_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adclick (Events)","section":"Events"},{"id":"adclick_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D adclick (Converted User Size)","section":"Events"},{"id":"adclick_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D adclick Rate (Events)","section":"Events"},{"id":"adclick_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_d30_events_cohort","formatting":"integer","short_name":"","name":"30D adrevenue (Events)","section":"Events"},{"id":"adrevenue_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_d30_events_cohort","formatting":"integer","short_name":"","name":"30D adshow (Events)","section":"Events"},{"id":"adshow_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D adshow (Revenue)","section":"Events"},{"id":"adshow_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D adshow Events per Conversion","section":"Events"},{"id":"adshow_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D adshow Revenue per Conversion","section":"Events"},{"id":"adshow_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D adshow (Conversions)","section":"Events"},{"id":"adshow_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adshow (Events)","section":"Events"},{"id":"adshow_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D adshow (Converted User Size)","section":"Events"},{"id":"adshow_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D adshow Rate (Events)","section":"Events"},{"id":"adshow_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D adshow Rate (Conversions)","section":"Events"},{"id":"adv_d30_events_cohort","formatting":"integer","short_name":"","name":"30D adv (Events)","section":"Events"},{"id":"adv_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D adv (Revenue)","section":"Events"},{"id":"adv_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D adv Events per Conversion","section":"Events"},{"id":"adv_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D adv Revenue per Conversion","section":"Events"},{"id":"adv_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D adv (Conversions)","section":"Events"},{"id":"adv_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D adv (Conversion Distribution)","section":"Events"},{"id":"adv_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adv (Events)","section":"Events"},{"id":"adv_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D adv (Converted User Size)","section":"Events"},{"id":"adv_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per adv (Conversions)","section":"Events"},{"id":"adv_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D adv Rate (Events)","section":"Events"},{"id":"adv_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D adv Rate (Conversions)","section":"Events"},{"id":"analytics_d30_events_cohort","formatting":"integer","short_name":"","name":"30D analytics (Events)","section":"Events"},{"id":"analytics_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D analytics (Revenue)","section":"Events"},{"id":"analytics_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D analytics Events per Conversion","section":"Events"},{"id":"analytics_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D analytics Revenue per Conversion","section":"Events"},{"id":"analytics_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D analytics (Conversions)","section":"Events"},{"id":"analytics_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per analytics (Events)","section":"Events"},{"id":"analytics_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D analytics (Converted User Size)","section":"Events"},{"id":"analytics_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D analytics Rate (Events)","section":"Events"},{"id":"analytics_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_d30_events_cohort","formatting":"integer","short_name":"","name":"30D buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_d30_events_cohort","formatting":"integer","short_name":"","name":"30D connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_10 (Events)","section":"Events"},{"id":"enter_10_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_10 (Revenue)","section":"Events"},{"id":"enter_10_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_100 (Events)","section":"Events"},{"id":"enter_100_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_100 (Revenue)","section":"Events"},{"id":"enter_100_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_15 (Events)","section":"Events"},{"id":"enter_15_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_15 (Revenue)","section":"Events"},{"id":"enter_15_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_20 (Events)","section":"Events"},{"id":"enter_20_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_20 (Revenue)","section":"Events"},{"id":"enter_20_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_30 (Events)","section":"Events"},{"id":"enter_30_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_30 (Revenue)","section":"Events"},{"id":"enter_30_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_40 (Events)","section":"Events"},{"id":"enter_40_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_40 (Revenue)","section":"Events"},{"id":"enter_40_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_50 (Events)","section":"Events"},{"id":"enter_50_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_50 (Revenue)","section":"Events"},{"id":"enter_50_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_60 (Events)","section":"Events"},{"id":"enter_60_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_60 (Revenue)","section":"Events"},{"id":"enter_60_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_70 (Events)","section":"Events"},{"id":"enter_70_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_70 (Revenue)","section":"Events"},{"id":"enter_70_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_80 (Events)","section":"Events"},{"id":"enter_80_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_80 (Revenue)","section":"Events"},{"id":"enter_80_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_d30_events_cohort","formatting":"integer","short_name":"","name":"30D enter_90 (Events)","section":"Events"},{"id":"enter_90_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D enter_90 (Revenue)","section":"Events"},{"id":"enter_90_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_d30_events_cohort","formatting":"integer","short_name":"","name":"30D EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_d30_events_cohort","formatting":"integer","short_name":"","name":"30D EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_d30_events_cohort","formatting":"integer","short_name":"","name":"30D FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_d30_events_cohort","formatting":"integer","short_name":"","name":"30D FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_d30_events_cohort","formatting":"integer","short_name":"","name":"30D FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_d30_events_cohort","formatting":"integer","short_name":"","name":"30D General Revenue (Events)","section":"Events"},{"id":"general revenue_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D General Revenue (Revenue)","section":"Events"},{"id":"general revenue_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_d30_events_cohort","formatting":"integer","short_name":"","name":"30D get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_d30_events_cohort","formatting":"integer","short_name":"","name":"30D get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_d30_events_cohort","formatting":"integer","short_name":"","name":"30D get_video_time (Events)","section":"Events"},{"id":"get_video_time_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_d30_events_cohort","formatting":"integer","short_name":"","name":"30D iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_d30_events_cohort","formatting":"integer","short_name":"","name":"30D IAP (Events)","section":"Events"},{"id":"iap_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D IAP (Revenue)","section":"Events"},{"id":"iap_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D IAP Events per Conversion","section":"Events"},{"id":"iap_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D IAP Revenue per Conversion","section":"Events"},{"id":"iap_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D IAP (Conversions)","section":"Events"},{"id":"iap_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D IAP (Conversion Distribution)","section":"Events"},{"id":"iap_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per IAP (Events)","section":"Events"},{"id":"iap_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D IAP (Converted User Size)","section":"Events"},{"id":"iap_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per IAP (Conversions)","section":"Events"},{"id":"iap_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D IAP Rate (Events)","section":"Events"},{"id":"iap_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_d30_events_cohort","formatting":"integer","short_name":"","name":"30D interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_d30_events_cohort","formatting":"integer","short_name":"","name":"30D interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_10 (Events)","section":"Events"},{"id":"level_10_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_10 (Revenue)","section":"Events"},{"id":"level_10_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_10 Events per Conversion","section":"Events"},{"id":"level_10_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_10 (Conversions)","section":"Events"},{"id":"level_10_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_10 (Events)","section":"Events"},{"id":"level_10_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_10 (Converted User Size)","section":"Events"},{"id":"level_10_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_10 Rate (Events)","section":"Events"},{"id":"level_10_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_100 (Events)","section":"Events"},{"id":"level_100_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_100 (Revenue)","section":"Events"},{"id":"level_100_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_100 Events per Conversion","section":"Events"},{"id":"level_100_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_100 (Conversions)","section":"Events"},{"id":"level_100_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_100 (Events)","section":"Events"},{"id":"level_100_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_100 (Converted User Size)","section":"Events"},{"id":"level_100_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_100 Rate (Events)","section":"Events"},{"id":"level_100_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_1000 (Events)","section":"Events"},{"id":"level_1000_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_1000 (Revenue)","section":"Events"},{"id":"level_1000_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_10000 (Events)","section":"Events"},{"id":"level_10000_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_10000 (Revenue)","section":"Events"},{"id":"level_10000_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_15 (Events)","section":"Events"},{"id":"level_15_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_15 (Revenue)","section":"Events"},{"id":"level_15_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_15 Events per Conversion","section":"Events"},{"id":"level_15_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_15 (Conversions)","section":"Events"},{"id":"level_15_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_15 (Events)","section":"Events"},{"id":"level_15_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_15 (Converted User Size)","section":"Events"},{"id":"level_15_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_15 Rate (Events)","section":"Events"},{"id":"level_15_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_20 (Events)","section":"Events"},{"id":"level_20_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_20 (Revenue)","section":"Events"},{"id":"level_20_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_20 Events per Conversion","section":"Events"},{"id":"level_20_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_20 (Conversions)","section":"Events"},{"id":"level_20_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_20 (Events)","section":"Events"},{"id":"level_20_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_20 (Converted User Size)","section":"Events"},{"id":"level_20_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_20 Rate (Events)","section":"Events"},{"id":"level_20_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_200 (Events)","section":"Events"},{"id":"level_200_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_200 (Revenue)","section":"Events"},{"id":"level_200_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_200 Events per Conversion","section":"Events"},{"id":"level_200_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_200 (Conversions)","section":"Events"},{"id":"level_200_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_200 (Events)","section":"Events"},{"id":"level_200_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_200 (Converted User Size)","section":"Events"},{"id":"level_200_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_200 Rate (Events)","section":"Events"},{"id":"level_200_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_30 (Events)","section":"Events"},{"id":"level_30_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_30 (Revenue)","section":"Events"},{"id":"level_30_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_30 Events per Conversion","section":"Events"},{"id":"level_30_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_30 (Conversions)","section":"Events"},{"id":"level_30_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_30 (Events)","section":"Events"},{"id":"level_30_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_30 (Converted User Size)","section":"Events"},{"id":"level_30_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_30 Rate (Events)","section":"Events"},{"id":"level_30_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_300 (Events)","section":"Events"},{"id":"level_300_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_300 (Revenue)","section":"Events"},{"id":"level_300_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_300 Events per Conversion","section":"Events"},{"id":"level_300_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_300 (Conversions)","section":"Events"},{"id":"level_300_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_300 (Events)","section":"Events"},{"id":"level_300_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_300 (Converted User Size)","section":"Events"},{"id":"level_300_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_300 Rate (Events)","section":"Events"},{"id":"level_300_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_3000 (Events)","section":"Events"},{"id":"level_3000_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_3000 (Revenue)","section":"Events"},{"id":"level_3000_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_400 (Events)","section":"Events"},{"id":"level_400_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_400 (Revenue)","section":"Events"},{"id":"level_400_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_400 Events per Conversion","section":"Events"},{"id":"level_400_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_400 (Conversions)","section":"Events"},{"id":"level_400_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_400 (Events)","section":"Events"},{"id":"level_400_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_400 (Converted User Size)","section":"Events"},{"id":"level_400_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_400 Rate (Events)","section":"Events"},{"id":"level_400_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_5 (Events)","section":"Events"},{"id":"level_5_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_5 (Revenue)","section":"Events"},{"id":"level_5_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_5 Events per Conversion","section":"Events"},{"id":"level_5_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_5 (Conversions)","section":"Events"},{"id":"level_5_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_5 (Events)","section":"Events"},{"id":"level_5_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_5 (Converted User Size)","section":"Events"},{"id":"level_5_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_5 Rate (Events)","section":"Events"},{"id":"level_5_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_50 (Events)","section":"Events"},{"id":"level_50_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_50 (Revenue)","section":"Events"},{"id":"level_50_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_50 Events per Conversion","section":"Events"},{"id":"level_50_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_50 (Conversions)","section":"Events"},{"id":"level_50_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_50 (Events)","section":"Events"},{"id":"level_50_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_50 (Converted User Size)","section":"Events"},{"id":"level_50_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_50 Rate (Events)","section":"Events"},{"id":"level_50_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_500 (Events)","section":"Events"},{"id":"level_500_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_500 (Revenue)","section":"Events"},{"id":"level_500_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_500 Events per Conversion","section":"Events"},{"id":"level_500_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_500 (Conversions)","section":"Events"},{"id":"level_500_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_500 (Events)","section":"Events"},{"id":"level_500_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_500 (Converted User Size)","section":"Events"},{"id":"level_500_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_500 Rate (Events)","section":"Events"},{"id":"level_500_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_5000 (Events)","section":"Events"},{"id":"level_5000_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_5000 (Revenue)","section":"Events"},{"id":"level_5000_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_d30_events_cohort","formatting":"integer","short_name":"","name":"30D level_600 (Events)","section":"Events"},{"id":"level_600_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D level_600 (Revenue)","section":"Events"},{"id":"level_600_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D level_600 Events per Conversion","section":"Events"},{"id":"level_600_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D level_600 (Conversions)","section":"Events"},{"id":"level_600_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_600 (Events)","section":"Events"},{"id":"level_600_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D level_600 (Converted User Size)","section":"Events"},{"id":"level_600_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D level_600 Rate (Events)","section":"Events"},{"id":"level_600_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_d30_events_cohort","formatting":"integer","short_name":"","name":"30D purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_d30_events_cohort","formatting":"integer","short_name":"","name":"30D resultpage (Events)","section":"Events"},{"id":"resultpage_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D resultpage (Revenue)","section":"Events"},{"id":"resultpage_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D resultpage Events per Conversion","section":"Events"},{"id":"resultpage_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D resultpage (Conversions)","section":"Events"},{"id":"resultpage_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D resultpage Rate (Events)","section":"Events"},{"id":"resultpage_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_d30_events_cohort","formatting":"integer","short_name":"","name":"30D showprice (Events)","section":"Events"},{"id":"showprice_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D showprice (Revenue)","section":"Events"},{"id":"showprice_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D showprice Events per Conversion","section":"Events"},{"id":"showprice_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D showprice Revenue per Conversion","section":"Events"},{"id":"showprice_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D showprice (Conversions)","section":"Events"},{"id":"showprice_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per showprice (Events)","section":"Events"},{"id":"showprice_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D showprice (Converted User Size)","section":"Events"},{"id":"showprice_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D showprice Rate (Events)","section":"Events"},{"id":"showprice_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_d30_events_cohort","formatting":"integer","short_name":"","name":"30D subrevenue (Events)","section":"Events"},{"id":"subrevenue_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_d30_events_cohort","formatting":"integer","short_name":"","name":"30D subscribe (Events)","section":"Events"},{"id":"subscribe_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D subscribe (Revenue)","section":"Events"},{"id":"subscribe_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D subscribe Events per Conversion","section":"Events"},{"id":"subscribe_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D subscribe (Conversions)","section":"Events"},{"id":"subscribe_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D subscribe Rate (Events)","section":"Events"},{"id":"subscribe_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_d30_events_cohort","formatting":"integer","short_name":"","name":"30D uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_d30_events_cohort","formatting":"integer","short_name":"","name":"30D uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_d30_events_cohort","formatting":"integer","short_name":"","name":"30D uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_d30_events_cohort","formatting":"integer","short_name":"","name":"30D uacprice (Events)","section":"Events"},{"id":"uacprice_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D uacprice (Revenue)","section":"Events"},{"id":"uacprice_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D uacprice Events per Conversion","section":"Events"},{"id":"uacprice_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D uacprice (Conversions)","section":"Events"},{"id":"uacprice_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D uacprice Rate (Events)","section":"Events"},{"id":"uacprice_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_d30_events_cohort","formatting":"integer","short_name":"","name":"30D uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_d30_events_cohort","formatting":"integer","short_name":"","name":"30D vip_click (Events)","section":"Events"},{"id":"vip_click_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D vip_click (Revenue)","section":"Events"},{"id":"vip_click_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D vip_click Events per Conversion","section":"Events"},{"id":"vip_click_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D vip_click (Conversions)","section":"Events"},{"id":"vip_click_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_click Rate (Events)","section":"Events"},{"id":"vip_click_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_d30_events_cohort","formatting":"integer","short_name":"","name":"30D vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_d30_events_cohort","formatting":"integer","short_name":"","name":"30D vip_event (Events)","section":"Events"},{"id":"vip_event_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D vip_event (Revenue)","section":"Events"},{"id":"vip_event_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D vip_event Events per Conversion","section":"Events"},{"id":"vip_event_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D vip_event (Conversions)","section":"Events"},{"id":"vip_event_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_event Rate (Events)","section":"Events"},{"id":"vip_event_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_d30_events_cohort","formatting":"integer","short_name":"","name":"30D vip_show (Events)","section":"Events"},{"id":"vip_show_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D vip_show (Revenue)","section":"Events"},{"id":"vip_show_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D vip_show Events per Conversion","section":"Events"},{"id":"vip_show_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D vip_show (Conversions)","section":"Events"},{"id":"vip_show_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_show Rate (Events)","section":"Events"},{"id":"vip_show_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_d30_events_cohort","formatting":"integer","short_name":"","name":"30D vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d30_events_cohort","formatting":"integer","short_name":"","name":"30D Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d30_revenue_cohort","formatting":"money","short_name":"","name":"30D Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_d30_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"30D Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d30_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"30D Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_d30_conversions_cohort","formatting":"integer","short_name":"","name":"30D Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d30_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"30D Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_d30_events_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_d30_converted_user_size_cohort","formatting":"integer","short_name":"","name":"30D Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_d30_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"30D Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_d30_events_rate_cohort","formatting":"percent","short_name":"","name":"30D Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_d30_conversions_rate_cohort","formatting":"percent","short_name":"","name":"30D Waterpipe_enter_20 Rate (Conversions)","section":"Events"},{"id":"7d_reward_2600_m0_events_cohort","formatting":"integer","short_name":"","name":"0M 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_m0_events_cohort","formatting":"integer","short_name":"","name":"0M active (Events)","section":"Events"},{"id":"active_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M active (Revenue)","section":"Events"},{"id":"active_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M active Events per Conversion","section":"Events"},{"id":"active_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M active Revenue per Conversion","section":"Events"},{"id":"active_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M active (Conversions)","section":"Events"},{"id":"active_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M active (Conversion Distribution)","section":"Events"},{"id":"active_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per active (Events)","section":"Events"},{"id":"active_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M active (Converted User Size)","section":"Events"},{"id":"active_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per active (Conversions)","section":"Events"},{"id":"active_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M active Rate (Events)","section":"Events"},{"id":"active_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M active Rate (Conversions)","section":"Events"},{"id":"ad_click_m0_events_cohort","formatting":"integer","short_name":"","name":"0M ad_click (Events)","section":"Events"},{"id":"ad_click_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M ad_click (Revenue)","section":"Events"},{"id":"ad_click_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M ad_click Events per Conversion","section":"Events"},{"id":"ad_click_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M ad_click (Conversions)","section":"Events"},{"id":"ad_click_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M ad_click Rate (Events)","section":"Events"},{"id":"ad_click_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_m0_events_cohort","formatting":"integer","short_name":"","name":"0M ad_show (Events)","section":"Events"},{"id":"ad_show_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M ad_show (Revenue)","section":"Events"},{"id":"ad_show_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M ad_show Events per Conversion","section":"Events"},{"id":"ad_show_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M ad_show (Conversions)","section":"Events"},{"id":"ad_show_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M ad_show Rate (Events)","section":"Events"},{"id":"ad_show_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_m0_events_cohort","formatting":"integer","short_name":"","name":"0M adaction (Events)","section":"Events"},{"id":"adaction_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M adaction (Revenue)","section":"Events"},{"id":"adaction_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M adaction Events per Conversion","section":"Events"},{"id":"adaction_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M adaction Revenue per Conversion","section":"Events"},{"id":"adaction_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M adaction (Conversions)","section":"Events"},{"id":"adaction_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adaction (Events)","section":"Events"},{"id":"adaction_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M adaction (Converted User Size)","section":"Events"},{"id":"adaction_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M adaction Rate (Events)","section":"Events"},{"id":"adaction_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M adaction Rate (Conversions)","section":"Events"},{"id":"adclick_m0_events_cohort","formatting":"integer","short_name":"","name":"0M adclick (Events)","section":"Events"},{"id":"adclick_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M adclick (Revenue)","section":"Events"},{"id":"adclick_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M adclick Events per Conversion","section":"Events"},{"id":"adclick_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M adclick Revenue per Conversion","section":"Events"},{"id":"adclick_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M adclick (Conversions)","section":"Events"},{"id":"adclick_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adclick (Events)","section":"Events"},{"id":"adclick_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M adclick (Converted User Size)","section":"Events"},{"id":"adclick_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M adclick Rate (Events)","section":"Events"},{"id":"adclick_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_m0_events_cohort","formatting":"integer","short_name":"","name":"0M adrevenue (Events)","section":"Events"},{"id":"adrevenue_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_m0_events_cohort","formatting":"integer","short_name":"","name":"0M adshow (Events)","section":"Events"},{"id":"adshow_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M adshow (Revenue)","section":"Events"},{"id":"adshow_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M adshow Events per Conversion","section":"Events"},{"id":"adshow_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M adshow Revenue per Conversion","section":"Events"},{"id":"adshow_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M adshow (Conversions)","section":"Events"},{"id":"adshow_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adshow (Events)","section":"Events"},{"id":"adshow_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M adshow (Converted User Size)","section":"Events"},{"id":"adshow_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M adshow Rate (Events)","section":"Events"},{"id":"adshow_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M adshow Rate (Conversions)","section":"Events"},{"id":"adv_m0_events_cohort","formatting":"integer","short_name":"","name":"0M adv (Events)","section":"Events"},{"id":"adv_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M adv (Revenue)","section":"Events"},{"id":"adv_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M adv Events per Conversion","section":"Events"},{"id":"adv_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M adv Revenue per Conversion","section":"Events"},{"id":"adv_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M adv (Conversions)","section":"Events"},{"id":"adv_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M adv (Conversion Distribution)","section":"Events"},{"id":"adv_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adv (Events)","section":"Events"},{"id":"adv_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M adv (Converted User Size)","section":"Events"},{"id":"adv_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per adv (Conversions)","section":"Events"},{"id":"adv_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M adv Rate (Events)","section":"Events"},{"id":"adv_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M adv Rate (Conversions)","section":"Events"},{"id":"analytics_m0_events_cohort","formatting":"integer","short_name":"","name":"0M analytics (Events)","section":"Events"},{"id":"analytics_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M analytics (Revenue)","section":"Events"},{"id":"analytics_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M analytics Events per Conversion","section":"Events"},{"id":"analytics_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M analytics Revenue per Conversion","section":"Events"},{"id":"analytics_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M analytics (Conversions)","section":"Events"},{"id":"analytics_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per analytics (Events)","section":"Events"},{"id":"analytics_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M analytics (Converted User Size)","section":"Events"},{"id":"analytics_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M analytics Rate (Events)","section":"Events"},{"id":"analytics_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_m0_events_cohort","formatting":"integer","short_name":"","name":"0M buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_m0_events_cohort","formatting":"integer","short_name":"","name":"0M connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_10 (Events)","section":"Events"},{"id":"enter_10_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_10 (Revenue)","section":"Events"},{"id":"enter_10_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_10 (Conversions)","section":"Events"},{"id":"enter_10_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_100 (Events)","section":"Events"},{"id":"enter_100_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_100 (Revenue)","section":"Events"},{"id":"enter_100_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_100 (Conversions)","section":"Events"},{"id":"enter_100_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_15 (Events)","section":"Events"},{"id":"enter_15_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_15 (Revenue)","section":"Events"},{"id":"enter_15_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_15 (Conversions)","section":"Events"},{"id":"enter_15_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_20 (Events)","section":"Events"},{"id":"enter_20_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_20 (Revenue)","section":"Events"},{"id":"enter_20_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_20 (Conversions)","section":"Events"},{"id":"enter_20_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_30 (Events)","section":"Events"},{"id":"enter_30_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_30 (Revenue)","section":"Events"},{"id":"enter_30_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_30 (Conversions)","section":"Events"},{"id":"enter_30_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_40 (Events)","section":"Events"},{"id":"enter_40_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_40 (Revenue)","section":"Events"},{"id":"enter_40_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_40 (Conversions)","section":"Events"},{"id":"enter_40_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_50 (Events)","section":"Events"},{"id":"enter_50_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_50 (Revenue)","section":"Events"},{"id":"enter_50_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_50 (Conversions)","section":"Events"},{"id":"enter_50_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_60 (Events)","section":"Events"},{"id":"enter_60_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_60 (Revenue)","section":"Events"},{"id":"enter_60_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_60 (Conversions)","section":"Events"},{"id":"enter_60_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_70 (Events)","section":"Events"},{"id":"enter_70_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_70 (Revenue)","section":"Events"},{"id":"enter_70_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_70 (Conversions)","section":"Events"},{"id":"enter_70_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_80 (Events)","section":"Events"},{"id":"enter_80_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_80 (Revenue)","section":"Events"},{"id":"enter_80_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_80 (Conversions)","section":"Events"},{"id":"enter_80_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_m0_events_cohort","formatting":"integer","short_name":"","name":"0M enter_90 (Events)","section":"Events"},{"id":"enter_90_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M enter_90 (Revenue)","section":"Events"},{"id":"enter_90_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M enter_90 (Conversions)","section":"Events"},{"id":"enter_90_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_m0_events_cohort","formatting":"integer","short_name":"","name":"0M EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_m0_events_cohort","formatting":"integer","short_name":"","name":"0M EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_m0_events_cohort","formatting":"integer","short_name":"","name":"0M FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_m0_events_cohort","formatting":"integer","short_name":"","name":"0M FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_m0_events_cohort","formatting":"integer","short_name":"","name":"0M FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_m0_events_cohort","formatting":"integer","short_name":"","name":"0M General Revenue (Events)","section":"Events"},{"id":"general revenue_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M General Revenue (Revenue)","section":"Events"},{"id":"general revenue_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M General Revenue (Conversions)","section":"Events"},{"id":"general revenue_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_m0_events_cohort","formatting":"integer","short_name":"","name":"0M get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_m0_events_cohort","formatting":"integer","short_name":"","name":"0M get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_m0_events_cohort","formatting":"integer","short_name":"","name":"0M get_video_time (Events)","section":"Events"},{"id":"get_video_time_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_m0_events_cohort","formatting":"integer","short_name":"","name":"0M iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_m0_events_cohort","formatting":"integer","short_name":"","name":"0M IAP (Events)","section":"Events"},{"id":"iap_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M IAP (Revenue)","section":"Events"},{"id":"iap_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M IAP Events per Conversion","section":"Events"},{"id":"iap_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M IAP Revenue per Conversion","section":"Events"},{"id":"iap_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M IAP (Conversions)","section":"Events"},{"id":"iap_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M IAP (Conversion Distribution)","section":"Events"},{"id":"iap_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per IAP (Events)","section":"Events"},{"id":"iap_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M IAP (Converted User Size)","section":"Events"},{"id":"iap_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per IAP (Conversions)","section":"Events"},{"id":"iap_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M IAP Rate (Events)","section":"Events"},{"id":"iap_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_m0_events_cohort","formatting":"integer","short_name":"","name":"0M interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_m0_events_cohort","formatting":"integer","short_name":"","name":"0M interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_10 (Events)","section":"Events"},{"id":"level_10_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_10 (Revenue)","section":"Events"},{"id":"level_10_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_10 Events per Conversion","section":"Events"},{"id":"level_10_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_10 (Conversions)","section":"Events"},{"id":"level_10_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_10 (Events)","section":"Events"},{"id":"level_10_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_10 (Converted User Size)","section":"Events"},{"id":"level_10_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_10 Rate (Events)","section":"Events"},{"id":"level_10_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_100 (Events)","section":"Events"},{"id":"level_100_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_100 (Revenue)","section":"Events"},{"id":"level_100_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_100 Events per Conversion","section":"Events"},{"id":"level_100_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_100 (Conversions)","section":"Events"},{"id":"level_100_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_100 (Events)","section":"Events"},{"id":"level_100_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_100 (Converted User Size)","section":"Events"},{"id":"level_100_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_100 Rate (Events)","section":"Events"},{"id":"level_100_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_1000 (Events)","section":"Events"},{"id":"level_1000_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_1000 (Revenue)","section":"Events"},{"id":"level_1000_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_1000 (Conversions)","section":"Events"},{"id":"level_1000_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_10000 (Events)","section":"Events"},{"id":"level_10000_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_10000 (Revenue)","section":"Events"},{"id":"level_10000_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_10000 (Conversions)","section":"Events"},{"id":"level_10000_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_15 (Events)","section":"Events"},{"id":"level_15_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_15 (Revenue)","section":"Events"},{"id":"level_15_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_15 Events per Conversion","section":"Events"},{"id":"level_15_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_15 (Conversions)","section":"Events"},{"id":"level_15_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_15 (Events)","section":"Events"},{"id":"level_15_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_15 (Converted User Size)","section":"Events"},{"id":"level_15_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_15 Rate (Events)","section":"Events"},{"id":"level_15_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_20 (Events)","section":"Events"},{"id":"level_20_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_20 (Revenue)","section":"Events"},{"id":"level_20_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_20 Events per Conversion","section":"Events"},{"id":"level_20_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_20 (Conversions)","section":"Events"},{"id":"level_20_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_20 (Events)","section":"Events"},{"id":"level_20_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_20 (Converted User Size)","section":"Events"},{"id":"level_20_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_20 Rate (Events)","section":"Events"},{"id":"level_20_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_200 (Events)","section":"Events"},{"id":"level_200_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_200 (Revenue)","section":"Events"},{"id":"level_200_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_200 Events per Conversion","section":"Events"},{"id":"level_200_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_200 (Conversions)","section":"Events"},{"id":"level_200_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_200 (Events)","section":"Events"},{"id":"level_200_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_200 (Converted User Size)","section":"Events"},{"id":"level_200_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_200 Rate (Events)","section":"Events"},{"id":"level_200_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_30 (Events)","section":"Events"},{"id":"level_30_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_30 (Revenue)","section":"Events"},{"id":"level_30_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_30 Events per Conversion","section":"Events"},{"id":"level_30_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_30 (Conversions)","section":"Events"},{"id":"level_30_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_30 (Events)","section":"Events"},{"id":"level_30_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_30 (Converted User Size)","section":"Events"},{"id":"level_30_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_30 Rate (Events)","section":"Events"},{"id":"level_30_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_300 (Events)","section":"Events"},{"id":"level_300_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_300 (Revenue)","section":"Events"},{"id":"level_300_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_300 Events per Conversion","section":"Events"},{"id":"level_300_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_300 (Conversions)","section":"Events"},{"id":"level_300_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_300 (Events)","section":"Events"},{"id":"level_300_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_300 (Converted User Size)","section":"Events"},{"id":"level_300_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_300 Rate (Events)","section":"Events"},{"id":"level_300_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_3000 (Events)","section":"Events"},{"id":"level_3000_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_3000 (Revenue)","section":"Events"},{"id":"level_3000_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_3000 (Conversions)","section":"Events"},{"id":"level_3000_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_400 (Events)","section":"Events"},{"id":"level_400_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_400 (Revenue)","section":"Events"},{"id":"level_400_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_400 Events per Conversion","section":"Events"},{"id":"level_400_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_400 (Conversions)","section":"Events"},{"id":"level_400_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_400 (Events)","section":"Events"},{"id":"level_400_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_400 (Converted User Size)","section":"Events"},{"id":"level_400_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_400 Rate (Events)","section":"Events"},{"id":"level_400_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_5 (Events)","section":"Events"},{"id":"level_5_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_5 (Revenue)","section":"Events"},{"id":"level_5_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_5 Events per Conversion","section":"Events"},{"id":"level_5_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_5 (Conversions)","section":"Events"},{"id":"level_5_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_5 (Events)","section":"Events"},{"id":"level_5_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_5 (Converted User Size)","section":"Events"},{"id":"level_5_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_5 Rate (Events)","section":"Events"},{"id":"level_5_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_50 (Events)","section":"Events"},{"id":"level_50_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_50 (Revenue)","section":"Events"},{"id":"level_50_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_50 Events per Conversion","section":"Events"},{"id":"level_50_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_50 (Conversions)","section":"Events"},{"id":"level_50_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_50 (Events)","section":"Events"},{"id":"level_50_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_50 (Converted User Size)","section":"Events"},{"id":"level_50_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_50 Rate (Events)","section":"Events"},{"id":"level_50_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_500 (Events)","section":"Events"},{"id":"level_500_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_500 (Revenue)","section":"Events"},{"id":"level_500_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_500 Events per Conversion","section":"Events"},{"id":"level_500_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_500 (Conversions)","section":"Events"},{"id":"level_500_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_500 (Events)","section":"Events"},{"id":"level_500_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_500 (Converted User Size)","section":"Events"},{"id":"level_500_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_500 Rate (Events)","section":"Events"},{"id":"level_500_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_5000 (Events)","section":"Events"},{"id":"level_5000_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_5000 (Revenue)","section":"Events"},{"id":"level_5000_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_5000 (Conversions)","section":"Events"},{"id":"level_5000_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_m0_events_cohort","formatting":"integer","short_name":"","name":"0M level_600 (Events)","section":"Events"},{"id":"level_600_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M level_600 (Revenue)","section":"Events"},{"id":"level_600_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M level_600 Events per Conversion","section":"Events"},{"id":"level_600_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M level_600 (Conversions)","section":"Events"},{"id":"level_600_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_600 (Events)","section":"Events"},{"id":"level_600_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M level_600 (Converted User Size)","section":"Events"},{"id":"level_600_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M level_600 Rate (Events)","section":"Events"},{"id":"level_600_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_m0_events_cohort","formatting":"integer","short_name":"","name":"0M purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_m0_events_cohort","formatting":"integer","short_name":"","name":"0M resultpage (Events)","section":"Events"},{"id":"resultpage_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M resultpage (Revenue)","section":"Events"},{"id":"resultpage_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M resultpage Events per Conversion","section":"Events"},{"id":"resultpage_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M resultpage (Conversions)","section":"Events"},{"id":"resultpage_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M resultpage Rate (Events)","section":"Events"},{"id":"resultpage_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_m0_events_cohort","formatting":"integer","short_name":"","name":"0M showprice (Events)","section":"Events"},{"id":"showprice_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M showprice (Revenue)","section":"Events"},{"id":"showprice_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M showprice Events per Conversion","section":"Events"},{"id":"showprice_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M showprice Revenue per Conversion","section":"Events"},{"id":"showprice_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M showprice (Conversions)","section":"Events"},{"id":"showprice_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per showprice (Events)","section":"Events"},{"id":"showprice_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M showprice (Converted User Size)","section":"Events"},{"id":"showprice_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M showprice Rate (Events)","section":"Events"},{"id":"showprice_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_m0_events_cohort","formatting":"integer","short_name":"","name":"0M subrevenue (Events)","section":"Events"},{"id":"subrevenue_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_m0_events_cohort","formatting":"integer","short_name":"","name":"0M subscribe (Events)","section":"Events"},{"id":"subscribe_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M subscribe (Revenue)","section":"Events"},{"id":"subscribe_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M subscribe Events per Conversion","section":"Events"},{"id":"subscribe_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M subscribe (Conversions)","section":"Events"},{"id":"subscribe_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M subscribe Rate (Events)","section":"Events"},{"id":"subscribe_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_m0_events_cohort","formatting":"integer","short_name":"","name":"0M uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_m0_events_cohort","formatting":"integer","short_name":"","name":"0M uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_m0_events_cohort","formatting":"integer","short_name":"","name":"0M uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_m0_events_cohort","formatting":"integer","short_name":"","name":"0M uacprice (Events)","section":"Events"},{"id":"uacprice_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M uacprice (Revenue)","section":"Events"},{"id":"uacprice_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M uacprice Events per Conversion","section":"Events"},{"id":"uacprice_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M uacprice (Conversions)","section":"Events"},{"id":"uacprice_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M uacprice Rate (Events)","section":"Events"},{"id":"uacprice_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_m0_events_cohort","formatting":"integer","short_name":"","name":"0M uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_m0_events_cohort","formatting":"integer","short_name":"","name":"0M vip_click (Events)","section":"Events"},{"id":"vip_click_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M vip_click (Revenue)","section":"Events"},{"id":"vip_click_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M vip_click Events per Conversion","section":"Events"},{"id":"vip_click_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M vip_click (Conversions)","section":"Events"},{"id":"vip_click_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_click Rate (Events)","section":"Events"},{"id":"vip_click_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_m0_events_cohort","formatting":"integer","short_name":"","name":"0M vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_m0_events_cohort","formatting":"integer","short_name":"","name":"0M vip_event (Events)","section":"Events"},{"id":"vip_event_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M vip_event (Revenue)","section":"Events"},{"id":"vip_event_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M vip_event Events per Conversion","section":"Events"},{"id":"vip_event_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M vip_event (Conversions)","section":"Events"},{"id":"vip_event_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_event Rate (Events)","section":"Events"},{"id":"vip_event_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_m0_events_cohort","formatting":"integer","short_name":"","name":"0M vip_show (Events)","section":"Events"},{"id":"vip_show_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M vip_show (Revenue)","section":"Events"},{"id":"vip_show_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M vip_show Events per Conversion","section":"Events"},{"id":"vip_show_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M vip_show (Conversions)","section":"Events"},{"id":"vip_show_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_show Rate (Events)","section":"Events"},{"id":"vip_show_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_m0_events_cohort","formatting":"integer","short_name":"","name":"0M vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m0_events_cohort","formatting":"integer","short_name":"","name":"0M Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_m0_revenue_cohort","formatting":"money","short_name":"","name":"0M Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_m0_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"0M Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_m0_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"0M Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_m0_conversions_cohort","formatting":"integer","short_name":"","name":"0M Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m0_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"0M Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_m0_events_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_m0_converted_user_size_cohort","formatting":"integer","short_name":"","name":"0M Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_m0_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"0M Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m0_events_rate_cohort","formatting":"percent","short_name":"","name":"0M Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_m0_conversions_rate_cohort","formatting":"percent","short_name":"","name":"0M Waterpipe_enter_20 Rate (Conversions)","section":"Events"},{"id":"7d_reward_2600_m1_events_cohort","formatting":"integer","short_name":"","name":"1M 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_m1_events_cohort","formatting":"integer","short_name":"","name":"1M active (Events)","section":"Events"},{"id":"active_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M active (Revenue)","section":"Events"},{"id":"active_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M active Events per Conversion","section":"Events"},{"id":"active_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M active Revenue per Conversion","section":"Events"},{"id":"active_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M active (Conversions)","section":"Events"},{"id":"active_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M active (Conversion Distribution)","section":"Events"},{"id":"active_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per active (Events)","section":"Events"},{"id":"active_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M active (Converted User Size)","section":"Events"},{"id":"active_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per active (Conversions)","section":"Events"},{"id":"active_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M active Rate (Events)","section":"Events"},{"id":"active_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M active Rate (Conversions)","section":"Events"},{"id":"ad_click_m1_events_cohort","formatting":"integer","short_name":"","name":"1M ad_click (Events)","section":"Events"},{"id":"ad_click_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M ad_click (Revenue)","section":"Events"},{"id":"ad_click_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M ad_click Events per Conversion","section":"Events"},{"id":"ad_click_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M ad_click (Conversions)","section":"Events"},{"id":"ad_click_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M ad_click Rate (Events)","section":"Events"},{"id":"ad_click_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_m1_events_cohort","formatting":"integer","short_name":"","name":"1M ad_show (Events)","section":"Events"},{"id":"ad_show_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M ad_show (Revenue)","section":"Events"},{"id":"ad_show_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M ad_show Events per Conversion","section":"Events"},{"id":"ad_show_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M ad_show (Conversions)","section":"Events"},{"id":"ad_show_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M ad_show Rate (Events)","section":"Events"},{"id":"ad_show_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_m1_events_cohort","formatting":"integer","short_name":"","name":"1M adaction (Events)","section":"Events"},{"id":"adaction_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M adaction (Revenue)","section":"Events"},{"id":"adaction_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M adaction Events per Conversion","section":"Events"},{"id":"adaction_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M adaction Revenue per Conversion","section":"Events"},{"id":"adaction_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M adaction (Conversions)","section":"Events"},{"id":"adaction_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adaction (Events)","section":"Events"},{"id":"adaction_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M adaction (Converted User Size)","section":"Events"},{"id":"adaction_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M adaction Rate (Events)","section":"Events"},{"id":"adaction_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M adaction Rate (Conversions)","section":"Events"},{"id":"adclick_m1_events_cohort","formatting":"integer","short_name":"","name":"1M adclick (Events)","section":"Events"},{"id":"adclick_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M adclick (Revenue)","section":"Events"},{"id":"adclick_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M adclick Events per Conversion","section":"Events"},{"id":"adclick_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M adclick Revenue per Conversion","section":"Events"},{"id":"adclick_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M adclick (Conversions)","section":"Events"},{"id":"adclick_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adclick (Events)","section":"Events"},{"id":"adclick_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M adclick (Converted User Size)","section":"Events"},{"id":"adclick_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M adclick Rate (Events)","section":"Events"},{"id":"adclick_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_m1_events_cohort","formatting":"integer","short_name":"","name":"1M adrevenue (Events)","section":"Events"},{"id":"adrevenue_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_m1_events_cohort","formatting":"integer","short_name":"","name":"1M adshow (Events)","section":"Events"},{"id":"adshow_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M adshow (Revenue)","section":"Events"},{"id":"adshow_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M adshow Events per Conversion","section":"Events"},{"id":"adshow_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M adshow Revenue per Conversion","section":"Events"},{"id":"adshow_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M adshow (Conversions)","section":"Events"},{"id":"adshow_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adshow (Events)","section":"Events"},{"id":"adshow_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M adshow (Converted User Size)","section":"Events"},{"id":"adshow_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M adshow Rate (Events)","section":"Events"},{"id":"adshow_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M adshow Rate (Conversions)","section":"Events"},{"id":"adv_m1_events_cohort","formatting":"integer","short_name":"","name":"1M adv (Events)","section":"Events"},{"id":"adv_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M adv (Revenue)","section":"Events"},{"id":"adv_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M adv Events per Conversion","section":"Events"},{"id":"adv_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M adv Revenue per Conversion","section":"Events"},{"id":"adv_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M adv (Conversions)","section":"Events"},{"id":"adv_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M adv (Conversion Distribution)","section":"Events"},{"id":"adv_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adv (Events)","section":"Events"},{"id":"adv_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M adv (Converted User Size)","section":"Events"},{"id":"adv_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per adv (Conversions)","section":"Events"},{"id":"adv_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M adv Rate (Events)","section":"Events"},{"id":"adv_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M adv Rate (Conversions)","section":"Events"},{"id":"analytics_m1_events_cohort","formatting":"integer","short_name":"","name":"1M analytics (Events)","section":"Events"},{"id":"analytics_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M analytics (Revenue)","section":"Events"},{"id":"analytics_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M analytics Events per Conversion","section":"Events"},{"id":"analytics_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M analytics Revenue per Conversion","section":"Events"},{"id":"analytics_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M analytics (Conversions)","section":"Events"},{"id":"analytics_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per analytics (Events)","section":"Events"},{"id":"analytics_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M analytics (Converted User Size)","section":"Events"},{"id":"analytics_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M analytics Rate (Events)","section":"Events"},{"id":"analytics_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_m1_events_cohort","formatting":"integer","short_name":"","name":"1M buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_m1_events_cohort","formatting":"integer","short_name":"","name":"1M connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_10 (Events)","section":"Events"},{"id":"enter_10_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_10 (Revenue)","section":"Events"},{"id":"enter_10_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_10 (Conversions)","section":"Events"},{"id":"enter_10_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_100 (Events)","section":"Events"},{"id":"enter_100_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_100 (Revenue)","section":"Events"},{"id":"enter_100_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_100 (Conversions)","section":"Events"},{"id":"enter_100_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_15 (Events)","section":"Events"},{"id":"enter_15_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_15 (Revenue)","section":"Events"},{"id":"enter_15_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_15 (Conversions)","section":"Events"},{"id":"enter_15_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_20 (Events)","section":"Events"},{"id":"enter_20_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_20 (Revenue)","section":"Events"},{"id":"enter_20_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_20 (Conversions)","section":"Events"},{"id":"enter_20_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_30 (Events)","section":"Events"},{"id":"enter_30_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_30 (Revenue)","section":"Events"},{"id":"enter_30_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_30 (Conversions)","section":"Events"},{"id":"enter_30_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_40 (Events)","section":"Events"},{"id":"enter_40_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_40 (Revenue)","section":"Events"},{"id":"enter_40_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_40 (Conversions)","section":"Events"},{"id":"enter_40_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_50 (Events)","section":"Events"},{"id":"enter_50_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_50 (Revenue)","section":"Events"},{"id":"enter_50_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_50 (Conversions)","section":"Events"},{"id":"enter_50_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_60 (Events)","section":"Events"},{"id":"enter_60_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_60 (Revenue)","section":"Events"},{"id":"enter_60_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_60 (Conversions)","section":"Events"},{"id":"enter_60_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_70 (Events)","section":"Events"},{"id":"enter_70_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_70 (Revenue)","section":"Events"},{"id":"enter_70_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_70 (Conversions)","section":"Events"},{"id":"enter_70_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_80 (Events)","section":"Events"},{"id":"enter_80_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_80 (Revenue)","section":"Events"},{"id":"enter_80_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_80 (Conversions)","section":"Events"},{"id":"enter_80_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_m1_events_cohort","formatting":"integer","short_name":"","name":"1M enter_90 (Events)","section":"Events"},{"id":"enter_90_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M enter_90 (Revenue)","section":"Events"},{"id":"enter_90_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M enter_90 (Conversions)","section":"Events"},{"id":"enter_90_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_m1_events_cohort","formatting":"integer","short_name":"","name":"1M EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_m1_events_cohort","formatting":"integer","short_name":"","name":"1M EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_m1_events_cohort","formatting":"integer","short_name":"","name":"1M FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_m1_events_cohort","formatting":"integer","short_name":"","name":"1M FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_m1_events_cohort","formatting":"integer","short_name":"","name":"1M FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_m1_events_cohort","formatting":"integer","short_name":"","name":"1M General Revenue (Events)","section":"Events"},{"id":"general revenue_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M General Revenue (Revenue)","section":"Events"},{"id":"general revenue_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M General Revenue (Conversions)","section":"Events"},{"id":"general revenue_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_m1_events_cohort","formatting":"integer","short_name":"","name":"1M get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_m1_events_cohort","formatting":"integer","short_name":"","name":"1M get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_m1_events_cohort","formatting":"integer","short_name":"","name":"1M get_video_time (Events)","section":"Events"},{"id":"get_video_time_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_m1_events_cohort","formatting":"integer","short_name":"","name":"1M iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_m1_events_cohort","formatting":"integer","short_name":"","name":"1M IAP (Events)","section":"Events"},{"id":"iap_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M IAP (Revenue)","section":"Events"},{"id":"iap_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M IAP Events per Conversion","section":"Events"},{"id":"iap_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M IAP Revenue per Conversion","section":"Events"},{"id":"iap_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M IAP (Conversions)","section":"Events"},{"id":"iap_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M IAP (Conversion Distribution)","section":"Events"},{"id":"iap_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per IAP (Events)","section":"Events"},{"id":"iap_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M IAP (Converted User Size)","section":"Events"},{"id":"iap_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per IAP (Conversions)","section":"Events"},{"id":"iap_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M IAP Rate (Events)","section":"Events"},{"id":"iap_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_m1_events_cohort","formatting":"integer","short_name":"","name":"1M interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_m1_events_cohort","formatting":"integer","short_name":"","name":"1M interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_10 (Events)","section":"Events"},{"id":"level_10_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_10 (Revenue)","section":"Events"},{"id":"level_10_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_10 Events per Conversion","section":"Events"},{"id":"level_10_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_10 (Conversions)","section":"Events"},{"id":"level_10_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_10 (Events)","section":"Events"},{"id":"level_10_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_10 (Converted User Size)","section":"Events"},{"id":"level_10_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_10 Rate (Events)","section":"Events"},{"id":"level_10_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_100 (Events)","section":"Events"},{"id":"level_100_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_100 (Revenue)","section":"Events"},{"id":"level_100_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_100 Events per Conversion","section":"Events"},{"id":"level_100_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_100 (Conversions)","section":"Events"},{"id":"level_100_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_100 (Events)","section":"Events"},{"id":"level_100_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_100 (Converted User Size)","section":"Events"},{"id":"level_100_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_100 Rate (Events)","section":"Events"},{"id":"level_100_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_1000 (Events)","section":"Events"},{"id":"level_1000_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_1000 (Revenue)","section":"Events"},{"id":"level_1000_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_1000 (Conversions)","section":"Events"},{"id":"level_1000_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_10000 (Events)","section":"Events"},{"id":"level_10000_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_10000 (Revenue)","section":"Events"},{"id":"level_10000_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_10000 (Conversions)","section":"Events"},{"id":"level_10000_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_15 (Events)","section":"Events"},{"id":"level_15_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_15 (Revenue)","section":"Events"},{"id":"level_15_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_15 Events per Conversion","section":"Events"},{"id":"level_15_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_15 (Conversions)","section":"Events"},{"id":"level_15_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_15 (Events)","section":"Events"},{"id":"level_15_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_15 (Converted User Size)","section":"Events"},{"id":"level_15_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_15 Rate (Events)","section":"Events"},{"id":"level_15_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_20 (Events)","section":"Events"},{"id":"level_20_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_20 (Revenue)","section":"Events"},{"id":"level_20_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_20 Events per Conversion","section":"Events"},{"id":"level_20_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_20 (Conversions)","section":"Events"},{"id":"level_20_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_20 (Events)","section":"Events"},{"id":"level_20_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_20 (Converted User Size)","section":"Events"},{"id":"level_20_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_20 Rate (Events)","section":"Events"},{"id":"level_20_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_200 (Events)","section":"Events"},{"id":"level_200_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_200 (Revenue)","section":"Events"},{"id":"level_200_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_200 Events per Conversion","section":"Events"},{"id":"level_200_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_200 (Conversions)","section":"Events"},{"id":"level_200_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_200 (Events)","section":"Events"},{"id":"level_200_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_200 (Converted User Size)","section":"Events"},{"id":"level_200_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_200 Rate (Events)","section":"Events"},{"id":"level_200_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_30 (Events)","section":"Events"},{"id":"level_30_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_30 (Revenue)","section":"Events"},{"id":"level_30_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_30 Events per Conversion","section":"Events"},{"id":"level_30_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_30 (Conversions)","section":"Events"},{"id":"level_30_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_30 (Events)","section":"Events"},{"id":"level_30_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_30 (Converted User Size)","section":"Events"},{"id":"level_30_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_30 Rate (Events)","section":"Events"},{"id":"level_30_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_300 (Events)","section":"Events"},{"id":"level_300_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_300 (Revenue)","section":"Events"},{"id":"level_300_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_300 Events per Conversion","section":"Events"},{"id":"level_300_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_300 (Conversions)","section":"Events"},{"id":"level_300_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_300 (Events)","section":"Events"},{"id":"level_300_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_300 (Converted User Size)","section":"Events"},{"id":"level_300_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_300 Rate (Events)","section":"Events"},{"id":"level_300_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_3000 (Events)","section":"Events"},{"id":"level_3000_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_3000 (Revenue)","section":"Events"},{"id":"level_3000_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_3000 (Conversions)","section":"Events"},{"id":"level_3000_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_400 (Events)","section":"Events"},{"id":"level_400_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_400 (Revenue)","section":"Events"},{"id":"level_400_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_400 Events per Conversion","section":"Events"},{"id":"level_400_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_400 (Conversions)","section":"Events"},{"id":"level_400_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_400 (Events)","section":"Events"},{"id":"level_400_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_400 (Converted User Size)","section":"Events"},{"id":"level_400_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_400 Rate (Events)","section":"Events"},{"id":"level_400_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_5 (Events)","section":"Events"},{"id":"level_5_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_5 (Revenue)","section":"Events"},{"id":"level_5_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_5 Events per Conversion","section":"Events"},{"id":"level_5_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_5 (Conversions)","section":"Events"},{"id":"level_5_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_5 (Events)","section":"Events"},{"id":"level_5_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_5 (Converted User Size)","section":"Events"},{"id":"level_5_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_5 Rate (Events)","section":"Events"},{"id":"level_5_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_50 (Events)","section":"Events"},{"id":"level_50_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_50 (Revenue)","section":"Events"},{"id":"level_50_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_50 Events per Conversion","section":"Events"},{"id":"level_50_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_50 (Conversions)","section":"Events"},{"id":"level_50_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_50 (Events)","section":"Events"},{"id":"level_50_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_50 (Converted User Size)","section":"Events"},{"id":"level_50_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_50 Rate (Events)","section":"Events"},{"id":"level_50_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_500 (Events)","section":"Events"},{"id":"level_500_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_500 (Revenue)","section":"Events"},{"id":"level_500_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_500 Events per Conversion","section":"Events"},{"id":"level_500_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_500 (Conversions)","section":"Events"},{"id":"level_500_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_500 (Events)","section":"Events"},{"id":"level_500_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_500 (Converted User Size)","section":"Events"},{"id":"level_500_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_500 Rate (Events)","section":"Events"},{"id":"level_500_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_5000 (Events)","section":"Events"},{"id":"level_5000_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_5000 (Revenue)","section":"Events"},{"id":"level_5000_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_5000 (Conversions)","section":"Events"},{"id":"level_5000_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_m1_events_cohort","formatting":"integer","short_name":"","name":"1M level_600 (Events)","section":"Events"},{"id":"level_600_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M level_600 (Revenue)","section":"Events"},{"id":"level_600_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M level_600 Events per Conversion","section":"Events"},{"id":"level_600_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M level_600 (Conversions)","section":"Events"},{"id":"level_600_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_600 (Events)","section":"Events"},{"id":"level_600_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M level_600 (Converted User Size)","section":"Events"},{"id":"level_600_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M level_600 Rate (Events)","section":"Events"},{"id":"level_600_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_m1_events_cohort","formatting":"integer","short_name":"","name":"1M purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_m1_events_cohort","formatting":"integer","short_name":"","name":"1M resultpage (Events)","section":"Events"},{"id":"resultpage_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M resultpage (Revenue)","section":"Events"},{"id":"resultpage_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M resultpage Events per Conversion","section":"Events"},{"id":"resultpage_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M resultpage (Conversions)","section":"Events"},{"id":"resultpage_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M resultpage Rate (Events)","section":"Events"},{"id":"resultpage_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_m1_events_cohort","formatting":"integer","short_name":"","name":"1M showprice (Events)","section":"Events"},{"id":"showprice_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M showprice (Revenue)","section":"Events"},{"id":"showprice_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M showprice Events per Conversion","section":"Events"},{"id":"showprice_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M showprice Revenue per Conversion","section":"Events"},{"id":"showprice_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M showprice (Conversions)","section":"Events"},{"id":"showprice_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per showprice (Events)","section":"Events"},{"id":"showprice_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M showprice (Converted User Size)","section":"Events"},{"id":"showprice_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M showprice Rate (Events)","section":"Events"},{"id":"showprice_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_m1_events_cohort","formatting":"integer","short_name":"","name":"1M subrevenue (Events)","section":"Events"},{"id":"subrevenue_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_m1_events_cohort","formatting":"integer","short_name":"","name":"1M subscribe (Events)","section":"Events"},{"id":"subscribe_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M subscribe (Revenue)","section":"Events"},{"id":"subscribe_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M subscribe Events per Conversion","section":"Events"},{"id":"subscribe_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M subscribe (Conversions)","section":"Events"},{"id":"subscribe_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M subscribe Rate (Events)","section":"Events"},{"id":"subscribe_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_m1_events_cohort","formatting":"integer","short_name":"","name":"1M uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_m1_events_cohort","formatting":"integer","short_name":"","name":"1M uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_m1_events_cohort","formatting":"integer","short_name":"","name":"1M uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_m1_events_cohort","formatting":"integer","short_name":"","name":"1M uacprice (Events)","section":"Events"},{"id":"uacprice_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M uacprice (Revenue)","section":"Events"},{"id":"uacprice_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M uacprice Events per Conversion","section":"Events"},{"id":"uacprice_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M uacprice (Conversions)","section":"Events"},{"id":"uacprice_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M uacprice Rate (Events)","section":"Events"},{"id":"uacprice_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_m1_events_cohort","formatting":"integer","short_name":"","name":"1M uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_m1_events_cohort","formatting":"integer","short_name":"","name":"1M vip_click (Events)","section":"Events"},{"id":"vip_click_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M vip_click (Revenue)","section":"Events"},{"id":"vip_click_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M vip_click Events per Conversion","section":"Events"},{"id":"vip_click_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M vip_click (Conversions)","section":"Events"},{"id":"vip_click_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_click Rate (Events)","section":"Events"},{"id":"vip_click_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_m1_events_cohort","formatting":"integer","short_name":"","name":"1M vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_m1_events_cohort","formatting":"integer","short_name":"","name":"1M vip_event (Events)","section":"Events"},{"id":"vip_event_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M vip_event (Revenue)","section":"Events"},{"id":"vip_event_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M vip_event Events per Conversion","section":"Events"},{"id":"vip_event_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M vip_event (Conversions)","section":"Events"},{"id":"vip_event_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_event Rate (Events)","section":"Events"},{"id":"vip_event_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_m1_events_cohort","formatting":"integer","short_name":"","name":"1M vip_show (Events)","section":"Events"},{"id":"vip_show_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M vip_show (Revenue)","section":"Events"},{"id":"vip_show_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M vip_show Events per Conversion","section":"Events"},{"id":"vip_show_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M vip_show (Conversions)","section":"Events"},{"id":"vip_show_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_show Rate (Events)","section":"Events"},{"id":"vip_show_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_m1_events_cohort","formatting":"integer","short_name":"","name":"1M vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m1_events_cohort","formatting":"integer","short_name":"","name":"1M Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_m1_revenue_cohort","formatting":"money","short_name":"","name":"1M Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_m1_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"1M Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_m1_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"1M Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_m1_conversions_cohort","formatting":"integer","short_name":"","name":"1M Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m1_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"1M Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_m1_events_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_m1_converted_user_size_cohort","formatting":"integer","short_name":"","name":"1M Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_m1_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"1M Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m1_events_rate_cohort","formatting":"percent","short_name":"","name":"1M Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_m1_conversions_rate_cohort","formatting":"percent","short_name":"","name":"1M Waterpipe_enter_20 Rate (Conversions)","section":"Events"},{"id":"7d_reward_2600_m2_events_cohort","formatting":"integer","short_name":"","name":"2M 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_m2_events_cohort","formatting":"integer","short_name":"","name":"2M active (Events)","section":"Events"},{"id":"active_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M active (Revenue)","section":"Events"},{"id":"active_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M active Events per Conversion","section":"Events"},{"id":"active_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M active Revenue per Conversion","section":"Events"},{"id":"active_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M active (Conversions)","section":"Events"},{"id":"active_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M active (Conversion Distribution)","section":"Events"},{"id":"active_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per active (Events)","section":"Events"},{"id":"active_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M active (Converted User Size)","section":"Events"},{"id":"active_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per active (Conversions)","section":"Events"},{"id":"active_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M active Rate (Events)","section":"Events"},{"id":"active_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M active Rate (Conversions)","section":"Events"},{"id":"ad_click_m2_events_cohort","formatting":"integer","short_name":"","name":"2M ad_click (Events)","section":"Events"},{"id":"ad_click_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M ad_click (Revenue)","section":"Events"},{"id":"ad_click_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M ad_click Events per Conversion","section":"Events"},{"id":"ad_click_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M ad_click (Conversions)","section":"Events"},{"id":"ad_click_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M ad_click Rate (Events)","section":"Events"},{"id":"ad_click_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_m2_events_cohort","formatting":"integer","short_name":"","name":"2M ad_show (Events)","section":"Events"},{"id":"ad_show_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M ad_show (Revenue)","section":"Events"},{"id":"ad_show_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M ad_show Events per Conversion","section":"Events"},{"id":"ad_show_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M ad_show (Conversions)","section":"Events"},{"id":"ad_show_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M ad_show Rate (Events)","section":"Events"},{"id":"ad_show_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_m2_events_cohort","formatting":"integer","short_name":"","name":"2M adaction (Events)","section":"Events"},{"id":"adaction_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M adaction (Revenue)","section":"Events"},{"id":"adaction_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M adaction Events per Conversion","section":"Events"},{"id":"adaction_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M adaction Revenue per Conversion","section":"Events"},{"id":"adaction_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M adaction (Conversions)","section":"Events"},{"id":"adaction_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adaction (Events)","section":"Events"},{"id":"adaction_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M adaction (Converted User Size)","section":"Events"},{"id":"adaction_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M adaction Rate (Events)","section":"Events"},{"id":"adaction_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M adaction Rate (Conversions)","section":"Events"},{"id":"adclick_m2_events_cohort","formatting":"integer","short_name":"","name":"2M adclick (Events)","section":"Events"},{"id":"adclick_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M adclick (Revenue)","section":"Events"},{"id":"adclick_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M adclick Events per Conversion","section":"Events"},{"id":"adclick_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M adclick Revenue per Conversion","section":"Events"},{"id":"adclick_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M adclick (Conversions)","section":"Events"},{"id":"adclick_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adclick (Events)","section":"Events"},{"id":"adclick_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M adclick (Converted User Size)","section":"Events"},{"id":"adclick_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M adclick Rate (Events)","section":"Events"},{"id":"adclick_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_m2_events_cohort","formatting":"integer","short_name":"","name":"2M adrevenue (Events)","section":"Events"},{"id":"adrevenue_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_m2_events_cohort","formatting":"integer","short_name":"","name":"2M adshow (Events)","section":"Events"},{"id":"adshow_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M adshow (Revenue)","section":"Events"},{"id":"adshow_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M adshow Events per Conversion","section":"Events"},{"id":"adshow_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M adshow Revenue per Conversion","section":"Events"},{"id":"adshow_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M adshow (Conversions)","section":"Events"},{"id":"adshow_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adshow (Events)","section":"Events"},{"id":"adshow_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M adshow (Converted User Size)","section":"Events"},{"id":"adshow_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M adshow Rate (Events)","section":"Events"},{"id":"adshow_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M adshow Rate (Conversions)","section":"Events"},{"id":"adv_m2_events_cohort","formatting":"integer","short_name":"","name":"2M adv (Events)","section":"Events"},{"id":"adv_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M adv (Revenue)","section":"Events"},{"id":"adv_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M adv Events per Conversion","section":"Events"},{"id":"adv_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M adv Revenue per Conversion","section":"Events"},{"id":"adv_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M adv (Conversions)","section":"Events"},{"id":"adv_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M adv (Conversion Distribution)","section":"Events"},{"id":"adv_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adv (Events)","section":"Events"},{"id":"adv_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M adv (Converted User Size)","section":"Events"},{"id":"adv_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per adv (Conversions)","section":"Events"},{"id":"adv_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M adv Rate (Events)","section":"Events"},{"id":"adv_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M adv Rate (Conversions)","section":"Events"},{"id":"analytics_m2_events_cohort","formatting":"integer","short_name":"","name":"2M analytics (Events)","section":"Events"},{"id":"analytics_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M analytics (Revenue)","section":"Events"},{"id":"analytics_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M analytics Events per Conversion","section":"Events"},{"id":"analytics_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M analytics Revenue per Conversion","section":"Events"},{"id":"analytics_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M analytics (Conversions)","section":"Events"},{"id":"analytics_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per analytics (Events)","section":"Events"},{"id":"analytics_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M analytics (Converted User Size)","section":"Events"},{"id":"analytics_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M analytics Rate (Events)","section":"Events"},{"id":"analytics_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_m2_events_cohort","formatting":"integer","short_name":"","name":"2M buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_m2_events_cohort","formatting":"integer","short_name":"","name":"2M connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_10 (Events)","section":"Events"},{"id":"enter_10_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_10 (Revenue)","section":"Events"},{"id":"enter_10_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_10 (Conversions)","section":"Events"},{"id":"enter_10_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_100 (Events)","section":"Events"},{"id":"enter_100_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_100 (Revenue)","section":"Events"},{"id":"enter_100_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_100 (Conversions)","section":"Events"},{"id":"enter_100_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_15 (Events)","section":"Events"},{"id":"enter_15_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_15 (Revenue)","section":"Events"},{"id":"enter_15_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_15 (Conversions)","section":"Events"},{"id":"enter_15_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_20 (Events)","section":"Events"},{"id":"enter_20_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_20 (Revenue)","section":"Events"},{"id":"enter_20_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_20 (Conversions)","section":"Events"},{"id":"enter_20_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_30 (Events)","section":"Events"},{"id":"enter_30_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_30 (Revenue)","section":"Events"},{"id":"enter_30_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_30 (Conversions)","section":"Events"},{"id":"enter_30_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_40 (Events)","section":"Events"},{"id":"enter_40_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_40 (Revenue)","section":"Events"},{"id":"enter_40_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_40 (Conversions)","section":"Events"},{"id":"enter_40_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_50 (Events)","section":"Events"},{"id":"enter_50_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_50 (Revenue)","section":"Events"},{"id":"enter_50_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_50 (Conversions)","section":"Events"},{"id":"enter_50_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_60 (Events)","section":"Events"},{"id":"enter_60_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_60 (Revenue)","section":"Events"},{"id":"enter_60_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_60 (Conversions)","section":"Events"},{"id":"enter_60_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_70 (Events)","section":"Events"},{"id":"enter_70_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_70 (Revenue)","section":"Events"},{"id":"enter_70_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_70 (Conversions)","section":"Events"},{"id":"enter_70_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_80 (Events)","section":"Events"},{"id":"enter_80_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_80 (Revenue)","section":"Events"},{"id":"enter_80_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_80 (Conversions)","section":"Events"},{"id":"enter_80_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_m2_events_cohort","formatting":"integer","short_name":"","name":"2M enter_90 (Events)","section":"Events"},{"id":"enter_90_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M enter_90 (Revenue)","section":"Events"},{"id":"enter_90_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M enter_90 (Conversions)","section":"Events"},{"id":"enter_90_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_m2_events_cohort","formatting":"integer","short_name":"","name":"2M EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_m2_events_cohort","formatting":"integer","short_name":"","name":"2M EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_m2_events_cohort","formatting":"integer","short_name":"","name":"2M FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_m2_events_cohort","formatting":"integer","short_name":"","name":"2M FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_m2_events_cohort","formatting":"integer","short_name":"","name":"2M FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_m2_events_cohort","formatting":"integer","short_name":"","name":"2M General Revenue (Events)","section":"Events"},{"id":"general revenue_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M General Revenue (Revenue)","section":"Events"},{"id":"general revenue_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M General Revenue (Conversions)","section":"Events"},{"id":"general revenue_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_m2_events_cohort","formatting":"integer","short_name":"","name":"2M get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_m2_events_cohort","formatting":"integer","short_name":"","name":"2M get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_m2_events_cohort","formatting":"integer","short_name":"","name":"2M get_video_time (Events)","section":"Events"},{"id":"get_video_time_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_m2_events_cohort","formatting":"integer","short_name":"","name":"2M iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_m2_events_cohort","formatting":"integer","short_name":"","name":"2M IAP (Events)","section":"Events"},{"id":"iap_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M IAP (Revenue)","section":"Events"},{"id":"iap_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M IAP Events per Conversion","section":"Events"},{"id":"iap_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M IAP Revenue per Conversion","section":"Events"},{"id":"iap_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M IAP (Conversions)","section":"Events"},{"id":"iap_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M IAP (Conversion Distribution)","section":"Events"},{"id":"iap_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per IAP (Events)","section":"Events"},{"id":"iap_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M IAP (Converted User Size)","section":"Events"},{"id":"iap_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per IAP (Conversions)","section":"Events"},{"id":"iap_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M IAP Rate (Events)","section":"Events"},{"id":"iap_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_m2_events_cohort","formatting":"integer","short_name":"","name":"2M interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_m2_events_cohort","formatting":"integer","short_name":"","name":"2M interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_10 (Events)","section":"Events"},{"id":"level_10_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_10 (Revenue)","section":"Events"},{"id":"level_10_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_10 Events per Conversion","section":"Events"},{"id":"level_10_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_10 (Conversions)","section":"Events"},{"id":"level_10_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_10 (Events)","section":"Events"},{"id":"level_10_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_10 (Converted User Size)","section":"Events"},{"id":"level_10_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_10 Rate (Events)","section":"Events"},{"id":"level_10_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_100 (Events)","section":"Events"},{"id":"level_100_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_100 (Revenue)","section":"Events"},{"id":"level_100_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_100 Events per Conversion","section":"Events"},{"id":"level_100_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_100 (Conversions)","section":"Events"},{"id":"level_100_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_100 (Events)","section":"Events"},{"id":"level_100_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_100 (Converted User Size)","section":"Events"},{"id":"level_100_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_100 Rate (Events)","section":"Events"},{"id":"level_100_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_1000 (Events)","section":"Events"},{"id":"level_1000_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_1000 (Revenue)","section":"Events"},{"id":"level_1000_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_1000 (Conversions)","section":"Events"},{"id":"level_1000_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_10000 (Events)","section":"Events"},{"id":"level_10000_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_10000 (Revenue)","section":"Events"},{"id":"level_10000_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_10000 (Conversions)","section":"Events"},{"id":"level_10000_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_15 (Events)","section":"Events"},{"id":"level_15_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_15 (Revenue)","section":"Events"},{"id":"level_15_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_15 Events per Conversion","section":"Events"},{"id":"level_15_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_15 (Conversions)","section":"Events"},{"id":"level_15_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_15 (Events)","section":"Events"},{"id":"level_15_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_15 (Converted User Size)","section":"Events"},{"id":"level_15_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_15 Rate (Events)","section":"Events"},{"id":"level_15_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_20 (Events)","section":"Events"},{"id":"level_20_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_20 (Revenue)","section":"Events"},{"id":"level_20_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_20 Events per Conversion","section":"Events"},{"id":"level_20_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_20 (Conversions)","section":"Events"},{"id":"level_20_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_20 (Events)","section":"Events"},{"id":"level_20_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_20 (Converted User Size)","section":"Events"},{"id":"level_20_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_20 Rate (Events)","section":"Events"},{"id":"level_20_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_200 (Events)","section":"Events"},{"id":"level_200_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_200 (Revenue)","section":"Events"},{"id":"level_200_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_200 Events per Conversion","section":"Events"},{"id":"level_200_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_200 (Conversions)","section":"Events"},{"id":"level_200_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_200 (Events)","section":"Events"},{"id":"level_200_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_200 (Converted User Size)","section":"Events"},{"id":"level_200_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_200 Rate (Events)","section":"Events"},{"id":"level_200_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_30 (Events)","section":"Events"},{"id":"level_30_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_30 (Revenue)","section":"Events"},{"id":"level_30_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_30 Events per Conversion","section":"Events"},{"id":"level_30_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_30 (Conversions)","section":"Events"},{"id":"level_30_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_30 (Events)","section":"Events"},{"id":"level_30_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_30 (Converted User Size)","section":"Events"},{"id":"level_30_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_30 Rate (Events)","section":"Events"},{"id":"level_30_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_300 (Events)","section":"Events"},{"id":"level_300_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_300 (Revenue)","section":"Events"},{"id":"level_300_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_300 Events per Conversion","section":"Events"},{"id":"level_300_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_300 (Conversions)","section":"Events"},{"id":"level_300_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_300 (Events)","section":"Events"},{"id":"level_300_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_300 (Converted User Size)","section":"Events"},{"id":"level_300_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_300 Rate (Events)","section":"Events"},{"id":"level_300_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_3000 (Events)","section":"Events"},{"id":"level_3000_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_3000 (Revenue)","section":"Events"},{"id":"level_3000_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_3000 (Conversions)","section":"Events"},{"id":"level_3000_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_400 (Events)","section":"Events"},{"id":"level_400_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_400 (Revenue)","section":"Events"},{"id":"level_400_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_400 Events per Conversion","section":"Events"},{"id":"level_400_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_400 (Conversions)","section":"Events"},{"id":"level_400_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_400 (Events)","section":"Events"},{"id":"level_400_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_400 (Converted User Size)","section":"Events"},{"id":"level_400_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_400 Rate (Events)","section":"Events"},{"id":"level_400_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_5 (Events)","section":"Events"},{"id":"level_5_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_5 (Revenue)","section":"Events"},{"id":"level_5_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_5 Events per Conversion","section":"Events"},{"id":"level_5_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_5 (Conversions)","section":"Events"},{"id":"level_5_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_5 (Events)","section":"Events"},{"id":"level_5_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_5 (Converted User Size)","section":"Events"},{"id":"level_5_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_5 Rate (Events)","section":"Events"},{"id":"level_5_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_50 (Events)","section":"Events"},{"id":"level_50_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_50 (Revenue)","section":"Events"},{"id":"level_50_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_50 Events per Conversion","section":"Events"},{"id":"level_50_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_50 (Conversions)","section":"Events"},{"id":"level_50_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_50 (Events)","section":"Events"},{"id":"level_50_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_50 (Converted User Size)","section":"Events"},{"id":"level_50_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_50 Rate (Events)","section":"Events"},{"id":"level_50_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_500 (Events)","section":"Events"},{"id":"level_500_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_500 (Revenue)","section":"Events"},{"id":"level_500_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_500 Events per Conversion","section":"Events"},{"id":"level_500_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_500 (Conversions)","section":"Events"},{"id":"level_500_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_500 (Events)","section":"Events"},{"id":"level_500_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_500 (Converted User Size)","section":"Events"},{"id":"level_500_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_500 Rate (Events)","section":"Events"},{"id":"level_500_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_5000 (Events)","section":"Events"},{"id":"level_5000_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_5000 (Revenue)","section":"Events"},{"id":"level_5000_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_5000 (Conversions)","section":"Events"},{"id":"level_5000_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_m2_events_cohort","formatting":"integer","short_name":"","name":"2M level_600 (Events)","section":"Events"},{"id":"level_600_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M level_600 (Revenue)","section":"Events"},{"id":"level_600_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M level_600 Events per Conversion","section":"Events"},{"id":"level_600_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M level_600 (Conversions)","section":"Events"},{"id":"level_600_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_600 (Events)","section":"Events"},{"id":"level_600_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M level_600 (Converted User Size)","section":"Events"},{"id":"level_600_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M level_600 Rate (Events)","section":"Events"},{"id":"level_600_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_m2_events_cohort","formatting":"integer","short_name":"","name":"2M purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_m2_events_cohort","formatting":"integer","short_name":"","name":"2M resultpage (Events)","section":"Events"},{"id":"resultpage_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M resultpage (Revenue)","section":"Events"},{"id":"resultpage_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M resultpage Events per Conversion","section":"Events"},{"id":"resultpage_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M resultpage (Conversions)","section":"Events"},{"id":"resultpage_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M resultpage Rate (Events)","section":"Events"},{"id":"resultpage_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_m2_events_cohort","formatting":"integer","short_name":"","name":"2M showprice (Events)","section":"Events"},{"id":"showprice_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M showprice (Revenue)","section":"Events"},{"id":"showprice_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M showprice Events per Conversion","section":"Events"},{"id":"showprice_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M showprice Revenue per Conversion","section":"Events"},{"id":"showprice_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M showprice (Conversions)","section":"Events"},{"id":"showprice_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per showprice (Events)","section":"Events"},{"id":"showprice_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M showprice (Converted User Size)","section":"Events"},{"id":"showprice_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M showprice Rate (Events)","section":"Events"},{"id":"showprice_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_m2_events_cohort","formatting":"integer","short_name":"","name":"2M subrevenue (Events)","section":"Events"},{"id":"subrevenue_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_m2_events_cohort","formatting":"integer","short_name":"","name":"2M subscribe (Events)","section":"Events"},{"id":"subscribe_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M subscribe (Revenue)","section":"Events"},{"id":"subscribe_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M subscribe Events per Conversion","section":"Events"},{"id":"subscribe_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M subscribe (Conversions)","section":"Events"},{"id":"subscribe_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M subscribe Rate (Events)","section":"Events"},{"id":"subscribe_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_m2_events_cohort","formatting":"integer","short_name":"","name":"2M uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_m2_events_cohort","formatting":"integer","short_name":"","name":"2M uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_m2_events_cohort","formatting":"integer","short_name":"","name":"2M uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_m2_events_cohort","formatting":"integer","short_name":"","name":"2M uacprice (Events)","section":"Events"},{"id":"uacprice_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M uacprice (Revenue)","section":"Events"},{"id":"uacprice_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M uacprice Events per Conversion","section":"Events"},{"id":"uacprice_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M uacprice (Conversions)","section":"Events"},{"id":"uacprice_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M uacprice Rate (Events)","section":"Events"},{"id":"uacprice_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_m2_events_cohort","formatting":"integer","short_name":"","name":"2M uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_m2_events_cohort","formatting":"integer","short_name":"","name":"2M vip_click (Events)","section":"Events"},{"id":"vip_click_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M vip_click (Revenue)","section":"Events"},{"id":"vip_click_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M vip_click Events per Conversion","section":"Events"},{"id":"vip_click_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M vip_click (Conversions)","section":"Events"},{"id":"vip_click_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_click Rate (Events)","section":"Events"},{"id":"vip_click_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_m2_events_cohort","formatting":"integer","short_name":"","name":"2M vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_m2_events_cohort","formatting":"integer","short_name":"","name":"2M vip_event (Events)","section":"Events"},{"id":"vip_event_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M vip_event (Revenue)","section":"Events"},{"id":"vip_event_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M vip_event Events per Conversion","section":"Events"},{"id":"vip_event_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M vip_event (Conversions)","section":"Events"},{"id":"vip_event_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_event Rate (Events)","section":"Events"},{"id":"vip_event_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_m2_events_cohort","formatting":"integer","short_name":"","name":"2M vip_show (Events)","section":"Events"},{"id":"vip_show_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M vip_show (Revenue)","section":"Events"},{"id":"vip_show_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M vip_show Events per Conversion","section":"Events"},{"id":"vip_show_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M vip_show (Conversions)","section":"Events"},{"id":"vip_show_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_show Rate (Events)","section":"Events"},{"id":"vip_show_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_m2_events_cohort","formatting":"integer","short_name":"","name":"2M vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m2_events_cohort","formatting":"integer","short_name":"","name":"2M Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_m2_revenue_cohort","formatting":"money","short_name":"","name":"2M Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_m2_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"2M Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_m2_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"2M Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_m2_conversions_cohort","formatting":"integer","short_name":"","name":"2M Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m2_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"2M Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_m2_events_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_m2_converted_user_size_cohort","formatting":"integer","short_name":"","name":"2M Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_m2_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"2M Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m2_events_rate_cohort","formatting":"percent","short_name":"","name":"2M Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_m2_conversions_rate_cohort","formatting":"percent","short_name":"","name":"2M Waterpipe_enter_20 Rate (Conversions)","section":"Events"},{"id":"7d_reward_2600_m3_events_cohort","formatting":"integer","short_name":"","name":"3M 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M 7d_Reward_2600 (Revenue)","section":"Events"},{"id":"7d_reward_2600_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M 7d_Reward_2600 Events per Conversion","section":"Events"},{"id":"7d_reward_2600_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M 7d_Reward_2600 Revenue per Conversion","section":"Events"},{"id":"7d_reward_2600_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M 7d_Reward_2600 (Conversion Distribution)","section":"Events"},{"id":"7d_reward_2600_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per 7d_Reward_2600 (Events)","section":"Events"},{"id":"7d_reward_2600_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M 7d_Reward_2600 (Converted User Size)","section":"Events"},{"id":"7d_reward_2600_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per 7d_Reward_2600 (Conversions)","section":"Events"},{"id":"7d_reward_2600_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M 7d_Reward_2600 Rate (Events)","section":"Events"},{"id":"7d_reward_2600_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M 7d_Reward_2600 Rate (Conversions)","section":"Events"},{"id":"active_m3_events_cohort","formatting":"integer","short_name":"","name":"3M active (Events)","section":"Events"},{"id":"active_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M active (Revenue)","section":"Events"},{"id":"active_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M active Events per Conversion","section":"Events"},{"id":"active_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M active Revenue per Conversion","section":"Events"},{"id":"active_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M active (Conversions)","section":"Events"},{"id":"active_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M active (Conversion Distribution)","section":"Events"},{"id":"active_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per active (Events)","section":"Events"},{"id":"active_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M active (Converted User Size)","section":"Events"},{"id":"active_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per active (Conversions)","section":"Events"},{"id":"active_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M active Rate (Events)","section":"Events"},{"id":"active_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M active Rate (Conversions)","section":"Events"},{"id":"ad_click_m3_events_cohort","formatting":"integer","short_name":"","name":"3M ad_click (Events)","section":"Events"},{"id":"ad_click_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M ad_click (Revenue)","section":"Events"},{"id":"ad_click_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M ad_click Events per Conversion","section":"Events"},{"id":"ad_click_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M ad_click Revenue per Conversion","section":"Events"},{"id":"ad_click_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M ad_click (Conversions)","section":"Events"},{"id":"ad_click_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M ad_click (Conversion Distribution)","section":"Events"},{"id":"ad_click_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per ad_click (Events)","section":"Events"},{"id":"ad_click_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M ad_click (Converted User Size)","section":"Events"},{"id":"ad_click_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per ad_click (Conversions)","section":"Events"},{"id":"ad_click_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M ad_click Rate (Events)","section":"Events"},{"id":"ad_click_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M ad_click Rate (Conversions)","section":"Events"},{"id":"ad_show_m3_events_cohort","formatting":"integer","short_name":"","name":"3M ad_show (Events)","section":"Events"},{"id":"ad_show_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M ad_show (Revenue)","section":"Events"},{"id":"ad_show_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M ad_show Events per Conversion","section":"Events"},{"id":"ad_show_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M ad_show Revenue per Conversion","section":"Events"},{"id":"ad_show_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M ad_show (Conversions)","section":"Events"},{"id":"ad_show_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M ad_show (Conversion Distribution)","section":"Events"},{"id":"ad_show_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per ad_show (Events)","section":"Events"},{"id":"ad_show_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M ad_show (Converted User Size)","section":"Events"},{"id":"ad_show_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per ad_show (Conversions)","section":"Events"},{"id":"ad_show_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M ad_show Rate (Events)","section":"Events"},{"id":"ad_show_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M ad_show Rate (Conversions)","section":"Events"},{"id":"adaction_m3_events_cohort","formatting":"integer","short_name":"","name":"3M adaction (Events)","section":"Events"},{"id":"adaction_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M adaction (Revenue)","section":"Events"},{"id":"adaction_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M adaction Events per Conversion","section":"Events"},{"id":"adaction_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M adaction Revenue per Conversion","section":"Events"},{"id":"adaction_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M adaction (Conversions)","section":"Events"},{"id":"adaction_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M adaction (Conversion Distribution)","section":"Events"},{"id":"adaction_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adaction (Events)","section":"Events"},{"id":"adaction_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M adaction (Converted User Size)","section":"Events"},{"id":"adaction_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adaction (Conversions)","section":"Events"},{"id":"adaction_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M adaction Rate (Events)","section":"Events"},{"id":"adaction_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M adaction Rate (Conversions)","section":"Events"},{"id":"adclick_m3_events_cohort","formatting":"integer","short_name":"","name":"3M adclick (Events)","section":"Events"},{"id":"adclick_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M adclick (Revenue)","section":"Events"},{"id":"adclick_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M adclick Events per Conversion","section":"Events"},{"id":"adclick_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M adclick Revenue per Conversion","section":"Events"},{"id":"adclick_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M adclick (Conversions)","section":"Events"},{"id":"adclick_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M adclick (Conversion Distribution)","section":"Events"},{"id":"adclick_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adclick (Events)","section":"Events"},{"id":"adclick_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M adclick (Converted User Size)","section":"Events"},{"id":"adclick_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adclick (Conversions)","section":"Events"},{"id":"adclick_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M adclick Rate (Events)","section":"Events"},{"id":"adclick_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M adclick Rate (Conversions)","section":"Events"},{"id":"adrevenue_m3_events_cohort","formatting":"integer","short_name":"","name":"3M adrevenue (Events)","section":"Events"},{"id":"adrevenue_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M adrevenue (Revenue)","section":"Events"},{"id":"adrevenue_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M adrevenue Events per Conversion","section":"Events"},{"id":"adrevenue_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M adrevenue Revenue per Conversion","section":"Events"},{"id":"adrevenue_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M adrevenue (Conversion Distribution)","section":"Events"},{"id":"adrevenue_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adrevenue (Events)","section":"Events"},{"id":"adrevenue_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M adrevenue (Converted User Size)","section":"Events"},{"id":"adrevenue_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adrevenue (Conversions)","section":"Events"},{"id":"adrevenue_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M adrevenue Rate (Events)","section":"Events"},{"id":"adrevenue_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M adrevenue Rate (Conversions)","section":"Events"},{"id":"adshow_m3_events_cohort","formatting":"integer","short_name":"","name":"3M adshow (Events)","section":"Events"},{"id":"adshow_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M adshow (Revenue)","section":"Events"},{"id":"adshow_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M adshow Events per Conversion","section":"Events"},{"id":"adshow_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M adshow Revenue per Conversion","section":"Events"},{"id":"adshow_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M adshow (Conversions)","section":"Events"},{"id":"adshow_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M adshow (Conversion Distribution)","section":"Events"},{"id":"adshow_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adshow (Events)","section":"Events"},{"id":"adshow_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M adshow (Converted User Size)","section":"Events"},{"id":"adshow_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adshow (Conversions)","section":"Events"},{"id":"adshow_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M adshow Rate (Events)","section":"Events"},{"id":"adshow_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M adshow Rate (Conversions)","section":"Events"},{"id":"adv_m3_events_cohort","formatting":"integer","short_name":"","name":"3M adv (Events)","section":"Events"},{"id":"adv_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M adv (Revenue)","section":"Events"},{"id":"adv_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M adv Events per Conversion","section":"Events"},{"id":"adv_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M adv Revenue per Conversion","section":"Events"},{"id":"adv_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M adv (Conversions)","section":"Events"},{"id":"adv_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M adv (Conversion Distribution)","section":"Events"},{"id":"adv_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adv (Events)","section":"Events"},{"id":"adv_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M adv (Converted User Size)","section":"Events"},{"id":"adv_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per adv (Conversions)","section":"Events"},{"id":"adv_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M adv Rate (Events)","section":"Events"},{"id":"adv_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M adv Rate (Conversions)","section":"Events"},{"id":"analytics_m3_events_cohort","formatting":"integer","short_name":"","name":"3M analytics (Events)","section":"Events"},{"id":"analytics_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M analytics (Revenue)","section":"Events"},{"id":"analytics_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M analytics Events per Conversion","section":"Events"},{"id":"analytics_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M analytics Revenue per Conversion","section":"Events"},{"id":"analytics_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M analytics (Conversions)","section":"Events"},{"id":"analytics_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M analytics (Conversion Distribution)","section":"Events"},{"id":"analytics_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per analytics (Events)","section":"Events"},{"id":"analytics_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M analytics (Converted User Size)","section":"Events"},{"id":"analytics_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per analytics (Conversions)","section":"Events"},{"id":"analytics_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M analytics Rate (Events)","section":"Events"},{"id":"analytics_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M analytics Rate (Conversions)","section":"Events"},{"id":"buyrevenue_m3_events_cohort","formatting":"integer","short_name":"","name":"3M buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M buyrevenue (Revenue)","section":"Events"},{"id":"buyrevenue_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M buyrevenue Events per Conversion","section":"Events"},{"id":"buyrevenue_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M buyrevenue Revenue per Conversion","section":"Events"},{"id":"buyrevenue_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M buyrevenue (Conversion Distribution)","section":"Events"},{"id":"buyrevenue_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per buyrevenue (Events)","section":"Events"},{"id":"buyrevenue_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M buyrevenue (Converted User Size)","section":"Events"},{"id":"buyrevenue_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per buyrevenue (Conversions)","section":"Events"},{"id":"buyrevenue_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M buyrevenue Rate (Events)","section":"Events"},{"id":"buyrevenue_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M buyrevenue Rate (Conversions)","section":"Events"},{"id":"connect_vpn_m3_events_cohort","formatting":"integer","short_name":"","name":"3M connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M connect_vpn (Revenue)","section":"Events"},{"id":"connect_vpn_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M connect_vpn Events per Conversion","section":"Events"},{"id":"connect_vpn_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M connect_vpn Revenue per Conversion","section":"Events"},{"id":"connect_vpn_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M connect_vpn (Conversion Distribution)","section":"Events"},{"id":"connect_vpn_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per connect_vpn (Events)","section":"Events"},{"id":"connect_vpn_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M connect_vpn (Converted User Size)","section":"Events"},{"id":"connect_vpn_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per connect_vpn (Conversions)","section":"Events"},{"id":"connect_vpn_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M connect_vpn Rate (Events)","section":"Events"},{"id":"connect_vpn_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M connect_vpn Rate (Conversions)","section":"Events"},{"id":"enter_10_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_10 (Events)","section":"Events"},{"id":"enter_10_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_10 (Revenue)","section":"Events"},{"id":"enter_10_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_10 Events per Conversion","section":"Events"},{"id":"enter_10_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_10 Revenue per Conversion","section":"Events"},{"id":"enter_10_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_10 (Conversions)","section":"Events"},{"id":"enter_10_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_10 (Conversion Distribution)","section":"Events"},{"id":"enter_10_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_10 (Events)","section":"Events"},{"id":"enter_10_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_10 (Converted User Size)","section":"Events"},{"id":"enter_10_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_10 (Conversions)","section":"Events"},{"id":"enter_10_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_10 Rate (Events)","section":"Events"},{"id":"enter_10_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_10 Rate (Conversions)","section":"Events"},{"id":"enter_100_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_100 (Events)","section":"Events"},{"id":"enter_100_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_100 (Revenue)","section":"Events"},{"id":"enter_100_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_100 Events per Conversion","section":"Events"},{"id":"enter_100_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_100 Revenue per Conversion","section":"Events"},{"id":"enter_100_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_100 (Conversions)","section":"Events"},{"id":"enter_100_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_100 (Conversion Distribution)","section":"Events"},{"id":"enter_100_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_100 (Events)","section":"Events"},{"id":"enter_100_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_100 (Converted User Size)","section":"Events"},{"id":"enter_100_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_100 (Conversions)","section":"Events"},{"id":"enter_100_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_100 Rate (Events)","section":"Events"},{"id":"enter_100_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_100 Rate (Conversions)","section":"Events"},{"id":"enter_15_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_15 (Events)","section":"Events"},{"id":"enter_15_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_15 (Revenue)","section":"Events"},{"id":"enter_15_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_15 Events per Conversion","section":"Events"},{"id":"enter_15_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_15 Revenue per Conversion","section":"Events"},{"id":"enter_15_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_15 (Conversions)","section":"Events"},{"id":"enter_15_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_15 (Conversion Distribution)","section":"Events"},{"id":"enter_15_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_15 (Events)","section":"Events"},{"id":"enter_15_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_15 (Converted User Size)","section":"Events"},{"id":"enter_15_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_15 (Conversions)","section":"Events"},{"id":"enter_15_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_15 Rate (Events)","section":"Events"},{"id":"enter_15_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_15 Rate (Conversions)","section":"Events"},{"id":"enter_20_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_20 (Events)","section":"Events"},{"id":"enter_20_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_20 (Revenue)","section":"Events"},{"id":"enter_20_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_20 Events per Conversion","section":"Events"},{"id":"enter_20_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_20 Revenue per Conversion","section":"Events"},{"id":"enter_20_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_20 (Conversions)","section":"Events"},{"id":"enter_20_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_20 (Conversion Distribution)","section":"Events"},{"id":"enter_20_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_20 (Events)","section":"Events"},{"id":"enter_20_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_20 (Converted User Size)","section":"Events"},{"id":"enter_20_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_20 (Conversions)","section":"Events"},{"id":"enter_20_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_20 Rate (Events)","section":"Events"},{"id":"enter_20_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_20 Rate (Conversions)","section":"Events"},{"id":"enter_30_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_30 (Events)","section":"Events"},{"id":"enter_30_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_30 (Revenue)","section":"Events"},{"id":"enter_30_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_30 Events per Conversion","section":"Events"},{"id":"enter_30_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_30 Revenue per Conversion","section":"Events"},{"id":"enter_30_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_30 (Conversions)","section":"Events"},{"id":"enter_30_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_30 (Conversion Distribution)","section":"Events"},{"id":"enter_30_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_30 (Events)","section":"Events"},{"id":"enter_30_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_30 (Converted User Size)","section":"Events"},{"id":"enter_30_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_30 (Conversions)","section":"Events"},{"id":"enter_30_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_30 Rate (Events)","section":"Events"},{"id":"enter_30_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_30 Rate (Conversions)","section":"Events"},{"id":"enter_40_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_40 (Events)","section":"Events"},{"id":"enter_40_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_40 (Revenue)","section":"Events"},{"id":"enter_40_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_40 Events per Conversion","section":"Events"},{"id":"enter_40_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_40 Revenue per Conversion","section":"Events"},{"id":"enter_40_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_40 (Conversions)","section":"Events"},{"id":"enter_40_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_40 (Conversion Distribution)","section":"Events"},{"id":"enter_40_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_40 (Events)","section":"Events"},{"id":"enter_40_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_40 (Converted User Size)","section":"Events"},{"id":"enter_40_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_40 (Conversions)","section":"Events"},{"id":"enter_40_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_40 Rate (Events)","section":"Events"},{"id":"enter_40_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_40 Rate (Conversions)","section":"Events"},{"id":"enter_50_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_50 (Events)","section":"Events"},{"id":"enter_50_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_50 (Revenue)","section":"Events"},{"id":"enter_50_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_50 Events per Conversion","section":"Events"},{"id":"enter_50_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_50 Revenue per Conversion","section":"Events"},{"id":"enter_50_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_50 (Conversions)","section":"Events"},{"id":"enter_50_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_50 (Conversion Distribution)","section":"Events"},{"id":"enter_50_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_50 (Events)","section":"Events"},{"id":"enter_50_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_50 (Converted User Size)","section":"Events"},{"id":"enter_50_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_50 (Conversions)","section":"Events"},{"id":"enter_50_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_50 Rate (Events)","section":"Events"},{"id":"enter_50_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_50 Rate (Conversions)","section":"Events"},{"id":"enter_60_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_60 (Events)","section":"Events"},{"id":"enter_60_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_60 (Revenue)","section":"Events"},{"id":"enter_60_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_60 Events per Conversion","section":"Events"},{"id":"enter_60_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_60 Revenue per Conversion","section":"Events"},{"id":"enter_60_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_60 (Conversions)","section":"Events"},{"id":"enter_60_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_60 (Conversion Distribution)","section":"Events"},{"id":"enter_60_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_60 (Events)","section":"Events"},{"id":"enter_60_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_60 (Converted User Size)","section":"Events"},{"id":"enter_60_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_60 (Conversions)","section":"Events"},{"id":"enter_60_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_60 Rate (Events)","section":"Events"},{"id":"enter_60_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_60 Rate (Conversions)","section":"Events"},{"id":"enter_70_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_70 (Events)","section":"Events"},{"id":"enter_70_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_70 (Revenue)","section":"Events"},{"id":"enter_70_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_70 Events per Conversion","section":"Events"},{"id":"enter_70_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_70 Revenue per Conversion","section":"Events"},{"id":"enter_70_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_70 (Conversions)","section":"Events"},{"id":"enter_70_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_70 (Conversion Distribution)","section":"Events"},{"id":"enter_70_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_70 (Events)","section":"Events"},{"id":"enter_70_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_70 (Converted User Size)","section":"Events"},{"id":"enter_70_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_70 (Conversions)","section":"Events"},{"id":"enter_70_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_70 Rate (Events)","section":"Events"},{"id":"enter_70_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_70 Rate (Conversions)","section":"Events"},{"id":"enter_80_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_80 (Events)","section":"Events"},{"id":"enter_80_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_80 (Revenue)","section":"Events"},{"id":"enter_80_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_80 Events per Conversion","section":"Events"},{"id":"enter_80_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_80 Revenue per Conversion","section":"Events"},{"id":"enter_80_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_80 (Conversions)","section":"Events"},{"id":"enter_80_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_80 (Conversion Distribution)","section":"Events"},{"id":"enter_80_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_80 (Events)","section":"Events"},{"id":"enter_80_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_80 (Converted User Size)","section":"Events"},{"id":"enter_80_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_80 (Conversions)","section":"Events"},{"id":"enter_80_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_80 Rate (Events)","section":"Events"},{"id":"enter_80_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_80 Rate (Conversions)","section":"Events"},{"id":"enter_90_m3_events_cohort","formatting":"integer","short_name":"","name":"3M enter_90 (Events)","section":"Events"},{"id":"enter_90_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M enter_90 (Revenue)","section":"Events"},{"id":"enter_90_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M enter_90 Events per Conversion","section":"Events"},{"id":"enter_90_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M enter_90 Revenue per Conversion","section":"Events"},{"id":"enter_90_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M enter_90 (Conversions)","section":"Events"},{"id":"enter_90_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M enter_90 (Conversion Distribution)","section":"Events"},{"id":"enter_90_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_90 (Events)","section":"Events"},{"id":"enter_90_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M enter_90 (Converted User Size)","section":"Events"},{"id":"enter_90_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per enter_90 (Conversions)","section":"Events"},{"id":"enter_90_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_90 Rate (Events)","section":"Events"},{"id":"enter_90_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M enter_90 Rate (Conversions)","section":"Events"},{"id":"event_install_m3_events_cohort","formatting":"integer","short_name":"","name":"3M EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M EVENT_INSTALL (Revenue)","section":"Events"},{"id":"event_install_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M EVENT_INSTALL Events per Conversion","section":"Events"},{"id":"event_install_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M EVENT_INSTALL Revenue per Conversion","section":"Events"},{"id":"event_install_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M EVENT_INSTALL (Conversion Distribution)","section":"Events"},{"id":"event_install_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per EVENT_INSTALL (Events)","section":"Events"},{"id":"event_install_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M EVENT_INSTALL (Converted User Size)","section":"Events"},{"id":"event_install_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per EVENT_INSTALL (Conversions)","section":"Events"},{"id":"event_install_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M EVENT_INSTALL Rate (Events)","section":"Events"},{"id":"event_install_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M EVENT_INSTALL Rate (Conversions)","section":"Events"},{"id":"event_launch_app_m3_events_cohort","formatting":"integer","short_name":"","name":"3M EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M EVENT_LAUNCH_APP (Revenue)","section":"Events"},{"id":"event_launch_app_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M EVENT_LAUNCH_APP Events per Conversion","section":"Events"},{"id":"event_launch_app_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M EVENT_LAUNCH_APP Revenue per Conversion","section":"Events"},{"id":"event_launch_app_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M EVENT_LAUNCH_APP (Conversion Distribution)","section":"Events"},{"id":"event_launch_app_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per EVENT_LAUNCH_APP (Events)","section":"Events"},{"id":"event_launch_app_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M EVENT_LAUNCH_APP (Converted User Size)","section":"Events"},{"id":"event_launch_app_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per EVENT_LAUNCH_APP (Conversions)","section":"Events"},{"id":"event_launch_app_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M EVENT_LAUNCH_APP Rate (Events)","section":"Events"},{"id":"event_launch_app_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M EVENT_LAUNCH_APP Rate (Conversions)","section":"Events"},{"id":"finditems_enter_10_m3_events_cohort","formatting":"integer","short_name":"","name":"3M FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M FindItems_enter_10 (Revenue)","section":"Events"},{"id":"finditems_enter_10_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M FindItems_enter_10 Events per Conversion","section":"Events"},{"id":"finditems_enter_10_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M FindItems_enter_10 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_10_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M FindItems_enter_10 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_10_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per FindItems_enter_10 (Events)","section":"Events"},{"id":"finditems_enter_10_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M FindItems_enter_10 (Converted User Size)","section":"Events"},{"id":"finditems_enter_10_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per FindItems_enter_10 (Conversions)","section":"Events"},{"id":"finditems_enter_10_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M FindItems_enter_10 Rate (Events)","section":"Events"},{"id":"finditems_enter_10_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M FindItems_enter_10 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_20_m3_events_cohort","formatting":"integer","short_name":"","name":"3M FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M FindItems_enter_20 (Revenue)","section":"Events"},{"id":"finditems_enter_20_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M FindItems_enter_20 Events per Conversion","section":"Events"},{"id":"finditems_enter_20_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M FindItems_enter_20 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_20_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M FindItems_enter_20 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_20_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per FindItems_enter_20 (Events)","section":"Events"},{"id":"finditems_enter_20_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M FindItems_enter_20 (Converted User Size)","section":"Events"},{"id":"finditems_enter_20_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per FindItems_enter_20 (Conversions)","section":"Events"},{"id":"finditems_enter_20_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M FindItems_enter_20 Rate (Events)","section":"Events"},{"id":"finditems_enter_20_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M FindItems_enter_20 Rate (Conversions)","section":"Events"},{"id":"finditems_enter_30_m3_events_cohort","formatting":"integer","short_name":"","name":"3M FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M FindItems_enter_30 (Revenue)","section":"Events"},{"id":"finditems_enter_30_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M FindItems_enter_30 Events per Conversion","section":"Events"},{"id":"finditems_enter_30_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M FindItems_enter_30 Revenue per Conversion","section":"Events"},{"id":"finditems_enter_30_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M FindItems_enter_30 (Conversion Distribution)","section":"Events"},{"id":"finditems_enter_30_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per FindItems_enter_30 (Events)","section":"Events"},{"id":"finditems_enter_30_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M FindItems_enter_30 (Converted User Size)","section":"Events"},{"id":"finditems_enter_30_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per FindItems_enter_30 (Conversions)","section":"Events"},{"id":"finditems_enter_30_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M FindItems_enter_30 Rate (Events)","section":"Events"},{"id":"finditems_enter_30_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M FindItems_enter_30 Rate (Conversions)","section":"Events"},{"id":"general revenue_m3_events_cohort","formatting":"integer","short_name":"","name":"3M General Revenue (Events)","section":"Events"},{"id":"general revenue_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M General Revenue (Revenue)","section":"Events"},{"id":"general revenue_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M General Revenue Events per Conversion","section":"Events"},{"id":"general revenue_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M General Revenue Revenue per Conversion","section":"Events"},{"id":"general revenue_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M General Revenue (Conversions)","section":"Events"},{"id":"general revenue_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M General Revenue (Conversion Distribution)","section":"Events"},{"id":"general revenue_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per General Revenue (Events)","section":"Events"},{"id":"general revenue_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M General Revenue (Converted User Size)","section":"Events"},{"id":"general revenue_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per General Revenue (Conversions)","section":"Events"},{"id":"general revenue_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M General Revenue Rate (Events)","section":"Events"},{"id":"general revenue_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M General Revenue Rate (Conversions)","section":"Events"},{"id":"get_normal_time_m3_events_cohort","formatting":"integer","short_name":"","name":"3M get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M get_normal_time (Revenue)","section":"Events"},{"id":"get_normal_time_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M get_normal_time Events per Conversion","section":"Events"},{"id":"get_normal_time_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M get_normal_time Revenue per Conversion","section":"Events"},{"id":"get_normal_time_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M get_normal_time (Conversion Distribution)","section":"Events"},{"id":"get_normal_time_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per get_normal_time (Events)","section":"Events"},{"id":"get_normal_time_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M get_normal_time (Converted User Size)","section":"Events"},{"id":"get_normal_time_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per get_normal_time (Conversions)","section":"Events"},{"id":"get_normal_time_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M get_normal_time Rate (Events)","section":"Events"},{"id":"get_normal_time_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M get_normal_time Rate (Conversions)","section":"Events"},{"id":"get_reward_time_m3_events_cohort","formatting":"integer","short_name":"","name":"3M get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M get_reward_time (Revenue)","section":"Events"},{"id":"get_reward_time_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M get_reward_time Events per Conversion","section":"Events"},{"id":"get_reward_time_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M get_reward_time Revenue per Conversion","section":"Events"},{"id":"get_reward_time_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M get_reward_time (Conversion Distribution)","section":"Events"},{"id":"get_reward_time_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per get_reward_time (Events)","section":"Events"},{"id":"get_reward_time_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M get_reward_time (Converted User Size)","section":"Events"},{"id":"get_reward_time_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per get_reward_time (Conversions)","section":"Events"},{"id":"get_reward_time_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M get_reward_time Rate (Events)","section":"Events"},{"id":"get_reward_time_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M get_reward_time Rate (Conversions)","section":"Events"},{"id":"get_video_time_m3_events_cohort","formatting":"integer","short_name":"","name":"3M get_video_time (Events)","section":"Events"},{"id":"get_video_time_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M get_video_time (Revenue)","section":"Events"},{"id":"get_video_time_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M get_video_time Events per Conversion","section":"Events"},{"id":"get_video_time_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M get_video_time Revenue per Conversion","section":"Events"},{"id":"get_video_time_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M get_video_time (Conversion Distribution)","section":"Events"},{"id":"get_video_time_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per get_video_time (Events)","section":"Events"},{"id":"get_video_time_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M get_video_time (Converted User Size)","section":"Events"},{"id":"get_video_time_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per get_video_time (Conversions)","section":"Events"},{"id":"get_video_time_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M get_video_time Rate (Events)","section":"Events"},{"id":"get_video_time_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M get_video_time Rate (Conversions)","section":"Events"},{"id":"iaa_revenue_m3_events_cohort","formatting":"integer","short_name":"","name":"3M iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M iaa_revenue (Revenue)","section":"Events"},{"id":"iaa_revenue_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M iaa_revenue Events per Conversion","section":"Events"},{"id":"iaa_revenue_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M iaa_revenue Revenue per Conversion","section":"Events"},{"id":"iaa_revenue_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M iaa_revenue (Conversion Distribution)","section":"Events"},{"id":"iaa_revenue_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per iaa_revenue (Events)","section":"Events"},{"id":"iaa_revenue_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M iaa_revenue (Converted User Size)","section":"Events"},{"id":"iaa_revenue_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per iaa_revenue (Conversions)","section":"Events"},{"id":"iaa_revenue_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M iaa_revenue Rate (Events)","section":"Events"},{"id":"iaa_revenue_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M iaa_revenue Rate (Conversions)","section":"Events"},{"id":"iap_m3_events_cohort","formatting":"integer","short_name":"","name":"3M IAP (Events)","section":"Events"},{"id":"iap_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M IAP (Revenue)","section":"Events"},{"id":"iap_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M IAP Events per Conversion","section":"Events"},{"id":"iap_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M IAP Revenue per Conversion","section":"Events"},{"id":"iap_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M IAP (Conversions)","section":"Events"},{"id":"iap_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M IAP (Conversion Distribution)","section":"Events"},{"id":"iap_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per IAP (Events)","section":"Events"},{"id":"iap_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M IAP (Converted User Size)","section":"Events"},{"id":"iap_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per IAP (Conversions)","section":"Events"},{"id":"iap_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M IAP Rate (Events)","section":"Events"},{"id":"iap_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M IAP Rate (Conversions)","section":"Events"},{"id":"interstital_ad_click_m3_events_cohort","formatting":"integer","short_name":"","name":"3M interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M interstital_ad_click (Revenue)","section":"Events"},{"id":"interstital_ad_click_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M interstital_ad_click Events per Conversion","section":"Events"},{"id":"interstital_ad_click_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M interstital_ad_click Revenue per Conversion","section":"Events"},{"id":"interstital_ad_click_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M interstital_ad_click (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_click_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per interstital_ad_click (Events)","section":"Events"},{"id":"interstital_ad_click_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M interstital_ad_click (Converted User Size)","section":"Events"},{"id":"interstital_ad_click_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per interstital_ad_click (Conversions)","section":"Events"},{"id":"interstital_ad_click_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M interstital_ad_click Rate (Events)","section":"Events"},{"id":"interstital_ad_click_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M interstital_ad_click Rate (Conversions)","section":"Events"},{"id":"interstital_ad_show_m3_events_cohort","formatting":"integer","short_name":"","name":"3M interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M interstital_ad_show (Revenue)","section":"Events"},{"id":"interstital_ad_show_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M interstital_ad_show Events per Conversion","section":"Events"},{"id":"interstital_ad_show_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M interstital_ad_show Revenue per Conversion","section":"Events"},{"id":"interstital_ad_show_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M interstital_ad_show (Conversion Distribution)","section":"Events"},{"id":"interstital_ad_show_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per interstital_ad_show (Events)","section":"Events"},{"id":"interstital_ad_show_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M interstital_ad_show (Converted User Size)","section":"Events"},{"id":"interstital_ad_show_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per interstital_ad_show (Conversions)","section":"Events"},{"id":"interstital_ad_show_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M interstital_ad_show Rate (Events)","section":"Events"},{"id":"interstital_ad_show_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M interstital_ad_show Rate (Conversions)","section":"Events"},{"id":"level_10_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_10 (Events)","section":"Events"},{"id":"level_10_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_10 (Revenue)","section":"Events"},{"id":"level_10_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_10 Events per Conversion","section":"Events"},{"id":"level_10_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_10 Revenue per Conversion","section":"Events"},{"id":"level_10_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_10 (Conversions)","section":"Events"},{"id":"level_10_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_10 (Conversion Distribution)","section":"Events"},{"id":"level_10_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_10 (Events)","section":"Events"},{"id":"level_10_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_10 (Converted User Size)","section":"Events"},{"id":"level_10_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_10 (Conversions)","section":"Events"},{"id":"level_10_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_10 Rate (Events)","section":"Events"},{"id":"level_10_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_10 Rate (Conversions)","section":"Events"},{"id":"level_100_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_100 (Events)","section":"Events"},{"id":"level_100_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_100 (Revenue)","section":"Events"},{"id":"level_100_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_100 Events per Conversion","section":"Events"},{"id":"level_100_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_100 Revenue per Conversion","section":"Events"},{"id":"level_100_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_100 (Conversions)","section":"Events"},{"id":"level_100_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_100 (Conversion Distribution)","section":"Events"},{"id":"level_100_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_100 (Events)","section":"Events"},{"id":"level_100_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_100 (Converted User Size)","section":"Events"},{"id":"level_100_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_100 (Conversions)","section":"Events"},{"id":"level_100_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_100 Rate (Events)","section":"Events"},{"id":"level_100_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_100 Rate (Conversions)","section":"Events"},{"id":"level_1000_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_1000 (Events)","section":"Events"},{"id":"level_1000_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_1000 (Revenue)","section":"Events"},{"id":"level_1000_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_1000 Events per Conversion","section":"Events"},{"id":"level_1000_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_1000 Revenue per Conversion","section":"Events"},{"id":"level_1000_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_1000 (Conversions)","section":"Events"},{"id":"level_1000_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_1000 (Conversion Distribution)","section":"Events"},{"id":"level_1000_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_1000 (Events)","section":"Events"},{"id":"level_1000_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_1000 (Converted User Size)","section":"Events"},{"id":"level_1000_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_1000 (Conversions)","section":"Events"},{"id":"level_1000_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_1000 Rate (Events)","section":"Events"},{"id":"level_1000_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_1000 Rate (Conversions)","section":"Events"},{"id":"level_10000_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_10000 (Events)","section":"Events"},{"id":"level_10000_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_10000 (Revenue)","section":"Events"},{"id":"level_10000_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_10000 Events per Conversion","section":"Events"},{"id":"level_10000_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_10000 Revenue per Conversion","section":"Events"},{"id":"level_10000_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_10000 (Conversions)","section":"Events"},{"id":"level_10000_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_10000 (Conversion Distribution)","section":"Events"},{"id":"level_10000_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_10000 (Events)","section":"Events"},{"id":"level_10000_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_10000 (Converted User Size)","section":"Events"},{"id":"level_10000_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_10000 (Conversions)","section":"Events"},{"id":"level_10000_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_10000 Rate (Events)","section":"Events"},{"id":"level_10000_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_10000 Rate (Conversions)","section":"Events"},{"id":"level_15_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_15 (Events)","section":"Events"},{"id":"level_15_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_15 (Revenue)","section":"Events"},{"id":"level_15_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_15 Events per Conversion","section":"Events"},{"id":"level_15_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_15 Revenue per Conversion","section":"Events"},{"id":"level_15_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_15 (Conversions)","section":"Events"},{"id":"level_15_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_15 (Conversion Distribution)","section":"Events"},{"id":"level_15_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_15 (Events)","section":"Events"},{"id":"level_15_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_15 (Converted User Size)","section":"Events"},{"id":"level_15_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_15 (Conversions)","section":"Events"},{"id":"level_15_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_15 Rate (Events)","section":"Events"},{"id":"level_15_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_15 Rate (Conversions)","section":"Events"},{"id":"level_20_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_20 (Events)","section":"Events"},{"id":"level_20_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_20 (Revenue)","section":"Events"},{"id":"level_20_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_20 Events per Conversion","section":"Events"},{"id":"level_20_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_20 Revenue per Conversion","section":"Events"},{"id":"level_20_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_20 (Conversions)","section":"Events"},{"id":"level_20_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_20 (Conversion Distribution)","section":"Events"},{"id":"level_20_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_20 (Events)","section":"Events"},{"id":"level_20_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_20 (Converted User Size)","section":"Events"},{"id":"level_20_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_20 (Conversions)","section":"Events"},{"id":"level_20_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_20 Rate (Events)","section":"Events"},{"id":"level_20_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_20 Rate (Conversions)","section":"Events"},{"id":"level_200_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_200 (Events)","section":"Events"},{"id":"level_200_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_200 (Revenue)","section":"Events"},{"id":"level_200_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_200 Events per Conversion","section":"Events"},{"id":"level_200_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_200 Revenue per Conversion","section":"Events"},{"id":"level_200_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_200 (Conversions)","section":"Events"},{"id":"level_200_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_200 (Conversion Distribution)","section":"Events"},{"id":"level_200_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_200 (Events)","section":"Events"},{"id":"level_200_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_200 (Converted User Size)","section":"Events"},{"id":"level_200_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_200 (Conversions)","section":"Events"},{"id":"level_200_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_200 Rate (Events)","section":"Events"},{"id":"level_200_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_200 Rate (Conversions)","section":"Events"},{"id":"level_30_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_30 (Events)","section":"Events"},{"id":"level_30_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_30 (Revenue)","section":"Events"},{"id":"level_30_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_30 Events per Conversion","section":"Events"},{"id":"level_30_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_30 Revenue per Conversion","section":"Events"},{"id":"level_30_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_30 (Conversions)","section":"Events"},{"id":"level_30_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_30 (Conversion Distribution)","section":"Events"},{"id":"level_30_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_30 (Events)","section":"Events"},{"id":"level_30_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_30 (Converted User Size)","section":"Events"},{"id":"level_30_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_30 (Conversions)","section":"Events"},{"id":"level_30_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_30 Rate (Events)","section":"Events"},{"id":"level_30_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_30 Rate (Conversions)","section":"Events"},{"id":"level_300_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_300 (Events)","section":"Events"},{"id":"level_300_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_300 (Revenue)","section":"Events"},{"id":"level_300_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_300 Events per Conversion","section":"Events"},{"id":"level_300_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_300 Revenue per Conversion","section":"Events"},{"id":"level_300_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_300 (Conversions)","section":"Events"},{"id":"level_300_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_300 (Conversion Distribution)","section":"Events"},{"id":"level_300_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_300 (Events)","section":"Events"},{"id":"level_300_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_300 (Converted User Size)","section":"Events"},{"id":"level_300_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_300 (Conversions)","section":"Events"},{"id":"level_300_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_300 Rate (Events)","section":"Events"},{"id":"level_300_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_300 Rate (Conversions)","section":"Events"},{"id":"level_3000_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_3000 (Events)","section":"Events"},{"id":"level_3000_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_3000 (Revenue)","section":"Events"},{"id":"level_3000_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_3000 Events per Conversion","section":"Events"},{"id":"level_3000_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_3000 Revenue per Conversion","section":"Events"},{"id":"level_3000_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_3000 (Conversions)","section":"Events"},{"id":"level_3000_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_3000 (Conversion Distribution)","section":"Events"},{"id":"level_3000_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_3000 (Events)","section":"Events"},{"id":"level_3000_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_3000 (Converted User Size)","section":"Events"},{"id":"level_3000_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_3000 (Conversions)","section":"Events"},{"id":"level_3000_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_3000 Rate (Events)","section":"Events"},{"id":"level_3000_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_3000 Rate (Conversions)","section":"Events"},{"id":"level_400_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_400 (Events)","section":"Events"},{"id":"level_400_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_400 (Revenue)","section":"Events"},{"id":"level_400_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_400 Events per Conversion","section":"Events"},{"id":"level_400_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_400 Revenue per Conversion","section":"Events"},{"id":"level_400_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_400 (Conversions)","section":"Events"},{"id":"level_400_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_400 (Conversion Distribution)","section":"Events"},{"id":"level_400_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_400 (Events)","section":"Events"},{"id":"level_400_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_400 (Converted User Size)","section":"Events"},{"id":"level_400_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_400 (Conversions)","section":"Events"},{"id":"level_400_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_400 Rate (Events)","section":"Events"},{"id":"level_400_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_400 Rate (Conversions)","section":"Events"},{"id":"level_5_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_5 (Events)","section":"Events"},{"id":"level_5_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_5 (Revenue)","section":"Events"},{"id":"level_5_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_5 Events per Conversion","section":"Events"},{"id":"level_5_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_5 Revenue per Conversion","section":"Events"},{"id":"level_5_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_5 (Conversions)","section":"Events"},{"id":"level_5_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_5 (Conversion Distribution)","section":"Events"},{"id":"level_5_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_5 (Events)","section":"Events"},{"id":"level_5_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_5 (Converted User Size)","section":"Events"},{"id":"level_5_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_5 (Conversions)","section":"Events"},{"id":"level_5_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_5 Rate (Events)","section":"Events"},{"id":"level_5_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_5 Rate (Conversions)","section":"Events"},{"id":"level_50_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_50 (Events)","section":"Events"},{"id":"level_50_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_50 (Revenue)","section":"Events"},{"id":"level_50_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_50 Events per Conversion","section":"Events"},{"id":"level_50_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_50 Revenue per Conversion","section":"Events"},{"id":"level_50_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_50 (Conversions)","section":"Events"},{"id":"level_50_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_50 (Conversion Distribution)","section":"Events"},{"id":"level_50_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_50 (Events)","section":"Events"},{"id":"level_50_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_50 (Converted User Size)","section":"Events"},{"id":"level_50_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_50 (Conversions)","section":"Events"},{"id":"level_50_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_50 Rate (Events)","section":"Events"},{"id":"level_50_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_50 Rate (Conversions)","section":"Events"},{"id":"level_500_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_500 (Events)","section":"Events"},{"id":"level_500_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_500 (Revenue)","section":"Events"},{"id":"level_500_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_500 Events per Conversion","section":"Events"},{"id":"level_500_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_500 Revenue per Conversion","section":"Events"},{"id":"level_500_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_500 (Conversions)","section":"Events"},{"id":"level_500_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_500 (Conversion Distribution)","section":"Events"},{"id":"level_500_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_500 (Events)","section":"Events"},{"id":"level_500_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_500 (Converted User Size)","section":"Events"},{"id":"level_500_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_500 (Conversions)","section":"Events"},{"id":"level_500_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_500 Rate (Events)","section":"Events"},{"id":"level_500_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_500 Rate (Conversions)","section":"Events"},{"id":"level_5000_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_5000 (Events)","section":"Events"},{"id":"level_5000_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_5000 (Revenue)","section":"Events"},{"id":"level_5000_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_5000 Events per Conversion","section":"Events"},{"id":"level_5000_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_5000 Revenue per Conversion","section":"Events"},{"id":"level_5000_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_5000 (Conversions)","section":"Events"},{"id":"level_5000_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_5000 (Conversion Distribution)","section":"Events"},{"id":"level_5000_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_5000 (Events)","section":"Events"},{"id":"level_5000_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_5000 (Converted User Size)","section":"Events"},{"id":"level_5000_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_5000 (Conversions)","section":"Events"},{"id":"level_5000_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_5000 Rate (Events)","section":"Events"},{"id":"level_5000_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_5000 Rate (Conversions)","section":"Events"},{"id":"level_600_m3_events_cohort","formatting":"integer","short_name":"","name":"3M level_600 (Events)","section":"Events"},{"id":"level_600_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M level_600 (Revenue)","section":"Events"},{"id":"level_600_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M level_600 Events per Conversion","section":"Events"},{"id":"level_600_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M level_600 Revenue per Conversion","section":"Events"},{"id":"level_600_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M level_600 (Conversions)","section":"Events"},{"id":"level_600_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M level_600 (Conversion Distribution)","section":"Events"},{"id":"level_600_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_600 (Events)","section":"Events"},{"id":"level_600_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M level_600 (Converted User Size)","section":"Events"},{"id":"level_600_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per level_600 (Conversions)","section":"Events"},{"id":"level_600_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M level_600 Rate (Events)","section":"Events"},{"id":"level_600_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M level_600 Rate (Conversions)","section":"Events"},{"id":"main2_enter_10_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Main2_enter_10 (Revenue)","section":"Events"},{"id":"main2_enter_10_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Main2_enter_10 Events per Conversion","section":"Events"},{"id":"main2_enter_10_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Main2_enter_10 Revenue per Conversion","section":"Events"},{"id":"main2_enter_10_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_10_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main2_enter_10 (Events)","section":"Events"},{"id":"main2_enter_10_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_10 (Converted User Size)","section":"Events"},{"id":"main2_enter_10_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main2_enter_10 (Conversions)","section":"Events"},{"id":"main2_enter_10_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_10 Rate (Events)","section":"Events"},{"id":"main2_enter_10_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_10 Rate (Conversions)","section":"Events"},{"id":"main2_enter_20_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Main2_enter_20 (Revenue)","section":"Events"},{"id":"main2_enter_20_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Main2_enter_20 Events per Conversion","section":"Events"},{"id":"main2_enter_20_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Main2_enter_20 Revenue per Conversion","section":"Events"},{"id":"main2_enter_20_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_20_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main2_enter_20 (Events)","section":"Events"},{"id":"main2_enter_20_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_20 (Converted User Size)","section":"Events"},{"id":"main2_enter_20_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main2_enter_20 (Conversions)","section":"Events"},{"id":"main2_enter_20_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_20 Rate (Events)","section":"Events"},{"id":"main2_enter_20_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_20 Rate (Conversions)","section":"Events"},{"id":"main2_enter_30_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Main2_enter_30 (Revenue)","section":"Events"},{"id":"main2_enter_30_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Main2_enter_30 Events per Conversion","section":"Events"},{"id":"main2_enter_30_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Main2_enter_30 Revenue per Conversion","section":"Events"},{"id":"main2_enter_30_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_30_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main2_enter_30 (Events)","section":"Events"},{"id":"main2_enter_30_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_30 (Converted User Size)","section":"Events"},{"id":"main2_enter_30_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main2_enter_30 (Conversions)","section":"Events"},{"id":"main2_enter_30_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_30 Rate (Events)","section":"Events"},{"id":"main2_enter_30_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_30 Rate (Conversions)","section":"Events"},{"id":"main2_enter_40_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Main2_enter_40 (Revenue)","section":"Events"},{"id":"main2_enter_40_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Main2_enter_40 Events per Conversion","section":"Events"},{"id":"main2_enter_40_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Main2_enter_40 Revenue per Conversion","section":"Events"},{"id":"main2_enter_40_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_40 (Conversion Distribution)","section":"Events"},{"id":"main2_enter_40_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main2_enter_40 (Events)","section":"Events"},{"id":"main2_enter_40_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Main2_enter_40 (Converted User Size)","section":"Events"},{"id":"main2_enter_40_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main2_enter_40 (Conversions)","section":"Events"},{"id":"main2_enter_40_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_40 Rate (Events)","section":"Events"},{"id":"main2_enter_40_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Main2_enter_40 Rate (Conversions)","section":"Events"},{"id":"main3_enter_10_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Main3_enter_10 (Revenue)","section":"Events"},{"id":"main3_enter_10_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Main3_enter_10 Events per Conversion","section":"Events"},{"id":"main3_enter_10_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Main3_enter_10 Revenue per Conversion","section":"Events"},{"id":"main3_enter_10_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Main3_enter_10 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_10_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main3_enter_10 (Events)","section":"Events"},{"id":"main3_enter_10_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Main3_enter_10 (Converted User Size)","section":"Events"},{"id":"main3_enter_10_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main3_enter_10 (Conversions)","section":"Events"},{"id":"main3_enter_10_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Main3_enter_10 Rate (Events)","section":"Events"},{"id":"main3_enter_10_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Main3_enter_10 Rate (Conversions)","section":"Events"},{"id":"main3_enter_20_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Main3_enter_20 (Revenue)","section":"Events"},{"id":"main3_enter_20_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Main3_enter_20 Events per Conversion","section":"Events"},{"id":"main3_enter_20_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Main3_enter_20 Revenue per Conversion","section":"Events"},{"id":"main3_enter_20_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Main3_enter_20 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_20_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main3_enter_20 (Events)","section":"Events"},{"id":"main3_enter_20_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Main3_enter_20 (Converted User Size)","section":"Events"},{"id":"main3_enter_20_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main3_enter_20 (Conversions)","section":"Events"},{"id":"main3_enter_20_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Main3_enter_20 Rate (Events)","section":"Events"},{"id":"main3_enter_20_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Main3_enter_20 Rate (Conversions)","section":"Events"},{"id":"main3_enter_30_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Main3_enter_30 (Revenue)","section":"Events"},{"id":"main3_enter_30_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Main3_enter_30 Events per Conversion","section":"Events"},{"id":"main3_enter_30_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Main3_enter_30 Revenue per Conversion","section":"Events"},{"id":"main3_enter_30_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Main3_enter_30 (Conversion Distribution)","section":"Events"},{"id":"main3_enter_30_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main3_enter_30 (Events)","section":"Events"},{"id":"main3_enter_30_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Main3_enter_30 (Converted User Size)","section":"Events"},{"id":"main3_enter_30_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Main3_enter_30 (Conversions)","section":"Events"},{"id":"main3_enter_30_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Main3_enter_30 Rate (Events)","section":"Events"},{"id":"main3_enter_30_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Main3_enter_30 Rate (Conversions)","section":"Events"},{"id":"purchase_flow_m3_events_cohort","formatting":"integer","short_name":"","name":"3M purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M purchase_flow (Revenue)","section":"Events"},{"id":"purchase_flow_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M purchase_flow Events per Conversion","section":"Events"},{"id":"purchase_flow_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M purchase_flow Revenue per Conversion","section":"Events"},{"id":"purchase_flow_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M purchase_flow (Conversion Distribution)","section":"Events"},{"id":"purchase_flow_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per purchase_flow (Events)","section":"Events"},{"id":"purchase_flow_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M purchase_flow (Converted User Size)","section":"Events"},{"id":"purchase_flow_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per purchase_flow (Conversions)","section":"Events"},{"id":"purchase_flow_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M purchase_flow Rate (Events)","section":"Events"},{"id":"purchase_flow_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M purchase_flow Rate (Conversions)","section":"Events"},{"id":"purchase_perky_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Purchase_Perky (Revenue)","section":"Events"},{"id":"purchase_perky_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Purchase_Perky Events per Conversion","section":"Events"},{"id":"purchase_perky_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Purchase_Perky Revenue per Conversion","section":"Events"},{"id":"purchase_perky_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Purchase_Perky (Conversion Distribution)","section":"Events"},{"id":"purchase_perky_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Purchase_Perky (Events)","section":"Events"},{"id":"purchase_perky_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Purchase_Perky (Converted User Size)","section":"Events"},{"id":"purchase_perky_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Purchase_Perky (Conversions)","section":"Events"},{"id":"purchase_perky_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Purchase_Perky Rate (Events)","section":"Events"},{"id":"purchase_perky_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Purchase_Perky Rate (Conversions)","section":"Events"},{"id":"purchase_simple_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Purchase_Simple (Revenue)","section":"Events"},{"id":"purchase_simple_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Purchase_Simple Events per Conversion","section":"Events"},{"id":"purchase_simple_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Purchase_Simple Revenue per Conversion","section":"Events"},{"id":"purchase_simple_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Purchase_Simple (Conversion Distribution)","section":"Events"},{"id":"purchase_simple_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Purchase_Simple (Events)","section":"Events"},{"id":"purchase_simple_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Purchase_Simple (Converted User Size)","section":"Events"},{"id":"purchase_simple_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Purchase_Simple (Conversions)","section":"Events"},{"id":"purchase_simple_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Purchase_Simple Rate (Events)","section":"Events"},{"id":"purchase_simple_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Purchase_Simple Rate (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Purchase_vip_quarterly (Revenue)","section":"Events"},{"id":"purchase_vip_quarterly_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Purchase_vip_quarterly Events per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Purchase_vip_quarterly Revenue per Conversion","section":"Events"},{"id":"purchase_vip_quarterly_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Purchase_vip_quarterly (Conversion Distribution)","section":"Events"},{"id":"purchase_vip_quarterly_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Purchase_vip_quarterly (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Purchase_vip_quarterly (Converted User Size)","section":"Events"},{"id":"purchase_vip_quarterly_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Purchase_vip_quarterly (Conversions)","section":"Events"},{"id":"purchase_vip_quarterly_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Purchase_vip_quarterly Rate (Events)","section":"Events"},{"id":"purchase_vip_quarterly_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Purchase_vip_quarterly Rate (Conversions)","section":"Events"},{"id":"resultpage_m3_events_cohort","formatting":"integer","short_name":"","name":"3M resultpage (Events)","section":"Events"},{"id":"resultpage_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M resultpage (Revenue)","section":"Events"},{"id":"resultpage_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M resultpage Events per Conversion","section":"Events"},{"id":"resultpage_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M resultpage Revenue per Conversion","section":"Events"},{"id":"resultpage_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M resultpage (Conversions)","section":"Events"},{"id":"resultpage_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M resultpage (Conversion Distribution)","section":"Events"},{"id":"resultpage_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per resultpage (Events)","section":"Events"},{"id":"resultpage_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M resultpage (Converted User Size)","section":"Events"},{"id":"resultpage_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per resultpage (Conversions)","section":"Events"},{"id":"resultpage_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M resultpage Rate (Events)","section":"Events"},{"id":"resultpage_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M resultpage Rate (Conversions)","section":"Events"},{"id":"showprice_m3_events_cohort","formatting":"integer","short_name":"","name":"3M showprice (Events)","section":"Events"},{"id":"showprice_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M showprice (Revenue)","section":"Events"},{"id":"showprice_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M showprice Events per Conversion","section":"Events"},{"id":"showprice_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M showprice Revenue per Conversion","section":"Events"},{"id":"showprice_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M showprice (Conversions)","section":"Events"},{"id":"showprice_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M showprice (Conversion Distribution)","section":"Events"},{"id":"showprice_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per showprice (Events)","section":"Events"},{"id":"showprice_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M showprice (Converted User Size)","section":"Events"},{"id":"showprice_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per showprice (Conversions)","section":"Events"},{"id":"showprice_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M showprice Rate (Events)","section":"Events"},{"id":"showprice_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M showprice Rate (Conversions)","section":"Events"},{"id":"subrevenue_m3_events_cohort","formatting":"integer","short_name":"","name":"3M subrevenue (Events)","section":"Events"},{"id":"subrevenue_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M subrevenue (Revenue)","section":"Events"},{"id":"subrevenue_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M subrevenue Events per Conversion","section":"Events"},{"id":"subrevenue_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M subrevenue Revenue per Conversion","section":"Events"},{"id":"subrevenue_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M subrevenue (Conversion Distribution)","section":"Events"},{"id":"subrevenue_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per subrevenue (Events)","section":"Events"},{"id":"subrevenue_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M subrevenue (Converted User Size)","section":"Events"},{"id":"subrevenue_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per subrevenue (Conversions)","section":"Events"},{"id":"subrevenue_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M subrevenue Rate (Events)","section":"Events"},{"id":"subrevenue_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M subrevenue Rate (Conversions)","section":"Events"},{"id":"subscribe_m3_events_cohort","formatting":"integer","short_name":"","name":"3M subscribe (Events)","section":"Events"},{"id":"subscribe_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M subscribe (Revenue)","section":"Events"},{"id":"subscribe_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M subscribe Events per Conversion","section":"Events"},{"id":"subscribe_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M subscribe Revenue per Conversion","section":"Events"},{"id":"subscribe_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M subscribe (Conversions)","section":"Events"},{"id":"subscribe_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M subscribe (Conversion Distribution)","section":"Events"},{"id":"subscribe_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per subscribe (Events)","section":"Events"},{"id":"subscribe_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M subscribe (Converted User Size)","section":"Events"},{"id":"subscribe_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per subscribe (Conversions)","section":"Events"},{"id":"subscribe_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M subscribe Rate (Events)","section":"Events"},{"id":"subscribe_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M subscribe Rate (Conversions)","section":"Events"},{"id":"uac_export_success_1_m3_events_cohort","formatting":"integer","short_name":"","name":"3M uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M uac_export_success_1 (Revenue)","section":"Events"},{"id":"uac_export_success_1_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M uac_export_success_1 Events per Conversion","section":"Events"},{"id":"uac_export_success_1_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M uac_export_success_1 Revenue per Conversion","section":"Events"},{"id":"uac_export_success_1_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M uac_export_success_1 (Conversion Distribution)","section":"Events"},{"id":"uac_export_success_1_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uac_export_success_1 (Events)","section":"Events"},{"id":"uac_export_success_1_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M uac_export_success_1 (Converted User Size)","section":"Events"},{"id":"uac_export_success_1_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uac_export_success_1 (Conversions)","section":"Events"},{"id":"uac_export_success_1_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M uac_export_success_1 Rate (Events)","section":"Events"},{"id":"uac_export_success_1_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M uac_export_success_1 Rate (Conversions)","section":"Events"},{"id":"uac_preview_2_m3_events_cohort","formatting":"integer","short_name":"","name":"3M uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M uac_preview_2 (Revenue)","section":"Events"},{"id":"uac_preview_2_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M uac_preview_2 Events per Conversion","section":"Events"},{"id":"uac_preview_2_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M uac_preview_2 Revenue per Conversion","section":"Events"},{"id":"uac_preview_2_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M uac_preview_2 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_2_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uac_preview_2 (Events)","section":"Events"},{"id":"uac_preview_2_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M uac_preview_2 (Converted User Size)","section":"Events"},{"id":"uac_preview_2_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uac_preview_2 (Conversions)","section":"Events"},{"id":"uac_preview_2_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M uac_preview_2 Rate (Events)","section":"Events"},{"id":"uac_preview_2_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M uac_preview_2 Rate (Conversions)","section":"Events"},{"id":"uac_preview_3_m3_events_cohort","formatting":"integer","short_name":"","name":"3M uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M uac_preview_3 (Revenue)","section":"Events"},{"id":"uac_preview_3_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M uac_preview_3 Events per Conversion","section":"Events"},{"id":"uac_preview_3_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M uac_preview_3 Revenue per Conversion","section":"Events"},{"id":"uac_preview_3_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M uac_preview_3 (Conversion Distribution)","section":"Events"},{"id":"uac_preview_3_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uac_preview_3 (Events)","section":"Events"},{"id":"uac_preview_3_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M uac_preview_3 (Converted User Size)","section":"Events"},{"id":"uac_preview_3_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uac_preview_3 (Conversions)","section":"Events"},{"id":"uac_preview_3_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M uac_preview_3 Rate (Events)","section":"Events"},{"id":"uac_preview_3_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M uac_preview_3 Rate (Conversions)","section":"Events"},{"id":"uacprice_m3_events_cohort","formatting":"integer","short_name":"","name":"3M uacprice (Events)","section":"Events"},{"id":"uacprice_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M uacprice (Revenue)","section":"Events"},{"id":"uacprice_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M uacprice Events per Conversion","section":"Events"},{"id":"uacprice_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M uacprice Revenue per Conversion","section":"Events"},{"id":"uacprice_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M uacprice (Conversions)","section":"Events"},{"id":"uacprice_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M uacprice (Conversion Distribution)","section":"Events"},{"id":"uacprice_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uacprice (Events)","section":"Events"},{"id":"uacprice_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M uacprice (Converted User Size)","section":"Events"},{"id":"uacprice_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uacprice (Conversions)","section":"Events"},{"id":"uacprice_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M uacprice Rate (Events)","section":"Events"},{"id":"uacprice_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M uacprice Rate (Conversions)","section":"Events"},{"id":"uacresultpage_m3_events_cohort","formatting":"integer","short_name":"","name":"3M uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M uacResultPage (Revenue)","section":"Events"},{"id":"uacresultpage_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M uacResultPage Events per Conversion","section":"Events"},{"id":"uacresultpage_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M uacResultPage Revenue per Conversion","section":"Events"},{"id":"uacresultpage_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M uacResultPage (Conversion Distribution)","section":"Events"},{"id":"uacresultpage_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uacResultPage (Events)","section":"Events"},{"id":"uacresultpage_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M uacResultPage (Converted User Size)","section":"Events"},{"id":"uacresultpage_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per uacResultPage (Conversions)","section":"Events"},{"id":"uacresultpage_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M uacResultPage Rate (Events)","section":"Events"},{"id":"uacresultpage_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M uacResultPage Rate (Conversions)","section":"Events"},{"id":"vip_click_m3_events_cohort","formatting":"integer","short_name":"","name":"3M vip_click (Events)","section":"Events"},{"id":"vip_click_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M vip_click (Revenue)","section":"Events"},{"id":"vip_click_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M vip_click Events per Conversion","section":"Events"},{"id":"vip_click_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M vip_click Revenue per Conversion","section":"Events"},{"id":"vip_click_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M vip_click (Conversions)","section":"Events"},{"id":"vip_click_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M vip_click (Conversion Distribution)","section":"Events"},{"id":"vip_click_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_click (Events)","section":"Events"},{"id":"vip_click_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M vip_click (Converted User Size)","section":"Events"},{"id":"vip_click_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_click (Conversions)","section":"Events"},{"id":"vip_click_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_click Rate (Events)","section":"Events"},{"id":"vip_click_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_click Rate (Conversions)","section":"Events"},{"id":"vip_click_event_m3_events_cohort","formatting":"integer","short_name":"","name":"3M vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M vip_click_event (Revenue)","section":"Events"},{"id":"vip_click_event_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M vip_click_event Events per Conversion","section":"Events"},{"id":"vip_click_event_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M vip_click_event Revenue per Conversion","section":"Events"},{"id":"vip_click_event_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M vip_click_event (Conversion Distribution)","section":"Events"},{"id":"vip_click_event_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_click_event (Events)","section":"Events"},{"id":"vip_click_event_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M vip_click_event (Converted User Size)","section":"Events"},{"id":"vip_click_event_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_click_event (Conversions)","section":"Events"},{"id":"vip_click_event_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_click_event Rate (Events)","section":"Events"},{"id":"vip_click_event_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_click_event Rate (Conversions)","section":"Events"},{"id":"vip_event_m3_events_cohort","formatting":"integer","short_name":"","name":"3M vip_event (Events)","section":"Events"},{"id":"vip_event_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M vip_event (Revenue)","section":"Events"},{"id":"vip_event_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M vip_event Events per Conversion","section":"Events"},{"id":"vip_event_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M vip_event Revenue per Conversion","section":"Events"},{"id":"vip_event_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M vip_event (Conversions)","section":"Events"},{"id":"vip_event_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M vip_event (Conversion Distribution)","section":"Events"},{"id":"vip_event_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_event (Events)","section":"Events"},{"id":"vip_event_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M vip_event (Converted User Size)","section":"Events"},{"id":"vip_event_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_event (Conversions)","section":"Events"},{"id":"vip_event_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_event Rate (Events)","section":"Events"},{"id":"vip_event_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_event Rate (Conversions)","section":"Events"},{"id":"vip_show_m3_events_cohort","formatting":"integer","short_name":"","name":"3M vip_show (Events)","section":"Events"},{"id":"vip_show_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M vip_show (Revenue)","section":"Events"},{"id":"vip_show_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M vip_show Events per Conversion","section":"Events"},{"id":"vip_show_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M vip_show Revenue per Conversion","section":"Events"},{"id":"vip_show_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M vip_show (Conversions)","section":"Events"},{"id":"vip_show_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M vip_show (Conversion Distribution)","section":"Events"},{"id":"vip_show_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_show (Events)","section":"Events"},{"id":"vip_show_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M vip_show (Converted User Size)","section":"Events"},{"id":"vip_show_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_show (Conversions)","section":"Events"},{"id":"vip_show_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_show Rate (Events)","section":"Events"},{"id":"vip_show_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_show Rate (Conversions)","section":"Events"},{"id":"vip_show_event_m3_events_cohort","formatting":"integer","short_name":"","name":"3M vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M vip_show_event (Revenue)","section":"Events"},{"id":"vip_show_event_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M vip_show_event Events per Conversion","section":"Events"},{"id":"vip_show_event_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M vip_show_event Revenue per Conversion","section":"Events"},{"id":"vip_show_event_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M vip_show_event (Conversion Distribution)","section":"Events"},{"id":"vip_show_event_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_show_event (Events)","section":"Events"},{"id":"vip_show_event_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M vip_show_event (Converted User Size)","section":"Events"},{"id":"vip_show_event_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per vip_show_event (Conversions)","section":"Events"},{"id":"vip_show_event_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_show_event Rate (Events)","section":"Events"},{"id":"vip_show_event_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M vip_show_event Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Waterpipe_enter_10 (Revenue)","section":"Events"},{"id":"waterpipe_enter_10_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Waterpipe_enter_10 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_10_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Waterpipe_enter_10 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_10_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Waterpipe_enter_10 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_10_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Waterpipe_enter_10 (Events)","section":"Events"},{"id":"waterpipe_enter_10_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Waterpipe_enter_10 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_10_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Waterpipe_enter_10 (Conversions)","section":"Events"},{"id":"waterpipe_enter_10_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Waterpipe_enter_10 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_10_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Waterpipe_enter_10 Rate (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m3_events_cohort","formatting":"integer","short_name":"","name":"3M Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_m3_revenue_cohort","formatting":"money","short_name":"","name":"3M Waterpipe_enter_20 (Revenue)","section":"Events"},{"id":"waterpipe_enter_20_m3_events_per_conversion_cohort","formatting":"decimal","short_name":"","name":"3M Waterpipe_enter_20 Events per Conversion","section":"Events"},{"id":"waterpipe_enter_20_m3_revenue_per_conversion_cohort","formatting":"money","short_name":"","name":"3M Waterpipe_enter_20 Revenue per Conversion","section":"Events"},{"id":"waterpipe_enter_20_m3_conversions_cohort","formatting":"integer","short_name":"","name":"3M Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m3_conversion_distribution_cohort","formatting":"percent","short_name":"","name":"3M Waterpipe_enter_20 (Conversion Distribution)","section":"Events"},{"id":"waterpipe_enter_20_m3_events_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Waterpipe_enter_20 (Events)","section":"Events"},{"id":"waterpipe_enter_20_m3_converted_user_size_cohort","formatting":"integer","short_name":"","name":"3M Waterpipe_enter_20 (Converted User Size)","section":"Events"},{"id":"waterpipe_enter_20_m3_conversions_cost_cohort","formatting":"decimal","short_name":"","name":"3M Cost per Waterpipe_enter_20 (Conversions)","section":"Events"},{"id":"waterpipe_enter_20_m3_events_rate_cohort","formatting":"percent","short_name":"","name":"3M Waterpipe_enter_20 Rate (Events)","section":"Events"},{"id":"waterpipe_enter_20_m3_conversions_rate_cohort","formatting":"percent","short_name":"","name":"3M Waterpipe_enter_20 Rate (Conversions)","section":"Events"}],"ad_revenue_sources":[{"id":"AdMob","name":"AdMob","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Admost","name":"Admost","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Admost SDK","name":"Admost SDK","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"AppLovin Max","name":"AppLovin Max (without FB)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Applovin MAX FB only","name":"Applovin MAX (FB only)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Applovin MAX SDK","name":"Applovin MAX SDK","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Facebook","name":"Facebook","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Helium by Chartboost SDK","name":"Helium by Chartboost SDK","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"IronSource","name":"IronSource","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"IronSource SDK","name":"IronSource SDK","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"MoPub","name":"MoPub","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"S2S Ad Revenue","name":"S2S Ad Revenue","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Tapjoy","name":"Tapjoy","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"TopOn","name":"TopOn","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Unity SDK","name":"Unity SDK","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"unknown","name":"unknown","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"apps":[{"id":"lyedauwpcvls","name":"3X VPN - Free, Unlimited, Safe surf, Speed up apps","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.free.unlimited.lemon.vpn"},{"id":"vhy2gmi62wao","name":"AbTalk Call - Free Phone Call & Worldwide Calling","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.abtalk.freecall"},{"id":"yl480y5lnn5s","name":"Barcode for Amazon","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"amazon.shop.barcode.scanner"},{"id":"i0m01rgawbgg","name":"Brain Boom","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.mind.brain.crazy.boom"},{"id":"10qb6jg0jrsg","name":"CatCut","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.video.music.editor.maker"},{"id":"vgr8xxmlbfuo","name":"Fancy Widget","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"6443466915"},{"id":"ajct88rdyb5s","name":"Fantasy Stylist","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"1624254773"},{"id":"67vjt8qkxk00","name":"Fantasy Stylist : Makeover Match 3","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.and.miyo.fantasystylist"},{"id":"1t49rh62areo","name":"Findout Boom","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.mind.find.out.boom"},{"id":"iv2xy53zaj28","name":"Free Super Z-VPN - Fast & Worldwide Proxy VPN","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.free.neo.vpn"},{"id":"x9tt584grmdc","name":"Free Touch VPN - Unlimited VPN & Fast Security VPN","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.free.turbo.unlimited.touch.vpn"},{"id":"6xs1uo156pvk","name":"Free VPN Master - Unlimited Ultra Fast WiFi Proxy","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.free.unblock.melon.vpn"},{"id":"2xk7j24dl7eo","name":"IndiaTalk","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.global.free.india.talk"},{"id":"yns0uqp4v94w","name":"Melon VPN - Easy Fast VPN","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"1458080487"},{"id":"c18yqx4kbjsw","name":"Melon VPN - Unblock Free Proxy VPN","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.vpnbottle.melon.free.unblock.fast.vpn"},{"id":"7pq3z0qp18xs","name":"Net Secure","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.secret.proxy"},{"id":"sj67ptn2rke8","name":"QR Code & Barcode Scanner Read","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.x.free.file.manager.app"},{"id":"8yuk2aze04xs","name":"QR Code & Barcode Scanner Read","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"1599076456"},{"id":"8hlejq7d1s3k","name":"TouchCall","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.free.phone.touch.call"},{"id":"m7isqq4gsyyo","name":"USA VPN - Free Unlimited Proxy & Security Fast VPN","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"usa.free.unlimited.vpn"},{"id":"fl16sh5j0q2o","name":"VPN Inf - Unlimited Free VPN & Fast Security VPN","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"co.infinitevpn.free.proxy"},{"id":"awfrqejtisxs","name":"VPN Master - Hotspot VPN ProxyVI","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.vpncapa.vpnmaster.free.unblock.vpn"},{"id":"vwbrgvqlrmkg","name":"Widgets Master","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":null},{"id":"w50t1d9z0g00","name":"XCall - Global Free Call App","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"x.free.unlimited.global.call"},{"id":"hop5uvl6pdds","name":"XCleaner","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.video.cleaner"},{"id":"y2zi4yadr4sg","name":"XScanner - QR Code & Barcode","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.bar.qr.code.scanner.reader"},{"id":"marr3b1qekn4","name":"XY VPN - Free, Secure, Unblock, Super, Hotspot","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.mate.vpn"},{"id":"bs79jinwo9og","name":"XY VPN iOS","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"1584915823"},{"id":"xnaxhcmuwq2o","name":"Yoga VPN","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.yogavpn"},{"id":"b9xjvovhqvb4","name":"corn parkour","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"popcorn.parkour.running"},{"id":"4gi04luz0olc","name":"corn parkour new","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"popcorn.parkour.running"},{"id":"gib1hvg3getc","name":"iScanner","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.i.scanner"},{"id":"46apajplrmyo","name":"smart boost","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":"","default_store_app_id":"com.smart.booster.clean"}],"overview_metrics":[{"id":"arpdau_ad","name":"ARPDAU (Ad)","short_name":"ARPDAU (Ad)","section":"Revenue","formatting":"money_precise","increase_is_negative":false,"description":""},{"id":"arpdau","name":"ARPDAU (All)","short_name":"ARPDAU (All)","section":"Revenue","formatting":"money_precise","increase_is_negative":false,"description":""},{"id":"arpdau_iap","name":"ARPDAU (IAP)","short_name":"ARPDAU (IAP)","section":"Revenue","formatting":"money_precise","increase_is_negative":false,"description":""},{"id":"ad_impressions","name":"Ad Impressions","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ad_rpm","name":"Ad RPM","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_revenue","name":"Ad Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"cohort_ad_revenue","name":"Ad Revenue (Cohort)","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"cost","name":"Ad Spend","short_name":"","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"adjust_cost","name":"Ad Spend (Attribution)","short_name":"","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"network_cost","name":"Ad Spend (Network)","short_name":"","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"network_cost_diff","name":"Ad Spend Diff (Network)","short_name":"","section":"Cost","formatting":"decimal","increase_is_negative":true,"description":""},{"id":"all_revenue","name":"All Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"cohort_all_revenue","name":"All Revenue (Cohort)","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"daus","name":"Avg. DAUs","short_name":"","section":"Conversion","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"maus","name":"Avg. MAUs","short_name":"","section":"Conversion","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"waus","name":"Avg. WAUs","short_name":"","section":"Conversion","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"base_sessions","name":"Base Sessions","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"ctr","name":"CTR","short_name":"CTR","section":"Conversion","formatting":"percent","increase_is_negative":false,"description":""},{"id":"network_ctr","name":"CTR (Network)","short_name":"CTR (Network)","section":"Conversion","formatting":"percent","increase_is_negative":false,"description":""},{"id":"click_conversion_rate","name":"Click Conversion Rate (CCR)","short_name":"CCR","section":"Conversion","formatting":"percent","increase_is_negative":false,"description":""},{"id":"click_cost","name":"Click Cost","short_name":"","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"clicks","name":"Clicks","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"attribution_clicks","name":"Clicks (Attribution)","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"network_clicks","name":"Clicks (Network)","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paid_clicks","name":"Clicks (paid)","short_name":"","section":"Cost","formatting":"integer","increase_is_negative":false,"description":""},{"id":"deattributions","name":"Deattributions","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":true,"description":""},{"id":"ecpc","name":"Effective Cost per Click (eCPC)","short_name":"eCPC","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"gdpr_forgets","name":"GDPR Forgets","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":true,"description":""},{"id":"gross_profit","name":"Gross profit","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"cohort_gross_profit","name":"Gross profit (Cohort)","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"impression_conversion_rate","name":"Impression Conversion Rate (ICR)","short_name":"ICR","section":"Conversion","formatting":"percent","increase_is_negative":false,"description":""},{"id":"impression_cost","name":"Impression Cost","short_name":"","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"impressions","name":"Impressions","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"attribution_impressions","name":"Impressions (Attribution)","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"network_impressions","name":"Impressions (Network)","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paid_impressions","name":"Impressions (paid)","short_name":"","section":"Cost","formatting":"integer","increase_is_negative":false,"description":""},{"id":"install_cost","name":"Install Cost","short_name":"","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"installs","name":"Installs","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"network_installs","name":"Installs (Network)","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"paid_installs","name":"Installs (paid)","short_name":"","section":"Cost","formatting":"integer","increase_is_negative":false,"description":""},{"id":"network_installs_diff","name":"Installs Diff (Network)","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":true,"description":""},{"id":"installs_per_mile","name":"Installs per Mille (IPM)","short_name":"IPM","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_install_invalid_signature_rate","name":"Invalid Signature Rejected Install Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"limit_ad_tracking_installs","name":"Limit Ad Tracking Installs","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"limit_ad_tracking_install_rate","name":"Limit Ad Tracking Rate","short_name":"","section":"Conversion","formatting":"percent","increase_is_negative":true,"description":""},{"id":"limit_ad_tracking_reattribution_rate","name":"Limit Ad Tracking Reattribution Rate","short_name":"","section":"Conversion","formatting":"percent","increase_is_negative":true,"description":""},{"id":"limit_ad_tracking_reattributions","name":"Limit Ad Tracking Reattributions","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"non_organic_installs","name":"Non-Organic Installs","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"organic_installs","name":"Organic Installs","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"organic_install_rate","name":"Organic install rate","short_name":"","section":"Conversion","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_ad","name":"ROAS (Ad Revenue)","short_name":"ROAS (Ad)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas","name":"ROAS (All Revenue)","short_name":"ROAS (All)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"roas_iap","name":"ROAS (IAP Revenue)","short_name":"ROAS (IAP)","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"reattributions","name":"Reattributions","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_install_malformed_advertising_id_rate","name":"Rejected Install Malformed Advertising ID Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_install_rate","name":"Rejected Install Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_installs","name":"Rejected Installs","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_installs_anon_ip","name":"Rejected Installs Anonymous IP","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_install_anon_ip_rate","name":"Rejected Installs Anonymous IP Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_installs_click_injection","name":"Rejected Installs Click Injection","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_install_click_injection_rate","name":"Rejected Installs Click Injection Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_installs_distribution_outlier","name":"Rejected Installs Distribution Outlier","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_install_distribution_outlier_rate","name":"Rejected Installs Distribution Outlier Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_installs_malformed_advertising_id","name":"Rejected Installs Malformed Advertising ID","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_installs_invalid_signature","name":"Rejected Installs SDK Signature","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_installs_too_many_engagements","name":"Rejected Installs Too Many Engagements","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_install_too_many_engagements_rate","name":"Rejected Installs Too Many Engagements Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_reattributions","name":"Rejected Reattribution","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_reattribution_rate","name":"Rejected Reattribution Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_reattributions_anon_ip","name":"Rejected Reattributions Anonymous IP","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_reattribution_anon_ip_rate","name":"Rejected Reattributions Anonymous IP Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_reattributions_click_injection","name":"Rejected Reattributions Click Injection","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_reattribution_click_injection_rate","name":"Rejected Reattributions Click Injection Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_reattributions_distribution_outlier","name":"Rejected Reattributions Distribution Outlier","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_reattribution_distribution_outlier_rate","name":"Rejected Reattributions Distribution Outlier Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"rejected_reattributions_too_many_engagements","name":"Rejected Reattributions Too Many Engagements","short_name":"","section":"Fraud","formatting":"integer","increase_is_negative":false,"description":""},{"id":"rejected_reattribution_too_many_engagements_rate","name":"Rejected Reattributions Too Many Engagements Rate","short_name":"","section":"Fraud","formatting":"percent","increase_is_negative":false,"description":""},{"id":"return_on_investment","name":"Return On Investment (ROI)","short_name":"ROI","section":"Revenue","formatting":"percent","increase_is_negative":false,"description":""},{"id":"revenue","name":"Revenue","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"cohort_revenue","name":"Revenue (Cohort)","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"revenue_events","name":"Revenue Events","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"revenue_to_cost","name":"Revenue To Cost Ratio (RCR)","short_name":"RCR","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"sessions","name":"Sessions","short_name":"","section":"Conversion","formatting":"integer","increase_is_negative":false,"description":""},{"id":"events","name":"Total Events","short_name":"","section":"Events","formatting":"integer","increase_is_negative":false,"description":""},{"id":"network_ecpc","name":"eCPC (Network)","short_name":"","section":"Conversion","formatting":"money","increase_is_negative":true,"description":""},{"id":"ecpi_all","name":"eCPI (All Installs)","short_name":"eCPI (All)","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"network_ecpi","name":"eCPI (Network)","short_name":"","section":"Conversion","formatting":"money","increase_is_negative":true,"description":""},{"id":"ecpi","name":"eCPI (Paid Installs)","short_name":"eCPI (Paid)","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"ecpm","name":"eCPM (Attribution)","short_name":"","section":"Cost","formatting":"money","increase_is_negative":true,"description":""},{"id":"network_ecpm","name":"eCPM (Network)","short_name":"","section":"Conversion","formatting":"money","increase_is_negative":true,"description":""}],"skad_metrics":[{"id":"conversion_1","name":"Conversion Bit 1 (SKAdNetwork)","short_name":"Conversion Bit 1","section":"6 Conversion Events (6 Bit)","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_2","name":"Conversion Bit 2 (SKAdNetwork)","short_name":"Conversion Bit 2","section":"6 Conversion Events (6 Bit)","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_3","name":"Conversion Bit 3 (SKAdNetwork)","short_name":"Conversion Bit 3","section":"6 Conversion Events (6 Bit)","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_4","name":"Conversion Bit 4 (SKAdNetwork)","short_name":"Conversion Bit 4","section":"6 Conversion Events (6 Bit)","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_5","name":"Conversion Bit 5 (SKAdNetwork)","short_name":"Conversion Bit 5","section":"6 Conversion Events (6 Bit)","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_6","name":"Conversion Bit 6 (SKAdNetwork)","short_name":"Conversion Bit 6","section":"6 Conversion Events (6 Bit)","formatting":"integer","increase_is_negative":false,"description":""},{"id":"skad_total_installs","name":"Total Installs (SKAdNetwork)","short_name":"","section":"Installs","formatting":"integer","increase_is_negative":false,"description":""},{"id":"skad_installs","name":"Installs (SKAdNetwork)","short_name":"","section":"Installs","formatting":"integer","increase_is_negative":false,"description":""},{"id":"skad_reinstalls","name":"Reinstalls (SKAdNetwork)","short_name":"","section":"Installs","formatting":"integer","increase_is_negative":false,"description":""},{"id":"skad_qualifiers","name":"Qualifiers (SKAdNetwork)","short_name":"","section":"Installs","formatting":"integer","increase_is_negative":false,"description":""},{"id":"invalid_payloads","name":"Invalid Payloads (SKAdNetwork)","short_name":"","section":"Installs","formatting":"integer","increase_is_negative":false,"description":""},{"id":"skad_conversion_value_null","name":"Conversion Value Null","short_name":"","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"skad_conversion_value_gt_0","name":"Conversion Value greater than 0 (SKAdNetwork)","short_name":"","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"valid_conversions","name":"Valid Conversions (SKAdNetwork)","short_name":"","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_total","name":"Conversion Value Total (SKAdNetwork)","short_name":"Conversion Value Total","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_0","name":"Conversion Value 0 (SKAdNetwork)","short_name":"Conversion Value 0","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_1","name":"Conversion Value 1 (SKAdNetwork)","short_name":"Conversion Value 1","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_2","name":"Conversion Value 2 (SKAdNetwork)","short_name":"Conversion Value 2","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_3","name":"Conversion Value 3 (SKAdNetwork)","short_name":"Conversion Value 3","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_4","name":"Conversion Value 4 (SKAdNetwork)","short_name":"Conversion Value 4","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_5","name":"Conversion Value 5 (SKAdNetwork)","short_name":"Conversion Value 5","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_6","name":"Conversion Value 6 (SKAdNetwork)","short_name":"Conversion Value 6","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_7","name":"Conversion Value 7 (SKAdNetwork)","short_name":"Conversion Value 7","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_8","name":"Conversion Value 8 (SKAdNetwork)","short_name":"Conversion Value 8","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_9","name":"Conversion Value 9 (SKAdNetwork)","short_name":"Conversion Value 9","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_10","name":"Conversion Value 10 (SKAdNetwork)","short_name":"Conversion Value 10","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_11","name":"Conversion Value 11 (SKAdNetwork)","short_name":"Conversion Value 11","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_12","name":"Conversion Value 12 (SKAdNetwork)","short_name":"Conversion Value 12","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_13","name":"Conversion Value 13 (SKAdNetwork)","short_name":"Conversion Value 13","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_14","name":"Conversion Value 14 (SKAdNetwork)","short_name":"Conversion Value 14","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_15","name":"Conversion Value 15 (SKAdNetwork)","short_name":"Conversion Value 15","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_16","name":"Conversion Value 16 (SKAdNetwork)","short_name":"Conversion Value 16","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_17","name":"Conversion Value 17 (SKAdNetwork)","short_name":"Conversion Value 17","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_18","name":"Conversion Value 18 (SKAdNetwork)","short_name":"Conversion Value 18","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_19","name":"Conversion Value 19 (SKAdNetwork)","short_name":"Conversion Value 19","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_20","name":"Conversion Value 20 (SKAdNetwork)","short_name":"Conversion Value 20","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_21","name":"Conversion Value 21 (SKAdNetwork)","short_name":"Conversion Value 21","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_22","name":"Conversion Value 22 (SKAdNetwork)","short_name":"Conversion Value 22","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_23","name":"Conversion Value 23 (SKAdNetwork)","short_name":"Conversion Value 23","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_24","name":"Conversion Value 24 (SKAdNetwork)","short_name":"Conversion Value 24","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_25","name":"Conversion Value 25 (SKAdNetwork)","short_name":"Conversion Value 25","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_26","name":"Conversion Value 26 (SKAdNetwork)","short_name":"Conversion Value 26","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_27","name":"Conversion Value 27 (SKAdNetwork)","short_name":"Conversion Value 27","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_28","name":"Conversion Value 28 (SKAdNetwork)","short_name":"Conversion Value 28","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_29","name":"Conversion Value 29 (SKAdNetwork)","short_name":"Conversion Value 29","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_30","name":"Conversion Value 30 (SKAdNetwork)","short_name":"Conversion Value 30","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_31","name":"Conversion Value 31 (SKAdNetwork)","short_name":"Conversion Value 31","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_32","name":"Conversion Value 32 (SKAdNetwork)","short_name":"Conversion Value 32","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_33","name":"Conversion Value 33 (SKAdNetwork)","short_name":"Conversion Value 33","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_34","name":"Conversion Value 34 (SKAdNetwork)","short_name":"Conversion Value 34","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_35","name":"Conversion Value 35 (SKAdNetwork)","short_name":"Conversion Value 35","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_36","name":"Conversion Value 36 (SKAdNetwork)","short_name":"Conversion Value 36","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_37","name":"Conversion Value 37 (SKAdNetwork)","short_name":"Conversion Value 37","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_38","name":"Conversion Value 38 (SKAdNetwork)","short_name":"Conversion Value 38","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_39","name":"Conversion Value 39 (SKAdNetwork)","short_name":"Conversion Value 39","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_40","name":"Conversion Value 40 (SKAdNetwork)","short_name":"Conversion Value 40","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_41","name":"Conversion Value 41 (SKAdNetwork)","short_name":"Conversion Value 41","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_42","name":"Conversion Value 42 (SKAdNetwork)","short_name":"Conversion Value 42","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_43","name":"Conversion Value 43 (SKAdNetwork)","short_name":"Conversion Value 43","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_44","name":"Conversion Value 44 (SKAdNetwork)","short_name":"Conversion Value 44","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_45","name":"Conversion Value 45 (SKAdNetwork)","short_name":"Conversion Value 45","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_46","name":"Conversion Value 46 (SKAdNetwork)","short_name":"Conversion Value 46","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_47","name":"Conversion Value 47 (SKAdNetwork)","short_name":"Conversion Value 47","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_48","name":"Conversion Value 48 (SKAdNetwork)","short_name":"Conversion Value 48","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_49","name":"Conversion Value 49 (SKAdNetwork)","short_name":"Conversion Value 49","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_50","name":"Conversion Value 50 (SKAdNetwork)","short_name":"Conversion Value 50","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_51","name":"Conversion Value 51 (SKAdNetwork)","short_name":"Conversion Value 51","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_52","name":"Conversion Value 52 (SKAdNetwork)","short_name":"Conversion Value 52","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_53","name":"Conversion Value 53 (SKAdNetwork)","short_name":"Conversion Value 53","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_54","name":"Conversion Value 54 (SKAdNetwork)","short_name":"Conversion Value 54","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_55","name":"Conversion Value 55 (SKAdNetwork)","short_name":"Conversion Value 55","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_56","name":"Conversion Value 56 (SKAdNetwork)","short_name":"Conversion Value 56","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_57","name":"Conversion Value 57 (SKAdNetwork)","short_name":"Conversion Value 57","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_58","name":"Conversion Value 58 (SKAdNetwork)","short_name":"Conversion Value 58","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_59","name":"Conversion Value 59 (SKAdNetwork)","short_name":"Conversion Value 59","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_60","name":"Conversion Value 60 (SKAdNetwork)","short_name":"Conversion Value 60","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_61","name":"Conversion Value 61 (SKAdNetwork)","short_name":"Conversion Value 61","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_62","name":"Conversion Value 62 (SKAdNetwork)","short_name":"Conversion Value 62","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"conversion_value_63","name":"Conversion Value 63 (SKAdNetwork)","short_name":"Conversion Value 63","section":"Conversion Values","formatting":"integer","increase_is_negative":false,"description":""},{"id":"connect_vpn_events_min","formatting":"integer","short_name":"","name":"connect_vpn (Min)","section":"Events"},{"id":"connect_vpn_events_max","formatting":"integer","short_name":"","name":"connect_vpn (Max)","section":"Events"},{"id":"connect_vpn_events_est","formatting":"integer","short_name":"","name":"connect_vpn (Average)","section":"Events"},{"id":"connect_vpn_revenue_min","formatting":"decimal","short_name":"","name":"connect_vpn (Min Revenue)","section":"Events"},{"id":"connect_vpn_revenue_max","formatting":"decimal","short_name":"","name":"connect_vpn (Max Revenue)","section":"Events"},{"id":"connect_vpn_revenue_est","formatting":"decimal","short_name":"","name":"connect_vpn (Average Revenue)","section":"Events"},{"id":"connect_vpn_skad_event_conversion_rate","formatting":"percent","short_name":"","name":"connect_vpn (Conversion rate)","section":"Events"},{"id":"skad_revenue_min_roas","name":"ROAS (SKAdN min)","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"skad_revenue_max_roas","name":"ROAS (SKAdN max)","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"skad_revenue_est_roas","name":"ROAS (SKAdN est)","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"skad_revenue_min_roi","name":"ROI (SKAdN min)","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"skad_revenue_max_roi","name":"ROI (SKAdN max)","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"skad_revenue_est_roi","name":"ROI (SKAdN est)","short_name":"","section":"Revenue","formatting":"decimal","increase_is_negative":false,"description":""},{"id":"general revenue_events_min","name":"Total Revenue (Min)","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"general revenue_events_max","name":"Total Revenue (Max)","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"general revenue_events_est","name":"Total Revenue (Average)","short_name":"","section":"Revenue","formatting":"integer","increase_is_negative":false,"description":""},{"id":"general revenue_revenue_min","name":"Total Revenue (Min Revenue)","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"general revenue_revenue_max","name":"Total Revenue (Max Revenue)","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""},{"id":"general revenue_revenue_est","name":"Total Revenue (Average Revenue)","short_name":"","section":"Revenue","formatting":"money","increase_is_negative":false,"description":""}],"countries":[{"id":"af","name":"Afghanistan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"al","name":"Albania","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"dz","name":"Algeria","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"as","name":"American Samoa","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ad","name":"Andorra","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ao","name":"Angola","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ai","name":"Anguilla","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"aq","name":"Antarctica","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ag","name":"Antigua And Barbuda","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ar","name":"Argentina","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"am","name":"Armenia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"aw","name":"Aruba","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"au","name":"Australia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"at","name":"Austria","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"az","name":"Azerbaijan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ax","name":"Åland Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bs","name":"Bahamas","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bh","name":"Bahrain","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bd","name":"Bangladesh","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bb","name":"Barbados","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"by","name":"Belarus","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"be","name":"Belgium","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bz","name":"Belize","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bj","name":"Benin","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bm","name":"Bermuda","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bt","name":"Bhutan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bo","name":"Bolivia, Plurinational State Of","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bq","name":"Bonaire, Saint Eustatius And Saba","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ba","name":"Bosnia & Herzegovina","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bw","name":"Botswana","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bv","name":"Bouvet Island","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"br","name":"Brazil","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"io","name":"British Indian Ocean Territory","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bn","name":"Brunei Darussalam","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bg","name":"Bulgaria","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bf","name":"Burkina Faso","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bi","name":"Burundi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"kh","name":"Cambodia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cm","name":"Cameroon","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ca","name":"Canada","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cv","name":"Cape Verde","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ky","name":"Cayman Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cf","name":"Central African Republic","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"td","name":"Chad","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cl","name":"Chile","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cn","name":"China","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cx","name":"Christmas Island","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cc","name":"Cocos (Keeling) Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"co","name":"Colombia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"km","name":"Comoros","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ck","name":"Cook Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cr","name":"Costa Rica","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ci","name":"Cote d'Ivoire","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"hr","name":"Croatia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cu","name":"Cuba","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cw","name":"Curacao","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cy","name":"Cyprus","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cz","name":"Czech Republic","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cd","name":"Democratic Republic Of Congo","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"dk","name":"Denmark","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"dj","name":"Djibouti","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"dm","name":"Dominica","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"do","name":"Dominican Republic","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tl","name":"East Timor","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ec","name":"Ecuador","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"eg","name":"Egypt","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sv","name":"El Salvador","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gq","name":"Equatorial Guinea","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"er","name":"Eritrea","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ee","name":"Estonia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"et","name":"Ethiopia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"fk","name":"Falkland Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"fo","name":"Faroe Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"fj","name":"Fiji","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"fi","name":"Finland","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"fr","name":"France","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gf","name":"French Guiana","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pf","name":"French Polynesia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tf","name":"French Southern Territories","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ga","name":"Gabon","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gm","name":"Gambia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ge","name":"Georgia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"de","name":"Germany","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gh","name":"Ghana","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gi","name":"Gibraltar","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gr","name":"Greece","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gl","name":"Greenland","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gd","name":"Grenada","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gp","name":"Guadeloupe","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gu","name":"Guam","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gt","name":"Guatemala","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gg","name":"Guernsey","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gn","name":"Guinea","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gw","name":"Guinea-bissau","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gy","name":"Guyana","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ht","name":"Haiti","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"hm","name":"Heard Island And McDonald Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"hn","name":"Honduras","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"hk","name":"Hong Kong","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"hu","name":"Hungary","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"is","name":"Iceland","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"in","name":"India","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"id","name":"Indonesia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ir","name":"Iran, Islamic Republic Of","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"iq","name":"Iraq","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ie","name":"Ireland","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"im","name":"Isle Of Man","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"il","name":"Israel","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"it","name":"Italy","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"jm","name":"Jamaica","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"jp","name":"Japan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"je","name":"Jersey","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"jo","name":"Jordan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"kz","name":"Kazakhstan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ke","name":"Kenya","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ki","name":"Kiribati","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"kp","name":"Korea, Democratic People's Republic Of","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"kw","name":"Kuwait","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"kg","name":"Kyrgyzstan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"la","name":"Lao People's Democratic Republic","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"lv","name":"Latvia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"lb","name":"Lebanon","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ls","name":"Lesotho","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"lr","name":"Liberia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ly","name":"Libya","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"li","name":"Liechtenstein","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"lt","name":"Lithuania","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"lu","name":"Luxembourg","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mo","name":"Macao","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mk","name":"Macedonia, The Former Yugoslav Republic Of","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mg","name":"Madagascar","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mw","name":"Malawi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"my","name":"Malaysia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mv","name":"Maldives","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ml","name":"Mali","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mt","name":"Malta","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mh","name":"Marshall Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mq","name":"Martinique","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mr","name":"Mauritania","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mu","name":"Mauritius","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"yt","name":"Mayotte","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mx","name":"Mexico","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"fm","name":"Micronesia, Federated States Of","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"md","name":"Moldova","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mc","name":"Monaco","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mn","name":"Mongolia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"me","name":"Montenegro","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ms","name":"Montserrat","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ma","name":"Morocco","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mz","name":"Mozambique","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mm","name":"Myanmar","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"na","name":"Namibia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"nr","name":"Nauru","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"np","name":"Nepal","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"nl","name":"Netherlands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"nc","name":"New Caledonia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"nz","name":"New Zealand","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ni","name":"Nicaragua","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ne","name":"Niger","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ng","name":"Nigeria","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"nu","name":"Niue","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"nf","name":"Norfolk Island","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mp","name":"Northern Mariana Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"no","name":"Norway","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"om","name":"Oman","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pk","name":"Pakistan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pw","name":"Palau","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ps","name":"Palestinian Territory, Occupied","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pa","name":"Panama","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pg","name":"Papua New Guinea","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"py","name":"Paraguay","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pe","name":"Peru","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ph","name":"Philippines","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pn","name":"Pitcairn","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pl","name":"Poland","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pt","name":"Portugal","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pr","name":"Puerto Rico","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"qa","name":"Qatar","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cg","name":"Republic Of Congo","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"re","name":"Reunion","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ro","name":"Romania","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ru","name":"Russia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"rw","name":"Rwanda","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"bl","name":"Saint Barthélemy","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sh","name":"Saint Helena, Ascension And Tristan Da Cunha","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"kn","name":"Saint Kitts And Nevis","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"lc","name":"Saint Lucia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mf","name":"Saint Martin","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"pm","name":"Saint Pierre And Miquelon","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"vc","name":"Saint Vincent And The Grenadines","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ws","name":"Samoa","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sm","name":"San Marino","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"st","name":"Sao Tome And Principe","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sa","name":"Saudi Arabia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sn","name":"Senegal","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"rs","name":"Serbia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sc","name":"Seychelles","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sl","name":"Sierra Leone","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sg","name":"Singapore","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sx","name":"Sint Maarten","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sk","name":"Slovakia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"si","name":"Slovenia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sb","name":"Solomon Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"so","name":"Somalia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"za","name":"South Africa","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gs","name":"South Georgia And The South Sandwich Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"kr","name":"South Korea","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ss","name":"South Sudan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"es","name":"Spain","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"lk","name":"Sri Lanka","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sd","name":"Sudan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sr","name":"Suriname","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sj","name":"Svalbard And Jan Mayen","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sz","name":"Swaziland","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"se","name":"Sweden","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ch","name":"Switzerland","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sy","name":"Syrian Arab Republic","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tw","name":"Taiwan, Province Of China","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tj","name":"Tajikistan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tz","name":"Tanzania, United Republic Of","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"th","name":"Thailand","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tg","name":"Togo","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tk","name":"Tokelau","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"to","name":"Tonga","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tt","name":"Trinidad And Tobago","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tn","name":"Tunisia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tr","name":"Turkey","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tm","name":"Turkmenistan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tc","name":"Turks And Caicos Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tv","name":"Tuvalu","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ug","name":"Uganda","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ua","name":"Ukraine","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ae","name":"United Arab Emirates","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"gb","name":"United Kingdom","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"us","name":"United States","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"um","name":"United States Minor Outlying Islands","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"zz","name":"Unknown","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"uy","name":"Uruguay","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"uz","name":"Uzbekistan","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"vu","name":"Vanuatu","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"va","name":"Vatican City State","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ve","name":"Venezuela, Bolivarian Republic Of","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"vn","name":"Viet Nam","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"vg","name":"Virgin Islands (British)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"vi","name":"Virgin Islands (US)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"wf","name":"Wallis And Futuna","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"eh","name":"Western Sahara","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ye","name":"Yemen","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"zm","name":"Zambia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"zw","name":"Zimbabwe","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"utc_offset":[{"id":"+00:00","name":"UTC +00:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+01:00","name":"UTC +01:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+02:00","name":"UTC +02:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+03:00","name":"UTC +03:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+03:30","name":"UTC +03:30","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+04:00","name":"UTC +04:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+04:30","name":"UTC +04:30","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+05:00","name":"UTC +05:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+05:30","name":"UTC +05:30","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+06:00","name":"UTC +06:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+06:30","name":"UTC +06:30","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+07:00","name":"UTC +07:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+08:00","name":"UTC +08:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+09:00","name":"UTC +09:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+09:30","name":"UTC +09:30","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+10:00","name":"UTC +10:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+10:30","name":"UTC +10:30","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+11:00","name":"UTC +11:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+12:00","name":"UTC +12:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+13:00","name":"UTC +13:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"+14:00","name":"UTC +14:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-01:00","name":"UTC -01:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-02:00","name":"UTC -02:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-02:30","name":"UTC -02:30","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-03:00","name":"UTC -03:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-03:30","name":"UTC -03:30","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-04:00","name":"UTC -04:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-05:00","name":"UTC -05:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-06:00","name":"UTC -06:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-07:00","name":"UTC -07:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-08:00","name":"UTC -08:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-09:00","name":"UTC -09:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-09:30","name":"UTC -09:30","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-10:00","name":"UTC -10:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-11:00","name":"UTC -11:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"-12:00","name":"UTC -12:00","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"channels":[{"id":"partner_-300","name":"Organic","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_778","name":"Adcash DSP","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_406","name":"AdTiming","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_857","name":"Adxmi","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_257","name":"Apple","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_7","name":"Applovin","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_221","name":"Appnext","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_1498","name":"Bigo","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_928","name":"ClickDealer","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_1635","name":"DemandScale","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_34","name":"Facebook","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_646","name":"Filex Media","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_1005","name":"GMO SmaAD (GMO TECH)","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_254","name":"Google Ads","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_2360","name":"Google Organic Search","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_57","name":"InMobi","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_2015","name":"InMobi DSP","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_182","name":"ironSource","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_410","name":"MAAS","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_369","name":"Mintegral","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_795","name":"MiraMedia","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_1770","name":"OPPO国际 | OPPO Global","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_1195","name":"PropellerAds","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_1569","name":"SKY FLAG","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_157","name":"Snapchat","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_2064","name":"Snapchat Web","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_172","name":"Startapp","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_30","name":"Tapjoy","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_1678","name":"TikTok for Business","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_32","name":"Twitter","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_217","name":"Unity Ads","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_1718","name":"Vivo 国际 | Vivo Global","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_112","name":"Vungle","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_560","name":"xiaomi","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_194","name":"Yeahmobi","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_2164","name":"快手（海外） | Kwai for Business (Global)","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_1600","name":"有米 国际 | Youmi Overseas","short_name":"","section":"Partners","formatting":null,"increase_is_negative":false,"description":""},{"id":"network_Untrusted Devices","name":"Untrusted Devices","short_name":"","section":"Custom channels","formatting":null,"increase_is_negative":false,"description":""},{"id":"network_GUEST","name":"GUEST","short_name":"","section":"Custom channels","formatting":null,"increase_is_negative":false,"description":""},{"id":"network_yoadx1","name":"yoadx1","short_name":"","section":"Custom channels","formatting":null,"increase_is_negative":false,"description":""},{"id":"network_test","name":"test","short_name":"","section":"Custom channels","formatting":null,"increase_is_negative":false,"description":""},{"id":"network_Ballyhoo","name":"Ballyhoo","short_name":"","section":"Custom channels","formatting":null,"increase_is_negative":false,"description":""},{"id":"network_Affle","name":"Affle","short_name":"","section":"Custom channels","formatting":null,"increase_is_negative":false,"description":""},{"id":"network_cobinla","name":"cobinla","short_name":"","section":"Custom channels","formatting":null,"increase_is_negative":false,"description":""}],"currencies":[{"id":"AED","name":"AED","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"AFN","name":"AFN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ALL","name":"ALL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"AMD","name":"AMD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ANG","name":"ANG","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"AOA","name":"AOA","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ARS","name":"ARS","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"AUD","name":"AUD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"AWG","name":"AWG","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"AZN","name":"AZN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BAM","name":"BAM","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BBD","name":"BBD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BDT","name":"BDT","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BGN","name":"BGN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BHD","name":"BHD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BIF","name":"BIF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BMD","name":"BMD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BND","name":"BND","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BOB","name":"BOB","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BRL","name":"BRL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BSD","name":"BSD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BTN","name":"BTN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BWP","name":"BWP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BYN","name":"BYN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BYR","name":"BYR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"BZD","name":"BZD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CAD","name":"CAD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CDF","name":"CDF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CHF","name":"CHF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CLP","name":"CLP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CNY","name":"CNY","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"COP","name":"COP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CRC","name":"CRC","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CUC","name":"CUC","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CUP","name":"CUP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CVE","name":"CVE","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"CZK","name":"CZK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"DJF","name":"DJF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"DKK","name":"DKK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"DOP","name":"DOP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"DZD","name":"DZD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"EGP","name":"EGP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ERN","name":"ERN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ETB","name":"ETB","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"EUR","name":"EUR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"FJD","name":"FJD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"FKP","name":"FKP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"GBP","name":"GBP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"GEL","name":"GEL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"GGP","name":"GGP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"GHS","name":"GHS","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"GIP","name":"GIP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"GMD","name":"GMD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"GNF","name":"GNF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"GTQ","name":"GTQ","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"GYD","name":"GYD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"HKD","name":"HKD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"HNL","name":"HNL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"HRK","name":"HRK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"HTG","name":"HTG","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"HUF","name":"HUF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"IDR","name":"IDR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ILS","name":"ILS","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"IMP","name":"IMP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"INR","name":"INR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"IQD","name":"IQD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"IRR","name":"IRR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ISK","name":"ISK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"JEP","name":"JEP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"JMD","name":"JMD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"JOD","name":"JOD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"JPY","name":"JPY","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"KES","name":"KES","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"KGS","name":"KGS","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"KHR","name":"KHR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"KMF","name":"KMF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"KPW","name":"KPW","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"KRW","name":"KRW","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"KWD","name":"KWD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"KYD","name":"KYD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"KZT","name":"KZT","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"LAK","name":"LAK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"LBP","name":"LBP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"LKR","name":"LKR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"LRD","name":"LRD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"LSL","name":"LSL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"LTL","name":"LTL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"LYD","name":"LYD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MAD","name":"MAD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MDL","name":"MDL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MGA","name":"MGA","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MKD","name":"MKD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MMK","name":"MMK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MNT","name":"MNT","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MOP","name":"MOP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MRO","name":"MRO","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MUR","name":"MUR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MVR","name":"MVR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MWK","name":"MWK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MXN","name":"MXN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MYR","name":"MYR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"MZN","name":"MZN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"NAD","name":"NAD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"NGN","name":"NGN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"NIO","name":"NIO","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"NOK","name":"NOK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"NPR","name":"NPR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"NZD","name":"NZD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"OMR","name":"OMR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"PAB","name":"PAB","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"PEN","name":"PEN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"PGK","name":"PGK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"PHP","name":"PHP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"PKR","name":"PKR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"PLN","name":"PLN","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"PYG","name":"PYG","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"QAR","name":"QAR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"RON","name":"RON","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"RSD","name":"RSD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"RUB","name":"RUB","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"RWF","name":"RWF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SAR","name":"SAR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SBD","name":"SBD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SCR","name":"SCR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SDG","name":"SDG","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SEK","name":"SEK","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SGD","name":"SGD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SHP","name":"SHP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SLL","name":"SLL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SOS","name":"SOS","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SPL","name":"SPL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SRD","name":"SRD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"STD","name":"STD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SVC","name":"SVC","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SYP","name":"SYP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"SZL","name":"SZL","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"THB","name":"THB","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"TJS","name":"TJS","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"TMT","name":"TMT","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"TND","name":"TND","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"TOP","name":"TOP","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"TRY","name":"TRY","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"TTD","name":"TTD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"TVD","name":"TVD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"TWD","name":"TWD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"TZS","name":"TZS","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"UAH","name":"UAH","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"UGX","name":"UGX","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"USD","name":"USD","short_name":"","section":"Apps Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"UYU","name":"UYU","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"UZS","name":"UZS","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"VEF","name":"VEF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"VND","name":"VND","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"VUV","name":"VUV","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"WST","name":"WST","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"XAF","name":"XAF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"XCD","name":"XCD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"XDR","name":"XDR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"XOF","name":"XOF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"XPF","name":"XPF","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"YER","name":"YER","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ZAR","name":"ZAR","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ZMW","name":"ZMW","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""},{"id":"ZWD","name":"ZWD","short_name":"","section":"Other Currencies","formatting":null,"increase_is_negative":false,"description":""}],"attributes":[{"id":"bid","name":"Bid","short_name":"","section":"","formatting":"money","increase_is_negative":false,"description":""},{"id":"daily_budget","name":"Daily Budget","short_name":"","section":"","formatting":"money","increase_is_negative":false,"description":""},{"id":"ad_status","name":"Status (Ad)","short_name":"","section":"","formatting":"select","increase_is_negative":false,"description":""},{"id":"adgroup_status","name":"Status (Adgroup)","short_name":"","section":"","formatting":"select","increase_is_negative":false,"description":""},{"id":"campaign_status","name":"Status (Campaign)","short_name":"","section":"","formatting":"select","increase_is_negative":false,"description":""}],"cost_mode":[{"id":"adjust","name":"Attribution","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mixed","name":"Mixed","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"network","name":"Network","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"attribution_status":[{"id":"all","name":"all","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"false","name":"installed","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"true","name":"reattributed","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"networks":[{"id":"AdTiming","name":"AdTiming","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Adcash","name":"Adcash","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Adxmi","name":"Adxmi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Affle","name":"Affle","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"AppLovin","name":"AppLovin","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Apple Search Ads","name":"Apple Search Ads","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Appnext","name":"Appnext","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Ballyhoo","name":"Ballyhoo","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Bigo","name":"Bigo","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ClickDealer","name":"ClickDealer","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"DemandScale","name":"DemandScale","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Facebook Installs","name":"Facebook Installs","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Facebook Messenger Installs","name":"Facebook Messenger Installs","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Filex","name":"Filex","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"GMO","name":"GMO","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"GUEST","name":"GUEST","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Google Ads ACE","name":"Google Ads ACE","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Google Ads ACI","name":"Google Ads ACI","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Google Ads Search","name":"Google Ads Search","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Google Organic Search","name":"Google Organic Search","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Inmobi","name":"Inmobi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Instagram Installs","name":"Instagram Installs","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Kwai","name":"Kwai","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"MaaS","name":"MaaS","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Mintegral","name":"Mintegral","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"OPPO Global","name":"OPPO Global","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Off-Facebook Installs","name":"Off-Facebook Installs","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"OppoGlobal","name":"OppoGlobal","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Organic","name":"Organic","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"PropellerAds","name":"PropellerAds","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Snapchat Audience Network","name":"Snapchat Audience Network","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Snapchat Installs","name":"Snapchat Installs","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"StartApp","name":"StartApp","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"TikTok","name":"TikTok","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Twitter Audience Platform","name":"Twitter Audience Platform","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Twitter Installs","name":"Twitter Installs","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Untrusted Devices","name":"Untrusted Devices","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"VivoGlobal","name":"VivoGlobal","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Vungle","name":"Vungle","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"Youmi","name":"Youmi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"cobinla","name":"cobinla","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ironSource","name":"ironSource","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"miramedia","name":"miramedia","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"skyfall","name":"skyfall","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"snapchat web","name":"snapchat web","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tapjoy","name":"tapjoy","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"test","name":"test","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"unity","name":"unity","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"unity ads","name":"unity ads","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"xiaomi","name":"xiaomi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"yeahmobi","name":"yeahmobi","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"yoadx1","name":"yoadx1","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"dimensions":[{"id":"creative_network","name":"Ad (Network)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"ad_account_id","name":"Ad Account ID","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"creative_id_network","name":"Ad ID (Network)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"adgroup","name":"Adgroup","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"adgroup_network","name":"Adgroup (Network)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"adgroup_id_network","name":"Adgroup ID (Network)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"app","name":"App","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"currency","name":"App Currency","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"currency_code","name":"App Currency Code","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"store_id","name":"App store ID","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"store_type","name":"App store type","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"app_token","name":"App token","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"campaign","name":"Campaign","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"campaign_network","name":"Campaign (Network)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"campaign_id_network","name":"Campaign ID (Network)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"channel","name":"Channel","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"country","name":"Country","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"country_code","name":"Country code","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"creative","name":"Creative","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"day","name":"Day","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"device_type","name":"Device type","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"hour","name":"Hour","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"month","name":"Month","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"network","name":"Network","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"os_name","name":"OS name","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner","name":"Partner","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_id","name":"Partner ID","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"partner_name","name":"Partner Name","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"platform","name":"Platform","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"quarter","name":"Quarter","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"region","name":"Region","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sdk_secret","name":"SDK Secret","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"sdk_secret_id","name":"SDK Secret ID","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"source_network","name":"Source (Network)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"source_id_network","name":"Source ID (Network)","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"tracker_token","name":"Tracker token","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"week","name":"Week","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"year","name":"Year","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}],"cohort_maturity":[{"id":"immature","name":"immature","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""},{"id":"mature","name":"mature","short_name":"","section":"","formatting":null,"increase_is_negative":false,"description":""}]}"""

# %%
adjust_config = json.loads(adjust_config)

# %%
adjust_config.keys()
# Out:
# dict_keys(['attribution_type', 'partners', 'attribution_source', 'cohort_metrics', 'event_metrics', 'ad_revenue_sources', 'apps', 'overview_metrics', 'skad_metrics', 'countries', 'utc_offset', 'channels', 'currencies', 'attributes', 'cost_mode', 'attribution_status', 'networks', 'dimensions', 'cohort_maturity'])

# %%
adjust_config['attribution_type']
# Out:
# [{'id': 'all',
#   'name': 'all',
#   'short_name': '',
#   'section': '',
#   'formatting': None,
#   'increase_is_negative': False,
#   'description': ''},
#  {'id': 'click',
#   'name': 'click',
#   'short_name': '',
#   'section': '',
#   'formatting': None,
#   'increase_is_negative': False,
#   'description': ''},
#  {'id': 'impression',
#   'name': 'impression',
#   'short_name': '',
#   'section': '',
#   'formatting': None,
#   'increase_is_negative': False,
#   'description': ''}]

# %%
adjust_config['attribution_source']
# Out:
# [{'id': 'dynamic',
#   'name': 'dynamic',
#   'short_name': '',
#   'section': '',
#   'formatting': None,
#   'increase_is_negative': False,
#   'description': ''}]

# %%
adjust_config['attribution_status']
# Out:
# [{'id': 'all',
#   'name': 'all',
#   'short_name': '',
#   'section': '',
#   'formatting': None,
#   'increase_is_negative': False,
#   'description': ''},
#  {'id': 'false',
#   'name': 'installed',
#   'short_name': '',
#   'section': '',
#   'formatting': None,
#   'increase_is_negative': False,
#   'description': ''},
#  {'id': 'true',
#   'name': 'reattributed',
#   'short_name': '',
#   'section': '',
#   'formatting': None,
#   'increase_is_negative': False,
#   'description': ''}]

# %%
adjust_config['attributes']
# Out:
# [{'id': 'bid',
#   'name': 'Bid',
#   'short_name': '',
#   'section': '',
#   'formatting': 'money',
#   'increase_is_negative': False,
#   'description': ''},
#  {'id': 'daily_budget',
#   'name': 'Daily Budget',
#   'short_name': '',
#   'section': '',
#   'formatting': 'money',
#   'increase_is_negative': False,
#   'description': ''},
#  {'id': 'ad_status',
#   'name': 'Status (Ad)',
#   'short_name': '',
#   'section': '',
#   'formatting': 'select',
#   'increase_is_negative': False,
#   'description': ''},
#  {'id': 'adgroup_status',
#   'name': 'Status (Adgroup)',
#   'short_name': '',
#   'section': '',
#   'formatting': 'select',
#   'increase_is_negative': False,
#   'description': ''},
#  {'id': 'campaign_status',
#   'name': 'Status (Campaign)',
#   'short_name': '',
#   'section': '',
#   'formatting': 'select',
#   'increase_is_negative': False,
#   'description': ''}]

# %%
adjust_config['cohort_maturity']
# Out:
# [{'id': 'immature',
#   'name': 'immature',
#   'short_name': '',
#   'section': '',
#   'formatting': None,
#   'increase_is_negative': False,
#   'description': ''},
#  {'id': 'mature',
#   'name': 'mature',
#   'short_name': '',
#   'section': '',
#   'formatting': None,
#   'increase_is_negative': False,
#   'description': ''}]

# %%
for d in adjust_config['dimensions']:
    print(d['id'], ' -> ', d['name'])
# Out:
# creative_network  ->  Ad (Network)
# ad_account_id  ->  Ad Account ID
# creative_id_network  ->  Ad ID (Network)
# adgroup  ->  Adgroup
# adgroup_network  ->  Adgroup (Network)
# adgroup_id_network  ->  Adgroup ID (Network)
# app  ->  App
# currency  ->  App Currency
# currency_code  ->  App Currency Code
# store_id  ->  App store ID
# store_type  ->  App store type
# app_token  ->  App token
# campaign  ->  Campaign
# campaign_network  ->  Campaign (Network)
# campaign_id_network  ->  Campaign ID (Network)
# channel  ->  Channel
# country  ->  Country
# country_code  ->  Country code
# creative  ->  Creative
# day  ->  Day
# device_type  ->  Device type
# hour  ->  Hour
# month  ->  Month
# network  ->  Network
# os_name  ->  OS name
# partner  ->  Partner
# partner_id  ->  Partner ID
# partner_name  ->  Partner Name
# platform  ->  Platform
# quarter  ->  Quarter
# region  ->  Region
# sdk_secret  ->  SDK Secret
# sdk_secret_id  ->  SDK Secret ID
# ...

# %%
print("\n".join([d['id'] for d in adjust_config['dimensions']]))

for d in adjust_config['dimensions']:
    print(f"{d['id']}: str = Field(description='{d['name']}')")
# Out:
# creative_network
# ad_account_id
# creative_id_network
# adgroup
# adgroup_network
# adgroup_id_network
# app
# currency
# currency_code
# store_id
# store_type
# app_token
# campaign
# campaign_network
# campaign_id_network
# channel
# country
# country_code
# creative
# day
# device_type
# hour
# month
# network
# os_name
# partner
# partner_id
# partner_name
# platform
# quarter
# region
# sdk_secret
# sdk_secret_id
# source_network
# source_id_network
# tracker_token
# week
# year
# creative_network: str = Field(description='Ad (Network)')
# ad_account_id: str = Field(description='Ad Account ID')
# creative_id_network: str = Field(description='Ad ID (Network)')
# adgroup: str = Field(description='Adgroup')
# adgroup_network: str = Field(description='Adgroup (Network)')
# adgroup_id_network: str = Field(description='Adgroup ID (Network)')
# app: str = Field(description='App')
# currency: str = Field(description='App Currency')
# ...

# %%
[c['id'] for c in adjust_config['skad_metrics']]
# Out:
# ['conversion_1',
#  'conversion_2',
#  'conversion_3',
#  'conversion_4',
#  'conversion_5',
#  'conversion_6',
#  'skad_total_installs',
#  'skad_installs',
#  'skad_reinstalls',
#  'skad_qualifiers',
#  'invalid_payloads',
#  'skad_conversion_value_null',
#  'skad_conversion_value_gt_0',
#  'valid_conversions',
#  'conversion_value_total',
#  'conversion_value_0',
#  'conversion_value_1',
#  'conversion_value_2',
#  'conversion_value_3',
#  'conversion_value_4',
#  'conversion_value_5',
#  'conversion_value_6',
#  'conversion_value_7',
#  'conversion_value_8',
#  'conversion_value_9',
#  'conversion_value_10',
#  'conversion_value_11',
#  'conversion_value_12',
#  'conversion_value_13',
#  'conversion_value_14',
#  'conversion_value_15',
#  'conversion_value_16',
#  'conversion_value_17',
#  'conversion_value_18',
#  'conversion_value_19',
#  'conversion_value_20',
#  'conversion_value_21',
#  'conversion_value_22',
#  'conversion_value_23',
#  'conversion_value_24',
# ...

# %%
[c['id'] for c in adjust_config['cohort_metrics']]
# Out:
# ['ad_impressions_d0',
#  'ad_impressions_d1',
#  'ad_impressions_d2',
#  'ad_impressions_d3',
#  'ad_impressions_d4',
#  'ad_impressions_d5',
#  'ad_impressions_d6',
#  'ad_impressions_d7',
#  'ad_impressions_d8',
#  'ad_impressions_d14',
#  'ad_impressions_d30',
#  'ad_impressions_d31',
#  'ad_impressions_d45',
#  'ad_impressions_d75',
#  'ad_impressions_w0',
#  'ad_impressions_w1',
#  'ad_impressions_w2',
#  'ad_impressions_w3',
#  'ad_impressions_m0',
#  'ad_impressions_m1',
#  'ad_impressions_m2',
#  'ad_impressions_m3',
#  'ad_impressions_m4',
#  'ad_impressions_m5',
#  'ad_impressions_m6',
#  'ad_impressions_m7',
#  'ad_impressions_m8',
#  'ad_impressions_m9',
#  'ad_impressions_m10',
#  'ad_impressions_m11',
#  'ad_impressions_m12',
#  'ad_impressions_total_d0',
#  'ad_impressions_total_d1',
#  'ad_impressions_total_d2',
#  'ad_impressions_total_d3',
#  'ad_impressions_total_d4',
#  'ad_impressions_total_d5',
#  'ad_impressions_total_d6',
#  'ad_impressions_total_d7',
# ...

# %%
len([c['id'] for c in adjust_config['event_metrics']])
# Out:
# 8848

# %%
adjust_config['overview_metrics'][3]
# Out:
# {'id': 'ad_impressions',
#  'name': 'Ad Impressions',
#  'short_name': '',
#  'section': 'Revenue',
#  'formatting': 'integer',
#  'increase_is_negative': False,
#  'description': ''}

# %%
# 生成 SQL for overview
for c in adjust_config['overview_metrics']:
    c_t = 'UInt32' if 'integer' in c['formatting'] else 'Decimal64(6)'
    sql = f"""`{c['id']}` {c_t} DEFAULT 0 COMMENT '{c['name']}',"""
    print(sql)
#     print(f"{c['id']}: Optional[{c_t}] = Field(description='{c['name']}')")
# Out:
# `arpdau_ad` Decimal64(6) DEFAULT 0 COMMENT 'ARPDAU (Ad)',
# `arpdau` Decimal64(6) DEFAULT 0 COMMENT 'ARPDAU (All)',
# `arpdau_iap` Decimal64(6) DEFAULT 0 COMMENT 'ARPDAU (IAP)',
# `ad_impressions` UInt32 DEFAULT 0 COMMENT 'Ad Impressions',
# `ad_rpm` Decimal64(6) DEFAULT 0 COMMENT 'Ad RPM',
# `ad_revenue` Decimal64(6) DEFAULT 0 COMMENT 'Ad Revenue',
# `cohort_ad_revenue` Decimal64(6) DEFAULT 0 COMMENT 'Ad Revenue (Cohort)',
# `cost` Decimal64(6) DEFAULT 0 COMMENT 'Ad Spend',
# `adjust_cost` Decimal64(6) DEFAULT 0 COMMENT 'Ad Spend (Attribution)',
# `network_cost` Decimal64(6) DEFAULT 0 COMMENT 'Ad Spend (Network)',
# `network_cost_diff` Decimal64(6) DEFAULT 0 COMMENT 'Ad Spend Diff (Network)',
# `all_revenue` Decimal64(6) DEFAULT 0 COMMENT 'All Revenue',
# `cohort_all_revenue` Decimal64(6) DEFAULT 0 COMMENT 'All Revenue (Cohort)',
# `daus` Decimal64(6) DEFAULT 0 COMMENT 'Avg. DAUs',
# `maus` Decimal64(6) DEFAULT 0 COMMENT 'Avg. MAUs',
# ...

# %%
# 生成 SQL for skad
for c in adjust_config['skad_metrics']:
    c_t = 'UInt32' if 'integer' in c['formatting'] else 'Decimal64(6)'
    sql = f"""`{c['id']}` {c_t} DEFAULT 0 COMMENT '{c['name']}',"""
    print(sql)
#     print(f"{c['id']}: Optional[{c_t}] = Field(description='{c['name']}')")
# Out:
# `conversion_1` UInt32 DEFAULT 0 COMMENT 'Conversion Bit 1 (SKAdNetwork)',
# `conversion_2` UInt32 DEFAULT 0 COMMENT 'Conversion Bit 2 (SKAdNetwork)',
# `conversion_3` UInt32 DEFAULT 0 COMMENT 'Conversion Bit 3 (SKAdNetwork)',
# `conversion_4` UInt32 DEFAULT 0 COMMENT 'Conversion Bit 4 (SKAdNetwork)',
# `conversion_5` UInt32 DEFAULT 0 COMMENT 'Conversion Bit 5 (SKAdNetwork)',
# `conversion_6` UInt32 DEFAULT 0 COMMENT 'Conversion Bit 6 (SKAdNetwork)',
# `skad_total_installs` UInt32 DEFAULT 0 COMMENT 'Total Installs (SKAdNetwork)',
# `skad_installs` UInt32 DEFAULT 0 COMMENT 'Installs (SKAdNetwork)',
# `skad_reinstalls` UInt32 DEFAULT 0 COMMENT 'Reinstalls (SKAdNetwork)',
# `skad_qualifiers` UInt32 DEFAULT 0 COMMENT 'Qualifiers (SKAdNetwork)',
# `invalid_payloads` UInt32 DEFAULT 0 COMMENT 'Invalid Payloads (SKAdNetwork)',
# `skad_conversion_value_null` UInt32 DEFAULT 0 COMMENT 'Conversion Value Null',
# ...

# %%
# 生成 pydantic model for Overview
for c in adjust_config['overview_metrics']:
    c_t = 'int' if 'integer' in c['formatting'] else 'float'
    print(f"{c['id']}: Optional[{c_t}] = Field(description='{c['name']}')")

# %%
# 生成 pydantic model for SKAD
for c in adjust_config['skad_metrics']:
    c_t = 'int' if 'integer' in c['formatting'] else 'float'
    print(f"{c['id']}: Optional[{c_t}] = Field(description='{c['name']}')")
# Out:
# conversion_1: Optional[int] = Field(description='Conversion Bit 1 (SKAdNetwork)')
# conversion_2: Optional[int] = Field(description='Conversion Bit 2 (SKAdNetwork)')
# conversion_3: Optional[int] = Field(description='Conversion Bit 3 (SKAdNetwork)')
# conversion_4: Optional[int] = Field(description='Conversion Bit 4 (SKAdNetwork)')
# conversion_5: Optional[int] = Field(description='Conversion Bit 5 (SKAdNetwork)')
# conversion_6: Optional[int] = Field(description='Conversion Bit 6 (SKAdNetwork)')
# skad_total_installs: Optional[int] = Field(description='Total Installs (SKAdNetwork)')
# skad_installs: Optional[int] = Field(description='Installs (SKAdNetwork)')
# skad_reinstalls: Optional[int] = Field(description='Reinstalls (SKAdNetwork)')
# skad_qualifiers: Optional[int] = Field(description='Qualifiers (SKAdNetwork)')
# invalid_payloads: Optional[int] = Field(description='Invalid Payloads (SKAdNetwork)')
# ...

# %%
# 生成 SQL for overview
for c in adjust_config['overview_metrics']:
    c_t = 'int' if 'integer' in c['formatting'] else 'float'
    print(f"{c['id']}: Optional[{c_t}] = Field(description='{c['name']}')")

# %%
# Out:
# conversion_1: Optional[int] = Field(description='Conversion Bit 1 (SKAdNetwork)')
# conversion_2: Optional[int] = Field(description='Conversion Bit 2 (SKAdNetwork)')
# conversion_3: Optional[int] = Field(description='Conversion Bit 3 (SKAdNetwork)')
# conversion_4: Optional[int] = Field(description='Conversion Bit 4 (SKAdNetwork)')
# conversion_5: Optional[int] = Field(description='Conversion Bit 5 (SKAdNetwork)')
# conversion_6: Optional[int] = Field(description='Conversion Bit 6 (SKAdNetwork)')
# skad_total_installs: Optional[int] = Field(description='Total Installs (SKAdNetwork)')
# skad_installs: Optional[int] = Field(description='Installs (SKAdNetwork)')
# skad_reinstalls: Optional[int] = Field(description='Reinstalls (SKAdNetwork)')
# skad_qualifiers: Optional[int] = Field(description='Qualifiers (SKAdNetwork)')
# invalid_payloads: Optional[int] = Field(description='Invalid Payloads (SKAdNetwork)')
# ...

# %%
[c['id'] for c in adjust_config['overview_metrics']]
# Out:
# ['arpdau_ad',
#  'arpdau',
#  'arpdau_iap',
#  'ad_impressions',
#  'ad_rpm',
#  'ad_revenue',
#  'cohort_ad_revenue',
#  'cost',
#  'adjust_cost',
#  'network_cost',
#  'network_cost_diff',
#  'all_revenue',
#  'cohort_all_revenue',
#  'daus',
#  'maus',
#  'waus',
#  'base_sessions',
#  'ctr',
#  'network_ctr',
#  'click_conversion_rate',
#  'click_cost',
#  'clicks',
#  'attribution_clicks',
#  'network_clicks',
#  'paid_clicks',
#  'deattributions',
#  'ecpc',
#  'gdpr_forgets',
#  'gross_profit',
#  'cohort_gross_profit',
#  'impression_conversion_rate',
#  'impression_cost',
#  'impressions',
#  'attribution_impressions',
#  'network_impressions',
#  'paid_impressions',
#  'install_cost',
#  'installs',
#  'network_installs',
#  'paid_installs',
#  'network_installs_diff',
#  'installs_per_mile',
#  'rejected_install_invalid_signature_rate',
#  'limit_ad_tracking_installs',
#  'limit_ad_tracking_install_rate',
#  'limit_ad_tracking_reattribution_rate',
# ...

# %%
[c['id'] for c in adjust_config['event_metrics']]
# Out:
# ['7d_reward_2600_events',
#  '7d_reward_2600_revenue',
#  'active_events',
#  'active_revenue',
#  'ad_click_events',
#  'ad_click_revenue',
#  'ad_show_events',
#  'ad_show_revenue',
#  'adaction_events',
#  'adaction_revenue',
#  'adclick_events',
#  'adclick_revenue',
#  'adrevenue_events',
#  'adrevenue_revenue',
#  'adshow_events',
#  'adshow_revenue',
#  'adv_events',
#  'adv_revenue',
#  'analytics_events',
#  'analytics_revenue',
#  'buyrevenue_events',
#  'buyrevenue_revenue',
#  'connect_vpn_events',
#  'connect_vpn_revenue',
#  'enter_10_events',
#  'enter_10_revenue',
#  'enter_100_events',
#  'enter_100_revenue',
#  'enter_15_events',
#  'enter_15_revenue',
#  'enter_20_events',
#  'enter_20_revenue',
#  'enter_30_events',
#  'enter_30_revenue',
#  'enter_40_events',
#  'enter_40_revenue',
#  'enter_50_events',
#  'enter_50_revenue',
#  'enter_60_events',
#  'enter_60_revenue',
#  'enter_70_events',
#  'enter_70_revenue',
#  'enter_80_events',
#  'enter_80_revenue',
# ...

# %%
user_action = json.loads("""{"error":0,"msg":"ok","data":{"insights":[{"user_count":10462,"show_user_cnt":10230,"click_user_cnt":9592,"loading_up_scroll_user_cnt":1739,"loading_up_scroll_s_user_cnt":1584,"loading_down_scroll_user_cnt":538,"loading_down_scroll_s_user_cnt":417,"preview_enter_user_cnt":9518,"template_use_user_cnt":8428,"preview_favorite_user_cnt":762,"preview_share_user_cnt":169,"preview_download_user_cnt":289,"edit_enter_user_cnt":7320,"edit_show_s_user_cnt":6897,"edit_export_user_cnt":4311,"edit_export_no_user_cnt":1704,"edit_return_user_cnt":3769,"edit_watermark_remove_user_cnt":877,"edit_resolution_click_user_cnt":642,"edit_export_s_user_cnt":3668,"edit_export_f_user_cnt":102,"edit_export_no_s_user_cnt":1182,"edit_export_no_f_user_cnt":50,"edit_music_swap_user_cnt":1889,"edit_photo_swap_user_cnt":1414,"photo_enter_user_cnt":7934,"photo_album_swap_user_cnt":403,"photo_scan_f_user_cnt":86,"photo_next_user_cnt":7335,"result_enter_user_cnt":4095,"result_show_user_cnt":3139,"result_home_back_user_cnt":3027,"result_whatsapp_user_cnt":574,"result_instagram_user_cnt":165,"result_youtube_user_cnt":170,"result_facebook_user_cnt":203,"result_recommend_user_cnt":910,"result_create_again_user_cnt":260,"result_hd_click_user_cnt":592,"show_cnt":51945,"click_cnt":28846,"loading_up_scroll_cnt":3002,"loading_up_scroll_s_cnt":2640,"loading_down_scroll_cnt":657,
nt":741,"edit_export_s_cnt":5123,"edit_export_no_s_cnt":1262,"edit_music_swap_cnt":3302,"edit_photo_swap_cnt":2622,"user_category":"user_new","user_category_name":"新用户","event_date":"2022-10-13","inst_date":null,"project_id":null,"datasource":null,"pkg":null,"os":null,"cv":null,"utm_country":"IN","utm_country_name":" 印度","utm_source":null,"utm_campaign_id":null,"utm_campaign_name":null,"utm_medium_id":null,"utm_medium_name":null,"utm_creative_id":null,"utm_creative_name":null,"edit_enter_per_all_user":2.7942042460870913,"edit_enter_per_new_user":1.9036106418918919,"edit_enter_ratio":1.0,"edit_enter_user_ratio":1.0,"edit_show_s_per_all_user":2.526652452025586,"edit_show_s_per_new_user":1.6263724662162162,"edit_show_s_ratio":0.8543619322278299,"edit_show_s_user_ratio":0.9448318611498527,"edit_watermark_remove_per_all_user":1.6098964326812428,"edit_watermark_remove_per_new_user":0.14769847972972974,"edit_watermark_remove_ratio":0.0775885974155621,"edit_watermark_remove_user_ratio":0.13466604679993802,"edit_resolution_click_per_all_user":1.3722222222222222,"edit_resolution_click_per_new_user":0.07823057432432433,"edit_resolution_click_ratio":0.0410958904109589,"edit_resolution_click_user_ratio":0.08368200836820083,"edit_music_swap_per_all_user":1.9538461538461538,"edit_music_swap_per_new_user":0.3486064189189189,"edit_music_swap_ratio":0.18312905551550107,"edit_music_swap_user_ratio":0.261893692856036,"edit_photo_swap_per_all_user":2.1282467532467533,"edit_photo_swap_per_new_user":0.2768158783783784,"edit_photo_swap_ratio":0.14541622760800843,"edit_photo_swap_user_ratio":0.19091895242522858,"edit_export_per_all_user":1.8017171988194258,"edit_export_per_new_user":0.7089315878378378,"edit_export_ratio":0.3724141755864899,"edit_export_user_ratio":0.5775608244227491,"edit_export_s_per_all_user":1.6846432094705688,"edit_export_s_per_new_user":0.5408572635135135,"edit_export_s_ratio":0.2841217902501248,"edit_export_s_user_ratio":0.47125368045870136,"edit_export_no_per_all_user":1.5469075747046561,"edit_export_no_per_new_user":0.23500844594594594,"edit_export_no_ratio":0.123454051355998,"edit_export_no_user_ratio":0.2229970556330389,"edit_export_no_s_per_all_user":1.3340380549682875,"edit_export_no_s_per_new_user":0.13323479729729729,"edit_export_no_s_ratio":0.06999057179302312,"edit_export_no_s_user_ratio":0.1465984813265148,"edit_return_per_all_user":2.037878787878788,"edit_return_per_new_user":0.709987331081081,"edit_return_ratio":0.37296877599689426,"edit_return_user_ratio":0.5113900511390052}]}}}""")

# %%
pd.DataFrame(user_action['data']['insights'])
# Out:
#     user_count  show_user_cnt  click_user_cnt  loading_up_scroll_user_cnt  \
# 0        10462          10230            9592                        1739
# 1         3302           3800            3531                        2036
# 2         9433           9056            8541                        1588
# 3         9652           9386            8772                        1653
# 4        10349           9958            9311                        1875
# 5        10290           9759            9075                        3679
# 6        10702          10121            9444                        5510
# 7         9430           8917            8348                        1428
# 8         9155           8804            8281                        1494
# 9         8804           8488            7963                        1478
# 10       10193          10155            9436                        5535
# 11        9472           9074            8451                        1602
#
# ...

# %%
# 食品
# food , more detail
